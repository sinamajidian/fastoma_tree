# %%
#!/usr/bin/python3


# IMPORTNAT  this code accept only .fa file as proteome

def parse_oma_db(oma_database_address):
    
    ############### Parsing OMA db ####################
    ###################################################

    oma_db = db.Database(oma_database_address)

    current_time = datetime.now().strftime("%H:%M:%S")
    print(current_time, "- OMA data is parsed and its release name is:", oma_db.get_release_name())
    list_oma_speices = [z.uniprot_species_code for z in oma_db.tax.genomes.values()] 
    current_time = datetime.now().strftime("%H:%M:%S")
    print(current_time,"- There are",len(list_oma_speices),"species in the OMA database.")
    
    return (oma_db, list_oma_speices)


def parse_hog_og_map(hog_og_map_address):
    
    ############### Parsing hog map python dic #############
    #########################################################

    oma_db = db.Database(oma_database_address)

    file = open(hog_og_map_address, "r")
    contents = file.read()
    hog_OG_map = ast.literal_eval(contents)
    file.close()
    current_time = datetime.now().strftime("%H:%M:%S")
    print(current_time,"- The hog-og map is read from file with the length of ", len(hog_OG_map))
       
    return (hog_OG_map)



def HOG_OG_map(oma_database_address):

    oma_db = db.Database(oma_database_address)
    print("OMA data is parsed and its release name is:", oma_db.get_release_name())
    list_hogog_speices = [z.uniprot_species_code for z in oma_db.tax.genomes.values()] 
    print("There are",len(list_hogog_speices),"species in the HOG-OG OMA database.")

    hog_OG_map = {hog_id.decode("utf-8") : og_count_list[0][0] for hog_id, og_count_list in build_hog_to_og_map(oma_db)}
    print("HOG-OG map is extracted with length of ", len(hog_OG_map))


    hog_OG_map_address = oma_database_address+"_hog_og_map.dic"
    with open(hog_OG_map_address, 'w') as file_map:
        print(hog_OG_map, file = file_map)

    file_map.close()
    print("HOG-OG map is written in the file",hog_OG_map_address)
    
    return (hog_OG_map)


def parse_proteome(list_oma_speices):
    
    ############### Parsing query proteome of species #######
    #########################################################

    
    # IMPORTNAT  this code accept only .fa file as proteome
    project_files = listdir(project_folder+"/omamer_search/proteome/")

    query_species_names = []
    for file in project_files:
        if file.split(".")[-1] == "fa":
            file_name_split = file.split(".")[:-1]
            query_species_names.append('.'.join(file_name_split))
        if file.split(".")[-1] == "fasta":
            file_name_split = file.split(".")[:-1]
            query_species_names.append('.'.join(file_name_split))

    # we may assert existence of query_species_name+".fa/hogmap"
    prots_record_allspecies = [ ]
    for query_species_name in query_species_names:
        prot_address = project_folder +"omamer_search/proteome/"+ query_species_name + ".fa" 
        
        prots_record = list(SeqIO.parse(prot_address, "fasta")) 
        prots_record_allspecies.append(prots_record)

    query_species_num = len(query_species_names)    
    current_time = datetime.now().strftime("%H:%M:%S")
    print(current_time,"- The are",str(query_species_num),"species in the proteome folder.")

    # for development
    for species_i in range(query_species_num):
        len_prot_record_i = len( prots_record_allspecies[species_i] )
        species_name_i = query_species_names[species_i]
        #print(species_name_i,len_prot_record_i)
        if species_name_i in list_oma_speices: 
            current_time = datetime.now().strftime("%H:%M:%S")
            print(current_time,"- the species",species_name_i," already exists in the oma database, remove them first")
            exit()

      
    # The proteins are parsed using  Bio.SeqIO.parse
    # the first part of the header line before space 
    # >tr|A0A2I3FYY2|A0A2I3FYY2_NOMLE Uncharacterized protein OS=Nomascus leucogenys OX=61853 GN=CLPTM1L PE=3 SV=1
    # will be ">tr|A0A2I3FYY2|A0A2I3FYY2_NOMLE"
    # [i.id for i in prots_record_allspecies[0] if len(i.id)!=30 and len(i.id)!=22 ] #'sp|O47892|CYB_NOMLE',
    

    
    return (query_species_names, prots_record_allspecies)

def parse_splice_file(query_species_names):

    protnames_splices_prots_allspecies = []
    species_name_noSplice = []
    for query_species_name in query_species_names:
        splice_address = project_folder +"omamer_search/proteome/"+ query_species_name + ".splice" 

        protnames_splices_prots = []

        try:
            splice_file = open(splice_address,'r');    
            for line in splice_file:
                line_strip = line.strip()
                protnames_splices_prot = line_strip.split(";") 
                protnames_splices_prots.append(protnames_splices_prot)
        except: 
            species_name_noSplice.append(query_species_name)

        protnames_splices_prots_allspecies.append(protnames_splices_prots)

    current_time = datetime.now().strftime("%H:%M:%S")
    print(current_time, "- No splicing file found for these species: ", species_name_noSplice)

    return protnames_splices_prots_allspecies



def parse_hogmap_omamer(query_species_names):

    ################### Parsing omamer's output  ########
    #####################################################
    
    prots_hogmap_name_allspecies = []
    prots_hogmap_hogid_allspecies = []
    prots_hogmap_subfscore_allspecies = []
    prots_hogmap_seqlen_allspecies = []
    prots_hogmap_subfmedseqlen_allspecies = []

    for query_species_name in query_species_names:
        omamer_output_address = project_folder + "omamer_search/hogmap/"+ query_species_name + ".hogmap"     
        omamer_output_file = open(omamer_output_address,'r');
        prots_hogmap_name = []
        prots_hogmap_hogid = []
        prots_hogmap_subfscore = []
        prots_hogmap_seqlen = []
        prots_hogmap_subfmedseqlen = []
        
        for line in omamer_output_file:
            line_strip=line.strip()
            if not line_strip.startswith('qs'):
                line_split= line_strip.split("\t")    
                #if line_split[1]!='na':
                prots_hogmap_name.append(line_split[0])
                prots_hogmap_hogid.append(line_split[1])
                prots_hogmap_subfscore.append(line_split[4]) # subfamily
                prots_hogmap_seqlen.append(line_split[5])
                prots_hogmap_subfmedseqlen.append(line_split[6])
                
        prots_hogmap_name_allspecies.append(prots_hogmap_name)
        prots_hogmap_hogid_allspecies.append(prots_hogmap_hogid)
        prots_hogmap_subfscore_allspecies.append(prots_hogmap_subfscore)
        prots_hogmap_seqlen_allspecies.append(prots_hogmap_seqlen)
        prots_hogmap_subfmedseqlen_allspecies.append(prots_hogmap_subfmedseqlen)
    
    current_time = datetime.now().strftime("%H:%M:%S")
    print(current_time,"- There are ",len(prots_hogmap_name_allspecies)," species in the hogmap folder.")
    print(current_time,"- The first species",query_species_names[0]," contains ",len(prots_hogmap_hogid_allspecies[0])," proteins.")
    print(current_time,"- The first protein of first species is ", prots_hogmap_name_allspecies[0][0])

    hogmap_allspecies = (prots_hogmap_name_allspecies, prots_hogmap_hogid_allspecies, prots_hogmap_subfscore_allspecies, prots_hogmap_seqlen_allspecies, prots_hogmap_subfmedseqlen_allspecies)
    return  hogmap_allspecies
    
    

def filter_prot_mapped(query_species_names, query_prot_records_species,query_prot_names_species_mapped):
    # omamer remove very small proteins, 
    # so  we lose track of order comparing hogmap and fasta file
    # the goal here is to remove those from seq record (of the fasta file)
    query_prot_records_species_filtered=[]
    for species_idx in range(len(query_species_names)):    
        # from fasta file
        query_species_name=query_species_names[species_idx]
        query_prot_records_species_i = query_prot_records_species[species_idx]
        query_prot_ids_records = [record.id for record in query_prot_records_species_i]

        # from hogmap file
        # without proteins that are not mapped on any hogs
        query_prot_names_species_i = query_prot_names_species_mapped[species_idx]

        if len(query_prot_names_species_i) != len(query_prot_records_species_i):

            query_prot_records_filterd=[]
            for query_prot_name in query_prot_names_species_i:
                if query_prot_name in query_prot_ids_records:
                    prot_record_idx = query_prot_ids_records.index(query_prot_name)
                    prot_record = query_prot_records_species_i[prot_record_idx]
                    query_prot_records_filterd.append(prot_record)
                else:
                    current_time = datetime.now().strftime("%H:%M:%S")                    
                    print(current_time,"- Error",query_species_name, query_prot_name)

            current_time = datetime.now().strftime("%H:%M:%S")        
            print(current_time,"- For the species", query_species_name, ", few proteins were ignored by omamer.")
            print(current_time,"- before filtering: in hogmap", len(query_prot_names_species_i), "in proteome", len(query_prot_records_species_i))
            print(current_time,"- After filtering:  in hogmap", len(query_prot_names_species_i), "in proteome", len(query_prot_records_filterd))            
            

        else:
            query_prot_records_filterd = query_prot_records_species_i

        query_prot_records_species_filtered.append(query_prot_records_filterd)
    current_time = datetime.now().strftime("%H:%M:%S")        
    print(current_time,"- For the rest of species, all proteins were mapped using OMAmer.")

    return query_prot_records_species_filtered



def extract_unique_hog_pure(query_species_names,query_hogids_species, query_prot_names_species_mapped,query_prot_records_species):
    ###### Extracting unique HOG list and corresponding query proteins ########
    ###########################################################################

    current_time = datetime.now().strftime("%H:%M:%S")
    print(current_time,"- Extracting proteins mapped only once on a HOG is started")

    query_hogids_filtr_species = []
    query_prot_names_filtr_species = []
    query_prot_records_filtr_species = []

    repeated_hogid_num = 0
    
    query_species_num = len(query_species_names) 
    
    dic_hogs_list=[]  # a list of dictinaries 


    for species_i in range(query_species_num):

        query_hogids =  query_hogids_species[species_i]
        query_prot_names = query_prot_names_species_mapped[species_i]
        query_prot_records  = query_prot_records_species[species_i]
        
        dic_hogs = {}
        for prot_i in range(len(query_hogids)):
            query_hogid      = query_hogids[prot_i]
            query_prot_name  = query_prot_names[prot_i]
            query_prot_record= query_prot_records[prot_i]
            if query_hogid!= 'na':
                if  query_hogid  not in  dic_hogs:
                    dic_hogs[query_hogid]=[(query_prot_name,query_prot_record)]
                else:
                    repeated_hogid_num += 1 
                    dic_hogs[query_hogid].append((query_prot_name,query_prot_record))
        dic_hogs_list.append(dic_hogs)

        
    for dic_hogs in dic_hogs_list: # each species
        
        query_prot_names_filtr = []
        query_prot_records_filtr = []

        hogid_list = list(dic_hogs.keys())
        for hogid in hogid_list:
            list_query_prot = dic_hogs[hogid]
            if len(list_query_prot)>1:
                del dic_hogs[hogid]
        #here dic_hogs is updated and  dic_hogs_list  is also updated.
        
        #print(len(hogid_list),len(dic_hogs))
        #for key, value in d.items():
        query_hogids_filtr = []
        query_prot_names_filtr = []
        query_prot_records_filtr = []        
        #query_hogids_filtr=list(dic_hogs.keys())
        for hogid, tuple_value  in dic_hogs.items():
            query_hogids_filtr.append(hogid)
            query_prot_names_filtr.append(tuple_value[0][0])
            query_prot_records_filtr.append(tuple_value[0][1])
        
        
        

        query_hogids_filtr_species.append(query_hogids_filtr)
        query_prot_names_filtr_species.append(query_prot_names_filtr)
        query_prot_records_filtr_species.append(query_prot_records_filtr)        
    
    current_time  = datetime.now().strftime("%H:%M:%S")
    print(current_time,"- Extracting proteins mapped only once on a HOG is finished")
    num_all_hogs=np.sum([len(dic_hogs) for dic_hogs in dic_hogs_list])
    print(current_time,"- For ",len(dic_hogs_list)," species, we keep ",num_all_hogs,"HOGs.")
    

    return (query_hogids_filtr_species, query_prot_names_filtr_species, query_prot_records_filtr_species )
  

def gather_OG(query_species_names, query_hogids_filtr_species, query_prot_names_filtr_species, query_prot_records_filtr_species):

    ############ Extracting the most frequent OG  ########
    #####################################################

    #dict (oma_group_nr -> dict(species, [proteins]))
    #Og[555] = {homo_erectus: [blabla, blublu], yellow_bird: [P52134], brown_bear: [P2121,B53223]}

    OGs_queries = {}

    # hog_OG_map = {}

    mostFrequent_OG_list_species = []

    frq_most_frequent_og_list_all = [] # for development
    
    query_species_num = len(query_species_names)  
    for species_i in  range(query_species_num):

        query_species_name = query_species_names[species_i]
        #print("\n",query_species_name)

        query_hogids_filtr = query_hogids_filtr_species[species_i]
        query_prot_names_filtr = query_prot_names_filtr_species[species_i]
        query_prot_records_filtr = query_prot_records_filtr_species[species_i]

        mostFrequent_OG_list=[]

        num_query_filtr = len(query_hogids_filtr)
        for  item_idx in range(num_query_filtr): #

            #query_protein = query_prot_names_filtr[item_idx]
            seqRecords_query =  query_prot_records_filtr[item_idx]
            seqRecords_query_edited = SeqRecord(Seq(str(seqRecords_query.seq)), query_species_name, '', '')
            #print(seqRecords_query_edited)

            hog_id= query_hogids_filtr[item_idx]

            if not hog_id in hog_OG_map:   # Caculitng  most frq OG for the new hog
                mostFrequent_OG= -1
                hog_OG_map[hog_id]=mostFrequent_OG

            else:  # hog_id is in hog_OG_map dic
                #print("using the hog-og-map")
                mostFrequent_OG = hog_OG_map[hog_id]

            if mostFrequent_OG in OGs_queries:
                OGs_queries_k = OGs_queries[mostFrequent_OG]

                if not query_species_name in OGs_queries_k:
                    OGs_queries_k[query_species_name] = seqRecords_query_edited
                    OGs_queries[mostFrequent_OG] = OGs_queries_k
            else:
                OGs_queries[mostFrequent_OG] = {query_species_name: seqRecords_query_edited} # query_protein = query_prot_names_filtr[item_idx]
    current_time = datetime.now().strftime("%H:%M:%S")
    print(current_time, "- Needed HOH-OG map ",len(OGs_queries),"are extracted from the map file.") 
    
    return OGs_queries



    
# def filter_gathered_OG(OGs_queries, query_species_names, keep_og_treshold_species_query):

    
#     current_time = datetime.now().strftime("%H:%M:%S")
#     print(current_time, "- Start filtering OGs of proteme queries with length of ", len(OGs_queries),"for ",len(query_species_names),"species.") 
        
#     OGs_queries_filtr={}

#     query_species_og_kept_set= set()

#     query_species_num_OGs_list=[]
#     for OG_id, values in OGs_queries.items():
#         query_species_og= list(values.keys())

#         query_species_num_OGs_list.append(len(query_species_og)) 
#         if len(query_species_og) > keep_og_treshold_species_query:
#             OGs_queries_filtr[OG_id]=values
#             query_species_og_kept_set= query_species_og_kept_set.union(set(query_species_og))


#     current_time = datetime.now().strftime("%H:%M:%S")
#     print(current_time, "- Finished filetering from ",len(OGs_queries),", now",len(OGs_queries_filtr),"OGs are remained.") 
               


#     not_included_species =[]
#     for i in set(query_species_names):
#         if i not in query_species_og_kept_set:
#             not_included_species.append(i)

    
#     current_time = datetime.now().strftime("%H:%M:%S")
#     print(current_time, "- These species missed due to the threshold of",keep_og_treshold_species_query,":",not_included_species) 
               


#     #query_species_num_OGs_list
#     # for i in not_included_species:
#     #     #print(i)
#     #     for OG_id, values in OGs_queries.items():
#     #         if i in values:
#     #             print(values.keys())
#     # easiet way keep the first one or make list and keep the best
#     # but better to set trehsold not to misss any species 
    
#     return OGs_queries_filtr
    


def filter_gathered_OG_2(OGs_queries, query_species_names, num_OG_keep_before_msa):

    current_time = datetime.now().strftime("%H:%M:%S")
    print(current_time, "- Start filtering OGs of proteme queries with length of ", len(OGs_queries),"for ",len(query_species_names),"species.") 
     
    
    if len(OGs_queries) < num_OG_keep_before_msa:
        
        OGs_queries_filtr = OGs_queries   
        
        current_time = datetime.now().strftime("%H:%M:%S")
        print(current_time, "- Number of OGs is ",len(OGs_queries),",which is too low, so filtering is not needed.") 
    
    else:        
    
        OGs_queries_filtr={}

        query_species_og_kept_set= set()

        query_species_num_OGs_list=[]
        for OG_id, values in OGs_queries.items():
            query_species_og= list(values.keys())
            query_species_num_OGs_list.append(len(query_species_og)) 

        threshold_numSpecies_keep_OG_before_msa = np.sort(query_species_num_OGs_list)[-num_OG_keep_before_msa]

        current_time = datetime.now().strftime("%H:%M:%S")
        print(current_time, "- Threshold for the number of species in OG is set to",threshold_numSpecies_keep_OG_before_msa,"to have around ",num_OG_keep_before_msa,"OGs before MSA.") 

        num_kept_OG =  sum([ 1  for i in query_species_num_OGs_list if i >= threshold_numSpecies_keep_OG_before_msa])
        
        if num_kept_OG > 3*num_OG_keep_before_msa:
            print(current_time, "- For threshold",threshold_numSpecies_keep_OG_before_msa,", the number of kept OGs is ",num_kept_OG,",but is too high. Let's increase the threshold by one.") 
            threshold_numSpecies_keep_OG_before_msa = min(len(query_species_names), threshold_numSpecies_keep_OG_before_msa+1)
            num_kept_OG =  sum([ 1  for i in query_species_num_OGs_list if i >= threshold_numSpecies_keep_OG_before_msa])
            print(current_time,"- For threshold",threshold_numSpecies_keep_OG_before_msa,", the number of kept OGs is ",num_kept_OG) 

        if num_kept_OG < 0.1 * num_OG_keep_before_msa:
            print(current_time, "- For threshold",threshold_numSpecies_keep_OG_before_msa,",the number of kept OGs is ",num_kept_OG,",but is too low. Let's decrease the threshold by one.") 

            threshold_numSpecies_keep_OG_before_msa = max(1, threshold_numSpecies_keep_OG_before_msa-1)
        
        print(current_time, "- Finally, the threshold is set to",threshold_numSpecies_keep_OG_before_msa) 

        for OG_id, values in OGs_queries.items():
            query_species_og= list(values.keys())
            query_species_num_OGs_list.append(len(query_species_og)) 
            if len(query_species_og) >= threshold_numSpecies_keep_OG_before_msa:
                OGs_queries_filtr[OG_id]=values
                query_species_og_kept_set= query_species_og_kept_set.union(set(query_species_og))

        current_time = datetime.now().strftime("%H:%M:%S")
        print(current_time, "- Finished filetering. From ",len(OGs_queries),", now",len(OGs_queries_filtr),"OGs are remained.") 




    not_included_species =[]
    for i in set(query_species_names):
        if i not in query_species_og_kept_set:
            not_included_species.append(i)

    current_time = datetime.now().strftime("%H:%M:%S")
    print(current_time, "- These species missed due to the threshold of",threshold_numSpecies_keep_OG_before_msa,":",not_included_species) 
    
    return OGs_queries_filtr
    
    

def find_best_spilce(query_species_names, prots_record_allspecies ,protnamess_splices_prots_allspecies, hogmap_allspecies ):

  

    (prots_hogmap_name_allspecies, prots_hogmap_hogid_allspecies, prots_hogmap_subfscore_allspecies, 
     prots_hogmap_seqlen_allspecies, prots_hogmap_subfmedseqlen_allspecies)= hogmap_allspecies
    # for small backbone, it should be smaller to have enough gene markers


    best_protnames_splice_prots_allspecies = []
    best_hogid_splice_prots_allspecies = []
    best_subfscore_splice_prots_allspecies = []
    protnamess_splices_prots_together_allspecies = []
    
    for species_idx in range(len(query_species_names)):    
        query_species_name= query_species_names[species_idx]

        prots_hogmap_name = prots_hogmap_name_allspecies[species_idx]
        prots_hogmap_hogid = prots_hogmap_hogid_allspecies[species_idx]
        prots_hogmap_subfscore = prots_hogmap_subfscore_allspecies[species_idx]
        prots_hogmap_seqlen = prots_hogmap_seqlen_allspecies[species_idx]
        prots_hogmap_subfmedseqlen  = prots_hogmap_subfmedseqlen_allspecies[species_idx]

        protnamess_splices_prots = protnamess_splices_prots_allspecies[species_idx]
        prots_record= prots_record_allspecies[species_idx]
            
        #print(query_species_name,"Number of prot in fa:",len(prots_record),", in .hogmap:",len(prots_hogmap_name))

        best_protnames_splice_prots = []
        best_hogid_splice_prots = []
        best_subfscore_splice_prots = []
        previous_prot_idx=0

        for protnamess_splices_prot in protnamess_splices_prots:

            diff_len_splices = []
            for protnames in protnamess_splices_prot: 
                
                num_search_next_transcript=100 
                # this is for speed up if the number of transcrip is low ocmpared to num prots in proteom,
                # increase this value to have a better speed

                prots_hogmap_name_sliced = prots_hogmap_name[previous_prot_idx : previous_prot_idx+num_search_next_transcript]

                if protnames in set(prots_hogmap_name_sliced):
                    prot_idx = prots_hogmap_name_sliced.index(protnames) + previous_prot_idx
                else:
                    try:
                        prot_idx = prots_hogmap_name.index(protnames)
                    except:
                        #print(protnames,"in splicing not found in the hogmap")
                        continue
                        
                previous_prot_idx = prot_idx

                prot_hogmap_name = prots_hogmap_name[prot_idx]
                prot_hogmap_hogid = prots_hogmap_hogid[prot_idx]
                prot_hogmap_subfscore = prots_hogmap_subfscore[prot_idx]
                prot_hogmap_seqlen = prots_hogmap_seqlen[prot_idx]
                prot_hogmap_subfmedseqlen  = prots_hogmap_subfmedseqlen[prot_idx]

                if not prot_hogmap_subfscore == "na":
                    diff_len_splice_subf = int(prot_hogmap_seqlen)-int(prot_hogmap_subfmedseqlen)
                    diff_len_splices.append(abs(diff_len_splice_subf))

            if len(diff_len_splices):
                best_protnames_splice = protnamess_splices_prot[diff_len_splices.index(min(diff_len_splices))]

                best_protnames_splice_prots.append(best_protnames_splice)
                best_hogid_splice_prots.append(prot_hogmap_hogid)
                best_subfscore_splice_prots.append(prot_hogmap_subfscore)

        best_protnames_splice_prots_allspecies.append(best_protnames_splice_prots)
        best_hogid_splice_prots_allspecies.append(best_hogid_splice_prots)
        best_subfscore_splice_prots_allspecies.append(best_subfscore_splice_prots)

        protnamess_splices_prots_together = []
        for protnamess_splices_prot in protnamess_splices_prots:
            protnamess_splices_prots_together+=protnamess_splices_prot

        #print("Number of prot with splicings:",len(protnamess_splices_prots_together),", unique splice:",len(best_protnames_splice_prots))

        protnamess_splices_prots_together_allspecies.append(protnamess_splices_prots_together)

    return (best_protnames_splice_prots_allspecies, best_hogid_splice_prots_allspecies,best_subfscore_splice_prots_allspecies, protnamess_splices_prots_together_allspecies)



def filter_records_allspecies(prots_record_allspecies, hogmap_allspecies, best_spilce_allspecies, subfamily_score_tresh):
    
    (prots_hogmap_name_allspecies, prots_hogmap_hogid_allspecies, prots_hogmap_subfscore_allspecies, 
     prots_hogmap_seqlen_allspecies, prots_hogmap_subfmedseqlen_allspecies)= hogmap_allspecies

    (best_protname_splice_prots_allspecies, best_hogid_splice_prots_allspecies,best_subfscore_splice_prots_allspecies,
     protnames_splices_prots_together_allspecies)=  best_spilce_allspecies

    prots_record_filterd_allspecies = []
    prots_name_filterd_allspecies = []
    prots_hogid_filterd_allspecies = [] 

    
    for species_idx in range(len(query_species_names)):    
        query_species_name= query_species_names[species_idx]
        
        prots_record = prots_record_allspecies[species_idx]
        print(species_idx, query_species_name)

        best_protname_splice_prots = best_protname_splice_prots_allspecies[species_idx]
        best_hogid_splice_prots = best_hogid_splice_prots_allspecies[species_idx]
        best_subfscore_splice_prots = best_subfscore_splice_prots_allspecies[species_idx]
        protnames_splices_prots_together = protnames_splices_prots_together_allspecies[species_idx]
        
        
        prots_hogmap_name = prots_hogmap_name_allspecies[species_idx]
        prots_hogmap_hogid = prots_hogmap_hogid_allspecies[species_idx]
        prots_hogmap_subfscore = prots_hogmap_subfscore_allspecies[species_idx]

        prots_record_filterd = []
        prots_name_filterd = []
        prots_hogid_filterd = []

        previous_prot_idx_nosplice=0
        previous_prot_idx_splice=0

        for prot_idx in range( len(prots_record) ):
            prot_record = prots_record[prot_idx]
            prot_name = prot_record.id

            if prot_name not in protnames_splices_prots_together:
                # there is no splicing for this variant in the .splice file 
                prots_hogmap_name_sliced = prots_hogmap_name[previous_prot_idx_nosplice:previous_prot_idx_nosplice+100]        
                if prot_name in set(prots_hogmap_name_sliced):
                    prot_idx_nosplice = previous_prot_idx_nosplice + prots_hogmap_name_sliced.index(prot_name) 
                else:
                    try:
                        prot_idx_nosplice = prots_hogmap_name.index(prot_name)           
                        #print("b",prot_name, previous_prot_idx_splice,prot_idx_splice)                    
                    except:
                        #print(prot_name,"in splicing not found in the hogmap")
                        continue
                        #print("b",prot_name, previous_prot_idx_nosplice,prot_idx_nosplice)
                #print("here1")
                previous_prot_idx_nosplice = prot_idx_nosplice

                prot_hogmap_hogid = prots_hogmap_hogid[prot_idx_nosplice]
                prot_hogmap_subfscore = prots_hogmap_subfscore[prot_idx_nosplice]

                if prot_hogmap_subfscore != "na":
                    if float(prot_hogmap_subfscore) > subfamily_score_tresh:
                        if prot_hogmap_hogid not in prots_hogid_filterd:  #to avoid paralogs, remove those prot mapped on same hog
                            prots_record_filterd.append(prot_record)
                            prots_name_filterd.append(prot_name)
                            prots_hogid_filterd.append(prot_hogmap_hogid)

            elif prot_name in best_protname_splice_prots:
                
                best_protname_splice_prots_sliced= best_protname_splice_prots[previous_prot_idx_splice:previous_prot_idx_splice+100]
                if prot_name in set(best_protname_splice_prots_sliced):        
                    prot_idx_splice = previous_prot_idx_splice + best_protname_splice_prots_sliced.index(prot_name) 
                else:
                    try:
                        prot_idx_splice = best_protname_splice_prots.index(prot_name) 
                        #print("b",prot_name, previous_prot_idx_splice,prot_idx_splice)                    
                    except:
                        #print(prot_name,"in splicing not found in the hogmap")
                        continue
                        
                previous_prot_idx_splice = prot_idx_splice
                

                prot_hogmap_hogid     = best_hogid_splice_prots[prot_idx_splice]
                prot_hogmap_subfscore = best_subfscore_splice_prots[prot_idx_splice]
                if prot_hogmap_subfscore != "na":
                    if float(prot_hogmap_subfscore) > subfamily_score_tresh:
                        if prot_hogmap_hogid not in prots_hogid_filterd:
                            prots_record_filterd.append(prot_record)
                            prots_name_filterd.append(prot_name)
                            prots_hogid_filterd.append(prot_hogmap_hogid)

        #print(len(prots_record_filterd), len(prots_name_filterd), len(prots_hogid_filterd))
        #print("Number of filtered prots:",len(prots_record_filterd))

        prots_record_filterd_allspecies.append(prots_record_filterd)
        prots_name_filterd_allspecies.append(prots_name_filterd)
        prots_hogid_filterd_allspecies.append(prots_hogid_filterd)

    return (prots_record_filterd_allspecies, prots_name_filterd_allspecies, prots_hogid_filterd_allspecies)



    

#def combine_OG_query_filtr(OGs_queries_filtr, oma_db, threshold_least_query_sepecies_in_OG,kept_oma_species_num):
def combine_OG_query_filtr(OGs_queries_filtr, oma_db, kept_oma_species_num):
    
#     ########## Combine proteins of OG with queries ##################
#     #################################################################
    
    current_time = datetime.now().strftime("%H:%M:%S")
    print(current_time, "- Combining queries with OG started for",len(OGs_queries_filtr),"OGs.") 
    
    species_og_dic={}
    
    proteins_object_OG_dic={}
    for OG_q in OGs_queries_filtr.keys():  # OG found in the query

        dic_species_prot = OGs_queries_filtr[OG_q]
        # if  len(dic_species_prot) > threshold_least_query_sepecies_in_OG:
        if OG_q != -1:
            OG_members = oma_db.oma_group_members(OG_q)
            proteins_object_OG = [db.ProteinEntry(oma_db, pr) for pr in OG_members]  # the protein IDs of og members
            proteins_object_OG_dic[OG_q]=proteins_object_OG

            species_all_og = [ str(pr.genome.uniprot_species_code) for pr in proteins_object_OG ]

            for species in species_all_og:
                if species in species_og_dic:
                    #species_og_dic[species].append(OG_q)                        
                    species_og_dic[species] +=1 
                else:
                    #species_og_dic[species]=[OG_q]
                    species_og_dic[species] = 1
    
    current_time = datetime.now().strftime("%H:%M:%S")
    print(current_time, "- Number of OMA species per OG is calculated") 
                         
    species_oma_list=[]
    og_num_list = []
    for species_oma, og_num in species_og_dic.items():
        og_num_list.append(og_num)
        species_oma_list.append(species_oma)
        
    id_species_keep = np.argsort(og_num_list)[-kept_oma_species_num:]
    species_oma_kept = [species_oma_list[i] for i in id_species_keep]

    current_time = datetime.now().strftime("%H:%M:%S")
    print(current_time, "- These OMA species are kept",species_oma_kept) 

    
    seqRecords_OG_queries = []
    seqRecords_all_filtr = []
    for OG_q in OGs_queries_filtr.keys():  # OG found in the query

        dic_species_prot = OGs_queries_filtr[OG_q]
#         if len(dic_species_prot) >threshold_least_query_sepecies_in_OG:

        seqRecords_query_edited_all = list(dic_species_prot.values())
        if OG_q != -1:
            proteins_object_OG = proteins_object_OG_dic[OG_q]
             # covnert to biopython objects
            seqRecords_OG = []
            for pr in proteins_object_OG:
                species_code = str(pr.genome.uniprot_species_code)
                if species_code in species_oma_kept:
                    seq_record = SeqRecord(Seq(pr.sequence),species_code,'','') 
                    seqRecords_OG.append(seq_record)

            seqRecords_OG_queries =seqRecords_OG + seqRecords_query_edited_all
            current_time = datetime.now().strftime("%H:%M:%S")
            #print(current_time, " - Length of OG",OG_q,"was",len(seqRecords_OG),",now is",len(seqRecords_OG_queries))
            print(current_time, " - Combining OG",OG_q," with length of ",len(seqRecords_OG),"\t with a query ",len(seqRecords_query_edited_all)," is just finished.")

            seqRecords_all_filtr.append(seqRecords_OG_queries)


    current_time = datetime.now().strftime("%H:%M:%S")
    print("\n", current_time, "- Combining queries with OG is finished! number of OGs",len(seqRecords_all_filtr)) # 
    
    
    
    open_file = open(project_folder+"fastoma_core/_file_combined_OGs_filtr.pkl", "wb")
    pickle.dump(seqRecords_all_filtr, open_file)
    open_file.close()

    current_time = datetime.now().strftime("%H:%M:%S")
    print("\n", current_time, "- The variable seqRecords_all_filtr is saved as", project_folder+"fastoma_core/_file_combined_OGs_filtr.pkl") # 
    
    return(seqRecords_all_filtr)




def run_msa_OG(seqRecords_OG_queries):
    ############## MSA  ##############
    ##################################
    #current_time = datetime.now().strftime("%H:%M:%S")
    #print(current_time, "- working on new OG with length of ",len(seqRecords_OG_queries))

    wrapper_mafft = mafft.Mafft(seqRecords_OG_queries,datatype="PROTEIN") 
    # MAfft error: Alphabet 'U' is unknown. -> add --anysymbol argument needed to define in the sourse code
    # workaround sed "s/U/X/g"
    
    wrapper_mafft.options.options['--retree'].set_value(1)


    run_mafft = wrapper_mafft() # it's wrapper  storing the result  and time 
    time_taken_mafft = wrapper_mafft.elapsed_time

    result_mafft = wrapper_mafft.result 
    time_taken_mafft2 = wrapper_mafft.elapsed_time
    
    current_time = datetime.now().strftime("%H:%M:%S")
    #print(current_time,"- time elapsed for MSA: ",time_taken_mafft2)
    print(current_time,"- MSA for an OG is just finished: ",time_taken_mafft2)

    return(result_mafft)
   


def run_msa_OG_parallel(seqRecords_all,number_max_workers):
        
    iterotr_OGs = 0 
    
    result_mafft_all_species=[]
    current_time = datetime.now().strftime("%H:%M:%S")
    print(current_time, "- Parallel msa is started for ",len(seqRecords_all)," OGs.")
    
    
    
    with concurrent.futures.ProcessPoolExecutor(max_workers=number_max_workers) as executor: 
        for seqRecords_OG_queries, output_values in zip(seqRecords_all, executor.map(run_msa_OG, seqRecords_all)):
            result_mafft_all_species.append(output_values)

            
    
    open_file = open(project_folder+"fastoma_core/_file_msas.pkl", "wb")
    pickle.dump(result_mafft_all_species, open_file)
    open_file.close()
    
    return result_mafft_all_species
    

def filter_ogs(result_mafft_all_species,ogs_keep_number):

    current_time = datetime.now().strftime("%H:%M:%S")
    print(current_time, "- Filtering MSA started.")

    density_ogs=[]
    for msa_og in result_mafft_all_species:

        gap_count_og= 0
        all_count_og=0
        for record in msa_og:
            seq=str(record.seq)
            gap_count_og += seq.count("-") + seq.count("?") + seq.count(".") +seq.count("~")    
        #gap_count_ogs.append(gap_count_og)
        density_og=gap_count_og/(len(msa_og)*len(msa_og[0]))
        density_ogs.append(density_og)
        #if density_ogs> treshold_density:
    plt.hist(density_ogs,bins=100) # , bins=10
    #plt.show()
    plt.savefig(project_folder+"fastoma_core/_density_ogs.pdf")
    current_time = datetime.now().strftime("%H:%M:%S")
    print(current_time, "- The histogram of density ogs is saved.")
    
    id_og_keep = np.argsort(density_ogs)[-ogs_keep_number:]
    result_mafft_all_species_filtr = [result_mafft_all_species[i] for i in id_og_keep]

    current_time = datetime.now().strftime("%H:%M:%S")
    print(current_time, "- Filtering MSA finished, keeping",len(result_mafft_all_species_filtr),"out of",len(result_mafft_all_species))       
    
    all_labels_raw_ra = [seq.id for aln in result_mafft_all_species_filtr for seq in aln]
    all_labels_raw_filter = [seq.id for aln in result_mafft_all_species for seq in aln]
    
    print(current_time, "- Number of unique record id, species name, was",len(set(all_labels_raw)),"and now is",len(set(all_labels_raw_filter)))
    if len(set(all_labels_raw_filter)) < len(set(all_labels_raw)) :
        print(current_time, "- Few of species were removed due to low OG numebr , use a higher  OG number to keep all species.") 
    

    
    open_file = open(project_folder+"fastoma_core/_"+str(ogs_keep_number)+"_file_msas_filtered.pkl", "wb")
    pickle.dump(result_mafft_all_species_filtr, open_file)
    open_file.close()

        
    return result_mafft_all_species_filtr



def concatante_alignments(result_mafft_all_species,ogs_keep_number):
    ############## Concatante alignments  ##############
    ####################################################

    #alignments= result_maf2_all
    current_time = datetime.now().strftime("%H:%M:%S")
    print(current_time, "- MSA concatenation started")
    
    
    alignments= result_mafft_all_species
    current_time = datetime.now().strftime("%H:%M:%S")
    print(current_time, "- Alignments len",len(alignments))
    #print([len(aln) for aln in alignments ])
    #print([len(seq) for aln in alignments for seq in aln])

    all_labels_raw = [seq.id for aln in alignments for seq in aln]
    all_labels = set(all_labels_raw)
    current_time = datetime.now().strftime("%H:%M:%S")
    #print(current_time, "- id labels: ",len(all_labels),len(all_labels_raw))
    
    # Make a dictionary to store info as we go along
    # (defaultdict is convenient -- asking for a missing key gives back an empty list)
    concat_buf = defaultdict(list)

    # Assume all alignments have same alphabet
    alphabet = alignments[0]._alphabet

    for aln in alignments:
        length = aln.get_alignment_length()
        #print("length",length)
        # check if any labels are missing in the current alignment
        these_labels = set(rec.id for rec in aln)
        missing = all_labels - these_labels
        #print(missing)
        # if any are missing, create unknown data of the right length,
        # stuff the string representation into the concat_buf dict
        for label in missing:
            new_seq = UnknownSeq(length, alphabet=alphabet)
            concat_buf[label].append(str(new_seq))

        # else stuff the string representation into the concat_buf dict
        for rec in aln:
            concat_buf[rec.id].append(str(rec.seq))

    # Stitch all the substrings together using join (most efficient way),
    # and build the Biopython data structures Seq, SeqRecord and MultipleSeqAlignment
    msa = MultipleSeqAlignment(SeqRecord(Seq(''.join(seq_arr), alphabet=alphabet), id=label)
                                for (label, seq_arr) in concat_buf.items())


    current_time = datetime.now().strftime("%H:%M:%S")
    print(current_time, "- MSA concatenation finished")

    ##########
    # print the borders of concatatnion  in nexus format
    # http://www.iqtree.org/doc/Advanced-Tutorial
    #######
    out_name_msa=project_folder+"fastoma_core/_"+str(ogs_keep_number)+"_msa_concatanated.txt"
    handle_msa_fasta = open(out_name_msa,"w")
    SeqIO.write(msa, handle_msa_fasta,"fasta")
    handle_msa_fasta.close()


    # sequences_all=[]
    # for spec, sequences in concat_buf.items():
    #      sequences_all.append(sequences)
    # for i in range(1,100):
    #     print(len(sequences_all[0][i]),len(sequences_all[2][i]) ,len(sequences_all[40][i]) )
    ## therefore, all of them are with same length of sequences

    species_0=list(concat_buf.keys())[0]
    sequences =  concat_buf[species_0]
    len_all = [len(i) for i in sequences] 
#     borders_in_supermatrix=[]
#     borders_in_supermatrix.append((1,len_all[0] )) 
#     accumalte = len_all[0]
#     for i in range(1,100):
#         borders_in_supermatrix.append((accumalte+1,accumalte+len_all[i]))
#         accumalte +=len_all[i]

#     print(len(msa),len(msa[0]),accumalte)
#     #check it works or not
#     # for i in range(100):
#     #     print(borders_in_supermatrix[i][1]-borders_in_supermatrix[i][0]+1,len_all[i])

#     #borders_in_supermatrix
    
#     # begin sets;
#     #     charset part1 = 1-100;
#     #     charset part2 = 101-384;
#     #     charpartition mine = HKY+G:part1, GTR+I+G:part2;
#     # end;
#     borders_out_file_add=project_folder+"border_out_parition.nex"
#     borders_out_file = open(borders_out_file_add,'w')

#     borders_out_file.write("#nexus"+"\n")
#     borders_out_file.write("begin sets;"+"\n")

#     for i, val in enumerate(borders_in_supermatrix):

#         line="    charset part"+str(i)+" = "+str(val[0])+"-"+str(val[1])+";"
#         #print(line)
#         borders_out_file.write(line+'\n')

#     borders_out_file.write("end;\n")
#     borders_out_file.close()
#     print(borders_out_file_add)
    
    
    current_time = datetime.now().strftime("%H:%M:%S")
    print(current_time, "- MSA concatenation has been written in the file",out_name_msa,"with length", len(msa),msa.get_alignment_length()) # super matrix size
    
    
    return msa





def gather_OG_2(query_species_names, prots_hogid_filterd_allspecies, prots_name_filterd_allspecies, prots_record_filterd_allspecies):
#(query_species_names, query_hogids_filtr_species, query_prot_names_filtr_species, query_prot_records_filtr_species):
   
    #(query_species_names, query_hogids_filtr_species, query_prot_names_filtr_species, query_prot_records_filtr_species):

    ############ Extracting the most frequent OG  ########
    #####################################################

    #dict (oma_group_nr -> dict(species, [proteins]))
    #Og[555] = {homo_erectus: [blabla, blublu], yellow_bird: [P52134], brown_bear: [P2121,B53223]}

    OGs_queries = {}

    # hog_OG_map = {}

    mostFrequent_OG_list_species = []

    frq_most_frequent_og_list_all = [] # for development
    
    for species_i in  range(len(query_species_names)):

        query_species_name = query_species_names[species_i]
        #print("\n",query_species_name)

        prots_hogid_filterd = prots_hogid_filterd_allspecies[species_i]
        prots_name_filterd = prots_name_filterd_allspecies[species_i]
        prots_record_filterd = prots_record_filterd_allspecies[species_i]

        mostFrequent_OG_list=[]

        for  item_idx in range(len(prots_hogid_filterd)): #

            #query_protein = query_prot_names_filtr[item_idx]
            seqRecords_query =  prots_record_filterd[item_idx]
            seqRecords_query_edited = SeqRecord(Seq(str(seqRecords_query.seq)), query_species_name, '', '')
            #print(seqRecords_query_edited)

            hog_id= prots_hogid_filterd[item_idx]

            if not hog_id in hog_OG_map:   # Caculitng  most frq OG for the new hog
                mostFrequent_OG= -1
                hog_OG_map[hog_id]=mostFrequent_OG

            else:  # hog_id is in hog_OG_map dic
                #print("using the hog-og-map")
                mostFrequent_OG = hog_OG_map[hog_id]

            if mostFrequent_OG in OGs_queries:
                OGs_queries_k = OGs_queries[mostFrequent_OG]

                if not query_species_name in OGs_queries_k:
                    OGs_queries_k[query_species_name] = seqRecords_query_edited
                    OGs_queries[mostFrequent_OG] = OGs_queries_k
            else:
                OGs_queries[mostFrequent_OG] = {query_species_name: seqRecords_query_edited} # query_protein = query_prot_names_filtr[item_idx]
    current_time = datetime.now().strftime("%H:%M:%S")
    print(current_time, "- Needed HOH-OG map ",len(OGs_queries),"are extracted from the map file.") 
    
    return OGs_queries

# %%
import numpy as np
import pyoma.browser.db as db
import concurrent.futures
import ast
import pickle

import zoo.wrappers.aligners.mafft as mafft  # mafft should be installed beforehand
# import zoo.wrappers.treebuilders.fasttree as fasttree

from datetime import datetime
from sys import argv
from os import listdir
from Bio import SeqIO
from Bio.SeqRecord import SeqRecord
from Bio.Seq import Seq, UnknownSeq
from Bio.Align import MultipleSeqAlignment

from collections import defaultdict


import matplotlib   #for development 
matplotlib.use('Agg')
import matplotlib.pyplot as plt


import pyoma.browser.db as db
from pyoma.browser.hoghelper import build_hog_to_og_map


if __name__ == "__main__":

    
    # a global variable
    #project_folder = argv[1]
    project_folder = "/work/FAC/FBM/DBC/cdessim2/default/smajidi1/fastoma/primate_oma/v27_10/"
    #"/work/FAC/FBM/DBC/cdessim2/default/smajidi1/fastoma/mammal/mml27/"
    
    oma_database_address = project_folder+"omamer_database/oma_path/OmaServer.h5"
    
    print("program has started. The oma database address is in ",oma_database_address)
    
    (oma_db, list_oma_speices) = parse_oma_db(oma_database_address)

    ## if you already  have the hog-og-map, parse it: 
    # hog_og_map_address=oma_database_address+"_hog_og_map.dic"    
    # (hog_OG_map)= parse_hog_og_map(hog_og_map_address)

    ## if you you don't have the hog-og-map, run this: 
    hog_OG_map = HOG_OG_map(oma_database_address)


    #  ?? we assume that the transcript file is in order. e.g. [PROCO00019,PROCO00020] is with the same order in the proteom file and hogmap file.
        
    (query_species_names, prots_record_allspecies) = parse_proteome(list_oma_speices)   
    protnames_splices_prots_allspecies = parse_splice_file(query_species_names)

    hogmap_allspecies = parse_hogmap_omamer(query_species_names)
    #(prots_hogmap_name_allspecies, prots_hogmap_hogid_allspecies, prots_hogmap_subfscore_allspecies, prots_hogmap_seqlen_allspecies, prots_hogmap_subfmedseqlen_allspecies)


    
    # project folder, handling_splicing,   number_max_workers
# Out:
# program has started. The oma database address is in  /work/FAC/FBM/DBC/cdessim2/default/smajidi1/fastoma/primate_oma/v27_10/omamer_database/oma_path/OmaServer.h5
# 09:19:22 - OMA data is parsed and its release name is: OmaStandalone; 1.0.x
# 09:19:22 - There are 10 species in the OMA database.
# OMA data is parsed and its release name is: OmaStandalone; 1.0.x
# There are 10 species in the HOG-OG OMA database.
# HOG-OG map is extracted with length of  38795
# HOG-OG map is written in the file /work/FAC/FBM/DBC/cdessim2/default/smajidi1/fastoma/primate_oma/v27_10/omamer_database/oma_path/OmaServer.h5_hog_og_map.dic
# 09:19:38 - The are 25 species in the proteome folder.
# 09:19:38 - No splicing file found for these species:  ['MANLE_', 'MICMU', 'PANTR_', 'CARSF_', 'SAIBB_', 'COLAP_']
# 09:19:39 - There are  25  species in the hogmap folder.
# 09:19:39 - The first species CERAT  contains  46067  proteins.
# 09:19:39 - The first protein of first species is  CERAT00001

# %%
if 1: 

    handling_splicing =  1# int(argv[2]) # 1 


    if handling_splicing == 1:
        best_spilce_allspecies = find_best_spilce(query_species_names, prots_record_allspecies ,protnames_splices_prots_allspecies, hogmap_allspecies )
        # (best_protname_splice_prots_allspecies, best_hogid_splice_prots_allspecies,best_subfscore_splice_prots_allspecies, protnames_splices_prots_together_allspecies)        
        (best_protnames_splice_prots_allspecies, best_hogid_splice_prots_allspecies, best_subfscore_splice_prots_allspecies,
         protnames_splices_prots_together_allspecies)=  best_spilce_allspecies
        
        
        # the definition of subfamily_score, It seems that I understand it wrongly and should not be used 
        
        subfamily_score_tresh =0

        (prots_record_filterd_allspecies, prots_name_filterd_allspecies, prots_hogid_filterd_allspecies) = filter_records_allspecies(prots_record_allspecies, hogmap_allspecies, best_spilce_allspecies, subfamily_score_tresh)

        OGs_queries = gather_OG_2(query_species_names, prots_hogid_filterd_allspecies, prots_name_filterd_allspecies, prots_record_filterd_allspecies)

    if handling_splicing == 0:


        query_prot_records_species = prots_record_allspecies
        query_prot_names_species_mapped = protnames_splices_prots_allspecies

        (prots_hogmap_name_allspecies, prots_hogmap_hogid_allspecies, prots_hogmap_subfscore_allspecies, prots_hogmap_seqlen_allspecies, prots_hogmap_subfmedseqlen_allspecies) = hogmap_allspecies 
        query_hogids_species = prots_hogmap_hogid_allspecies
        query_prot_names_species_mapped = prots_hogmap_name_allspecies


        query_prot_records_species_filtered =  filter_prot_mapped(query_species_names, query_prot_records_species, query_prot_names_species_mapped)
        (query_hogids_filtr_species, query_prot_names_filtr_species, query_prot_records_filtr_species) = extract_unique_hog_pure(query_species_names,query_hogids_species, query_prot_names_species_mapped, query_prot_records_species_filtered) 

        OGs_queries = gather_OG(query_species_names, query_hogids_filtr_species, query_prot_names_filtr_species, query_prot_records_filtr_species)
# Out:
# 0 CERAT
# 1 MACNE_
# 2 OTOGA_
# 3 CHLSB
# 4 PAPAN
# 5 GORGO_
# 6 PANPA
# 7 BOVIN_
# 8 MOUSE_
# 9 MACFA
# 10 MANLE_
# 11 MICMU
# 12 RHIBE
# 13 PANTR_
# 14 CARSF_
# 15 AOTNA
# 16 PONAB
# 17 SAIBB_
# 18 PROCO
# 19 RHIRO
# 20 HUMAN
# 21 MACMU
# 22 CALJA
# 23 COLAP_
# 24 NOMLE
# 15:02:49 - Needed HOH-OG map  20967 are extracted from the map file.

# %%
# import time
# start = time.time()
# end = time.time()
# elapsed=end - start
# print(elapsed)

# %%
    num_OG_keep_before_msa=500
    OGs_queries_filtr= filter_gathered_OG_2(OGs_queries, query_species_names, num_OG_keep_before_msa)

#     threshold_least_query_sepecies_in_OG =  keep_og_treshold_species_query# 15

    kept_oma_species_num = 10 # 20
# Out:
# 15:27:15 - Start filtering OGs of proteme queries with length of  20967 for  25 species.
# 15:27:15 - Threshold for the number of species in OG is set to 25 to have around  500 OGs before MSA.
# 15:27:15 - For threshold 25 , the number of kept OGs is  5079 ,but is too high. Let's increase the threshold by one.
# 15:27:15 - For threshold 25 , the number of kept OGs is  5079
# 15:27:15 - Finally, the threshold is set to 25
# 15:27:15 - Finished filetering. From  20967 , now 5079 OGs are remained.
# 15:27:15 - These species missed due to the threshold of 25 : []

# %%
    seqRecords_all_filtr = combine_OG_query_filtr(OGs_queries_filtr, oma_db,kept_oma_species_num)
    
#    seqRecords_all_filtr = combine_OG_query_filtr(OGs_queries_filtr, oma_db, threshold_least_query_sepecies_in_OG,kept_oma_species_num)
# Out:
# 14:33:56 - Combining queries with OG started for 961 OGs.
# 14:34:02 - Number of OMA species per OG is calculated
# 14:34:02 - These OMA species are kept ['MOUSE', 'BOVIN', 'OTOGA', 'GORGO', 'MACNE']
# 14:34:02  - Combining OG 18471  with length of  5 	 with a query  25  is just finished.
# 14:34:02  - Combining OG 10646  with length of  5 	 with a query  18  is just finished.
# 14:34:02  - Combining OG 18034  with length of  5 	 with a query  21  is just finished.
# 14:34:02  - Combining OG 9138  with length of  5 	 with a query  25  is just finished.
# 14:34:02  - Combining OG 9566  with length of  5 	 with a query  25  is just finished.
# 14:34:02  - Combining OG 2894  with length of  5 	 with a query  23  is just finished.
# 14:34:02  - Combining OG 9473  with length of  5 	 with a query  25  is just finished.
# 14:34:02  - Combining OG 2952  with length of  5 	 with a query  23  is just finished.
# 14:34:02  - Combining OG 4995  with length of  5 	 with a query  24  is just finished.
# 14:34:02  - Combining OG 50  with length of  5 	 with a query  17  is just finished.
# 14:34:02  - Combining OG 19393  with length of  4 	 with a query  19  is just finished.
# 14:34:02  - Combining OG 19062  with length of  4 	 with a query  22  is just finished.
# 14:34:02  - Combining OG 14836  with length of  5 	 with a query  24  is just finished.
# 14:34:02  - Combining OG 10765  with length of  5 	 with a query  17  is just finished.
# 14:34:02  - Combining OG 4328  with length of  3 	 with a query  16  is just finished.
# 14:34:02  - Combining OG 3233  with length of  5 	 with a query  22  is just finished.
# 14:34:02  - Combining OG 9336  with length of  5 	 with a query  23  is just finished.
# 14:34:02  - Combining OG 9985  with length of  3 	 with a query  17  is just finished.
# 14:34:02  - Combining OG 3281  with length of  5 	 with a query  20  is just finished.
# 14:34:02  - Combining OG 13034  with length of  5 	 with a query  24  is just finished.
# 14:34:02  - Combining OG 17672  with length of  5 	 with a query  24  is just finished.
# 14:34:02  - Combining OG 8779  with length of  3 	 with a query  17  is just finished.
# 14:34:02  - Combining OG 18157  with length of  5 	 with a query  18  is just finished.
# 14:34:02  - Combining OG 16748  with length of  5 	 with a query  22  is just finished.
# 14:34:02  - Combining OG 13581  with length of  5 	 with a query  25  is just finished.
# 14:34:02  - Combining OG 20283  with length of  5 	 with a query  16  is just finished.
# 14:34:02  - Combining OG 9114  with length of  5 	 with a query  17  is just finished.
# 14:34:02  - Combining OG 19164  with length of  4 	 with a query  25  is just finished.
# 14:34:02  - Combining OG 16718  with length of  5 	 with a query  17  is just finished.
# 14:34:02  - Combining OG 13743  with length of  5 	 with a query  23  is just finished.
# 14:34:02  - Combining OG 19346  with length of  5 	 with a query  23  is just finished.
# 14:34:02  - Combining OG 12966  with length of  5 	 with a query  24  is just finished.
# 14:34:02  - Combining OG 17615  with length of  5 	 with a query  17  is just finished.
# 14:34:02  - Combining OG 18230  with length of  5 	 with a query  21  is just finished.
# 14:34:02  - Combining OG 6708  with length of  5 	 with a query  22  is just finished.
# 14:34:02  - Combining OG 10819  with length of  5 	 with a query  25  is just finished.
# 14:34:02  - Combining OG 17668  with length of  5 	 with a query  17  is just finished.
# 14:34:02  - Combining OG 17659  with length of  5 	 with a query  22  is just finished.
# 14:34:02  - Combining OG 16526  with length of  5 	 with a query  23  is just finished.
# 14:34:02  - Combining OG 18214  with length of  5 	 with a query  20  is just finished.
# 14:34:02  - Combining OG 11365  with length of  4 	 with a query  19  is just finished.
# 14:34:02  - Combining OG 17671  with length of  5 	 with a query  19  is just finished.
# 14:34:02  - Combining OG 18847  with length of  5 	 with a query  19  is just finished.
# 14:34:02  - Combining OG 8706  with length of  5 	 with a query  23  is just finished.
# 14:34:02  - Combining OG 8936  with length of  5 	 with a query  18  is just finished.
# 14:34:02  - Combining OG 19213  with length of  5 	 with a query  25  is just finished.
# 14:34:02  - Combining OG 17446  with length of  5 	 with a query  22  is just finished.
# 14:34:02  - Combining OG 15500  with length of  5 	 with a query  25  is just finished.
# 14:34:02  - Combining OG 9248  with length of  5 	 with a query  19  is just finished.
# 14:34:02  - Combining OG 19562  with length of  5 	 with a query  23  is just finished.
# 14:34:02  - Combining OG 17915  with length of  5 	 with a query  23  is just finished.
# 14:34:02  - Combining OG 19080  with length of  5 	 with a query  24  is just finished.
# 14:34:02  - Combining OG 16196  with length of  5 	 with a query  24  is just finished.
# 14:34:02  - Combining OG 14769  with length of  5 	 with a query  21  is just finished.
# 14:34:02  - Combining OG 16499  with length of  4 	 with a query  17  is just finished.
# 14:34:02  - Combining OG 2  with length of  4 	 with a query  25  is just finished.
# 14:34:02  - Combining OG 18308  with length of  5 	 with a query  24  is just finished.
# 14:34:02  - Combining OG 18621  with length of  5 	 with a query  24  is just finished.
# 14:34:02  - Combining OG 8774  with length of  5 	 with a query  23  is just finished.
# 14:34:02  - Combining OG 13443  with length of  5 	 with a query  21  is just finished.
# 14:34:02  - Combining OG 19470  with length of  5 	 with a query  23  is just finished.
# 14:34:02  - Combining OG 17657  with length of  4 	 with a query  16  is just finished.
# 14:34:02  - Combining OG 19262  with length of  4 	 with a query  16  is just finished.
# 14:34:02  - Combining OG 19766  with length of  3 	 with a query  16  is just finished.
# 14:34:02  - Combining OG 17674  with length of  5 	 with a query  24  is just finished.
# 14:34:02  - Combining OG 18332  with length of  5 	 with a query  25  is just finished.
# 14:34:02  - Combining OG 11001  with length of  4 	 with a query  24  is just finished.
# 14:34:02  - Combining OG 18837  with length of  5 	 with a query  21  is just finished.
# 14:34:02  - Combining OG 20255  with length of  5 	 with a query  22  is just finished.
# 14:34:02  - Combining OG 18056  with length of  5 	 with a query  25  is just finished.
# 14:34:02  - Combining OG 16396  with length of  5 	 with a query  19  is just finished.
# 14:34:02  - Combining OG 17040  with length of  4 	 with a query  21  is just finished.
# 14:34:02  - Combining OG 11424  with length of  5 	 with a query  25  is just finished.
# 14:34:02  - Combining OG 16016  with length of  5 	 with a query  24  is just finished.
# 14:34:02  - Combining OG 17237  with length of  5 	 with a query  23  is just finished.
# 14:34:02  - Combining OG 19639  with length of  5 	 with a query  19  is just finished.
# 14:34:02  - Combining OG 15224  with length of  4 	 with a query  17  is just finished.
# 14:34:02  - Combining OG 13918  with length of  5 	 with a query  23  is just finished.
# 14:34:02  - Combining OG 15934  with length of  5 	 with a query  15  is just finished.
# 14:34:02  - Combining OG 10368  with length of  5 	 with a query  22  is just finished.
# 14:34:02  - Combining OG 5221  with length of  5 	 with a query  20  is just finished.
# 14:34:02  - Combining OG 19137  with length of  5 	 with a query  23  is just finished.
# 14:34:02  - Combining OG 17380  with length of  5 	 with a query  24  is just finished.
# 14:34:02  - Combining OG 13119  with length of  5 	 with a query  19  is just finished.
# 14:34:02  - Combining OG 14471  with length of  5 	 with a query  19  is just finished.
# 14:34:02  - Combining OG 17760  with length of  5 	 with a query  24  is just finished.
# 14:34:02  - Combining OG 10673  with length of  5 	 with a query  20  is just finished.
# 14:34:02  - Combining OG 20644  with length of  5 	 with a query  23  is just finished.
# 14:34:02  - Combining OG 11251  with length of  5 	 with a query  25  is just finished.
# 14:34:02  - Combining OG 15340  with length of  5 	 with a query  20  is just finished.
# 14:34:02  - Combining OG 17165  with length of  5 	 with a query  19  is just finished.
# 14:34:02  - Combining OG 11253  with length of  5 	 with a query  24  is just finished.
# 14:34:02  - Combining OG 8882  with length of  5 	 with a query  18  is just finished.
# 14:34:02  - Combining OG 12023  with length of  5 	 with a query  20  is just finished.
# 14:34:02  - Combining OG 11985  with length of  5 	 with a query  19  is just finished.
# 14:34:02  - Combining OG 18525  with length of  5 	 with a query  23  is just finished.
# 14:34:02  - Combining OG 17039  with length of  3 	 with a query  15  is just finished.
# 14:34:02  - Combining OG 16188  with length of  5 	 with a query  18  is just finished.
# 14:34:02  - Combining OG 5874  with length of  5 	 with a query  17  is just finished.
# 14:34:02  - Combining OG 19037  with length of  5 	 with a query  15  is just finished.
# 14:34:02  - Combining OG 16720  with length of  5 	 with a query  24  is just finished.
# 14:34:02  - Combining OG 16032  with length of  5 	 with a query  25  is just finished.
# 14:34:02  - Combining OG 19161  with length of  5 	 with a query  24  is just finished.
# 14:34:02  - Combining OG 18098  with length of  5 	 with a query  24  is just finished.
# 14:34:02  - Combining OG 16912  with length of  5 	 with a query  24  is just finished.
# 14:34:02  - Combining OG 12219  with length of  5 	 with a query  24  is just finished.
# 14:34:02  - Combining OG 13364  with length of  5 	 with a query  21  is just finished.
# 14:34:02  - Combining OG 20274  with length of  5 	 with a query  22  is just finished.
# 14:34:02  - Combining OG 16542  with length of  5 	 with a query  25  is just finished.
# 14:34:02  - Combining OG 7085  with length of  5 	 with a query  24  is just finished.
# 14:34:02  - Combining OG 16850  with length of  5 	 with a query  23  is just finished.
# 14:34:02  - Combining OG 16828  with length of  5 	 with a query  23  is just finished.
# 14:34:02  - Combining OG 16909  with length of  5 	 with a query  23  is just finished.
# 14:34:02  - Combining OG 4921  with length of  5 	 with a query  19  is just finished.
# 14:34:02  - Combining OG 10861  with length of  5 	 with a query  19  is just finished.
# 14:34:02  - Combining OG 20543  with length of  3 	 with a query  23  is just finished.
# 14:34:02  - Combining OG 14780  with length of  5 	 with a query  22  is just finished.
# 14:34:02  - Combining OG 11804  with length of  5 	 with a query  18  is just finished.
# 14:34:02  - Combining OG 18586  with length of  5 	 with a query  24  is just finished.
# 14:34:02  - Combining OG 19169  with length of  5 	 with a query  19  is just finished.
# 14:34:02  - Combining OG 18538  with length of  5 	 with a query  25  is just finished.
# 14:34:02  - Combining OG 19293  with length of  5 	 with a query  23  is just finished.
# 14:34:02  - Combining OG 19029  with length of  5 	 with a query  22  is just finished.
# 14:34:02  - Combining OG 4553  with length of  5 	 with a query  18  is just finished.
# 14:34:02  - Combining OG 18099  with length of  5 	 with a query  22  is just finished.
# 14:34:02  - Combining OG 16717  with length of  3 	 with a query  16  is just finished.
# 14:34:02  - Combining OG 20222  with length of  5 	 with a query  20  is just finished.
# 14:34:02  - Combining OG 19756  with length of  5 	 with a query  24  is just finished.
# 14:34:02  - Combining OG 13838  with length of  5 	 with a query  17  is just finished.
# 14:34:02  - Combining OG 2328  with length of  5 	 with a query  19  is just finished.
# 14:34:02  - Combining OG 8190  with length of  5 	 with a query  24  is just finished.
# 14:34:02  - Combining OG 15295  with length of  5 	 with a query  25  is just finished.
# 14:34:02  - Combining OG 17029  with length of  3 	 with a query  22  is just finished.
# 14:34:02  - Combining OG 7393  with length of  5 	 with a query  24  is just finished.
# 14:34:02  - Combining OG 10040  with length of  5 	 with a query  21  is just finished.
# 14:34:02  - Combining OG 15564  with length of  5 	 with a query  22  is just finished.
# 14:34:02  - Combining OG 17920  with length of  5 	 with a query  17  is just finished.
# 14:34:02  - Combining OG 9617  with length of  5 	 with a query  15  is just finished.
# 14:34:02  - Combining OG 19144  with length of  5 	 with a query  18  is just finished.
# 14:34:02  - Combining OG 13713  with length of  5 	 with a query  24  is just finished.
# 14:34:02  - Combining OG 10206  with length of  5 	 with a query  18  is just finished.
# 14:34:02  - Combining OG 12922  with length of  5 	 with a query  22  is just finished.
# 14:34:02  - Combining OG 19508  with length of  5 	 with a query  24  is just finished.
# 14:34:02  - Combining OG 20423  with length of  5 	 with a query  25  is just finished.
# 14:34:02  - Combining OG 18208  with length of  5 	 with a query  22  is just finished.
# 14:34:02  - Combining OG 10839  with length of  5 	 with a query  21  is just finished.
# 14:34:02  - Combining OG 5112  with length of  4 	 with a query  18  is just finished.
# 14:34:02  - Combining OG 15809  with length of  4 	 with a query  20  is just finished.
# 14:34:02  - Combining OG 10940  with length of  5 	 with a query  21  is just finished.
# 14:34:02  - Combining OG 10073  with length of  4 	 with a query  18  is just finished.
# 14:34:02  - Combining OG 11605  with length of  5 	 with a query  22  is just finished.
# 14:34:02  - Combining OG 12015  with length of  5 	 with a query  25  is just finished.
# 14:34:02  - Combining OG 17538  with length of  5 	 with a query  25  is just finished.
# 14:34:02  - Combining OG 1183  with length of  5 	 with a query  22  is just finished.
# 14:34:02  - Combining OG 19096  with length of  5 	 with a query  17  is just finished.
# 14:34:02  - Combining OG 20002  with length of  5 	 with a query  24  is just finished.
# 14:34:02  - Combining OG 17747  with length of  5 	 with a query  25  is just finished.
# 14:34:02  - Combining OG 13154  with length of  5 	 with a query  15  is just finished.
# 14:34:02  - Combining OG 16603  with length of  5 	 with a query  20  is just finished.
# 14:34:02  - Combining OG 9059  with length of  5 	 with a query  22  is just finished.
# 14:34:02  - Combining OG 18762  with length of  5 	 with a query  23  is just finished.
# 14:34:02  - Combining OG 9348  with length of  5 	 with a query  15  is just finished.
# 14:34:02  - Combining OG 10178  with length of  5 	 with a query  19  is just finished.
# 14:34:02  - Combining OG 7977  with length of  5 	 with a query  25  is just finished.
# 14:34:02  - Combining OG 18469  with length of  5 	 with a query  16  is just finished.
# 14:34:02  - Combining OG 16967  with length of  5 	 with a query  24  is just finished.
# 14:34:02  - Combining OG 11993  with length of  5 	 with a query  25  is just finished.
# 14:34:02  - Combining OG 17045  with length of  5 	 with a query  25  is just finished.
# 14:34:02  - Combining OG 16425  with length of  5 	 with a query  21  is just finished.
# 14:34:02  - Combining OG 17447  with length of  5 	 with a query  25  is just finished.
# 14:34:02  - Combining OG 18498  with length of  5 	 with a query  17  is just finished.
# 14:34:02  - Combining OG 6676  with length of  5 	 with a query  23  is just finished.
# 14:34:02  - Combining OG 9777  with length of  5 	 with a query  25  is just finished.
# 14:34:02  - Combining OG 15795  with length of  5 	 with a query  24  is just finished.
# 14:34:02  - Combining OG 6264  with length of  5 	 with a query  22  is just finished.
# 14:34:02  - Combining OG 16270  with length of  5 	 with a query  25  is just finished.
# 14:34:02  - Combining OG 17124  with length of  5 	 with a query  24  is just finished.
# 14:34:02  - Combining OG 18459  with length of  5 	 with a query  20  is just finished.
# 14:34:02  - Combining OG 19878  with length of  3 	 with a query  22  is just finished.
# 14:34:02  - Combining OG 3940  with length of  5 	 with a query  16  is just finished.
# 14:34:02  - Combining OG 2305  with length of  5 	 with a query  25  is just finished.
# 14:34:02  - Combining OG 8874  with length of  5 	 with a query  15  is just finished.
# 14:34:02  - Combining OG 4451  with length of  5 	 with a query  19  is just finished.
# 14:34:02  - Combining OG 19191  with length of  5 	 with a query  23  is just finished.
# 14:34:02  - Combining OG 8503  with length of  5 	 with a query  25  is just finished.
# 14:34:02  - Combining OG 18234  with length of  5 	 with a query  25  is just finished.
# 14:34:02  - Combining OG 7768  with length of  5 	 with a query  20  is just finished.
# 14:34:02  - Combining OG 19229  with length of  5 	 with a query  22  is just finished.
# 14:34:02  - Combining OG 9358  with length of  5 	 with a query  25  is just finished.
# 14:34:02  - Combining OG 9709  with length of  5 	 with a query  19  is just finished.
# 14:34:02  - Combining OG 10043  with length of  5 	 with a query  19  is just finished.
# 14:34:02  - Combining OG 12332  with length of  5 	 with a query  24  is just finished.
# 14:34:02  - Combining OG 18494  with length of  5 	 with a query  22  is just finished.
# 14:34:02  - Combining OG 17557  with length of  5 	 with a query  24  is just finished.
# 14:34:02  - Combining OG 8752  with length of  5 	 with a query  16  is just finished.
# 14:34:02  - Combining OG 17468  with length of  5 	 with a query  25  is just finished.
# 14:34:02  - Combining OG 19539  with length of  4 	 with a query  20  is just finished.
# 14:34:02  - Combining OG 19154  with length of  4 	 with a query  17  is just finished.
# 14:34:02  - Combining OG 10493  with length of  5 	 with a query  19  is just finished.
# 14:34:02  - Combining OG 10323  with length of  5 	 with a query  20  is just finished.
# 14:34:02  - Combining OG 10424  with length of  5 	 with a query  17  is just finished.
# 14:34:02  - Combining OG 18871  with length of  4 	 with a query  17  is just finished.
# 14:34:02  - Combining OG 8338  with length of  5 	 with a query  25  is just finished.
# 14:34:02  - Combining OG 7722  with length of  5 	 with a query  20  is just finished.
# 14:34:02  - Combining OG 19876  with length of  5 	 with a query  20  is just finished.
# 14:34:02  - Combining OG 4535  with length of  4 	 with a query  16  is just finished.
# 14:34:02  - Combining OG 5895  with length of  5 	 with a query  17  is just finished.
# 14:34:02  - Combining OG 9556  with length of  5 	 with a query  17  is just finished.
# 14:34:02  - Combining OG 12003  with length of  5 	 with a query  23  is just finished.
# 14:34:02  - Combining OG 18362  with length of  2 	 with a query  19  is just finished.
# 14:34:02  - Combining OG 18652  with length of  4 	 with a query  19  is just finished.
# 14:34:02  - Combining OG 17989  with length of  5 	 with a query  25  is just finished.
# 14:34:02  - Combining OG 19114  with length of  4 	 with a query  25  is just finished.
# 14:34:02  - Combining OG 17859  with length of  5 	 with a query  25  is just finished.
# 14:34:02  - Combining OG 18421  with length of  5 	 with a query  25  is just finished.
# 14:34:02  - Combining OG 15535  with length of  5 	 with a query  19  is just finished.
# 14:34:02  - Combining OG 8450  with length of  3 	 with a query  15  is just finished.
# 14:34:02  - Combining OG 13913  with length of  5 	 with a query  15  is just finished.
# 14:34:02  - Combining OG 13460  with length of  4 	 with a query  22  is just finished.
# 14:34:02  - Combining OG 17271  with length of  5 	 with a query  24  is just finished.
# 14:34:02  - Combining OG 13322  with length of  5 	 with a query  22  is just finished.
# 14:34:02  - Combining OG 3401  with length of  4 	 with a query  19  is just finished.
# 14:34:02  - Combining OG 16992  with length of  5 	 with a query  24  is just finished.
# 14:34:02  - Combining OG 12175  with length of  5 	 with a query  15  is just finished.
# 14:34:02  - Combining OG 17206  with length of  5 	 with a query  18  is just finished.
# 14:34:02  - Combining OG 17072  with length of  5 	 with a query  19  is just finished.
# 14:34:02  - Combining OG 12928  with length of  5 	 with a query  22  is just finished.
# 14:34:02  - Combining OG 15250  with length of  4 	 with a query  23  is just finished.
# 14:34:02  - Combining OG 18143  with length of  5 	 with a query  22  is just finished.
# 14:34:02  - Combining OG 18391  with length of  5 	 with a query  16  is just finished.
# 14:34:02  - Combining OG 1755  with length of  5 	 with a query  18  is just finished.
# 14:34:02  - Combining OG 8223  with length of  4 	 with a query  20  is just finished.
# 14:34:02  - Combining OG 6414  with length of  3 	 with a query  17  is just finished.
# 14:34:02  - Combining OG 16332  with length of  5 	 with a query  25  is just finished.
# 14:34:02  - Combining OG 19431  with length of  5 	 with a query  23  is just finished.
# 14:34:02  - Combining OG 18496  with length of  5 	 with a query  16  is just finished.
# 14:34:02  - Combining OG 15435  with length of  5 	 with a query  24  is just finished.
# 14:34:02  - Combining OG 8517  with length of  5 	 with a query  24  is just finished.
# 14:34:02  - Combining OG 13175  with length of  5 	 with a query  18  is just finished.
# 14:34:02  - Combining OG 8440  with length of  5 	 with a query  24  is just finished.
# 14:34:02  - Combining OG 15520  with length of  5 	 with a query  15  is just finished.
# 14:34:02  - Combining OG 18638  with length of  5 	 with a query  23  is just finished.
# 14:34:02  - Combining OG 15033  with length of  5 	 with a query  22  is just finished.
# 14:34:02  - Combining OG 16932  with length of  5 	 with a query  22  is just finished.
# 14:34:02  - Combining OG 18753  with length of  5 	 with a query  22  is just finished.
# 14:34:02  - Combining OG 14844  with length of  5 	 with a query  20  is just finished.
# 14:34:02  - Combining OG 12089  with length of  5 	 with a query  24  is just finished.
# 14:34:02  - Combining OG 17591  with length of  5 	 with a query  24  is just finished.
# 14:34:02  - Combining OG 14790  with length of  5 	 with a query  23  is just finished.
# 14:34:02  - Combining OG 11471  with length of  3 	 with a query  23  is just finished.
# 14:34:02  - Combining OG 11868  with length of  3 	 with a query  24  is just finished.
# 14:34:02  - Combining OG 10036  with length of  5 	 with a query  15  is just finished.
# 14:34:02  - Combining OG 2503  with length of  5 	 with a query  20  is just finished.
# 14:34:02  - Combining OG 10462  with length of  5 	 with a query  21  is just finished.
# 14:34:02  - Combining OG 9436  with length of  4 	 with a query  20  is just finished.
# 14:34:02  - Combining OG 17322  with length of  5 	 with a query  21  is just finished.
# 14:34:02  - Combining OG 18311  with length of  5 	 with a query  19  is just finished.
# 14:34:02  - Combining OG 17314  with length of  5 	 with a query  15  is just finished.
# 14:34:02  - Combining OG 11833  with length of  5 	 with a query  15  is just finished.
# 14:34:02  - Combining OG 1987  with length of  5 	 with a query  19  is just finished.
# 14:34:02  - Combining OG 17004  with length of  5 	 with a query  25  is just finished.
# 14:34:02  - Combining OG 7077  with length of  5 	 with a query  17  is just finished.
# 14:34:02  - Combining OG 6197  with length of  5 	 with a query  21  is just finished.
# 14:34:02  - Combining OG 14362  with length of  5 	 with a query  21  is just finished.
# 14:34:03  - Combining OG 13811  with length of  5 	 with a query  20  is just finished.
# 14:34:03  - Combining OG 17967  with length of  5 	 with a query  24  is just finished.
# 14:34:03  - Combining OG 16656  with length of  5 	 with a query  22  is just finished.
# 14:34:03  - Combining OG 19355  with length of  5 	 with a query  25  is just finished.
# 14:34:03  - Combining OG 11569  with length of  5 	 with a query  18  is just finished.
# 14:34:03  - Combining OG 17998  with length of  5 	 with a query  25  is just finished.
# 14:34:03  - Combining OG 16412  with length of  5 	 with a query  25  is just finished.
# 14:34:03  - Combining OG 17610  with length of  5 	 with a query  24  is just finished.
# 14:34:03  - Combining OG 12521  with length of  5 	 with a query  18  is just finished.
# 14:34:03  - Combining OG 15613  with length of  5 	 with a query  19  is just finished.
# 14:34:03  - Combining OG 11301  with length of  5 	 with a query  17  is just finished.
# 14:34:03  - Combining OG 14117  with length of  5 	 with a query  24  is just finished.
# 14:34:03  - Combining OG 9099  with length of  5 	 with a query  21  is just finished.
# 14:34:03  - Combining OG 19835  with length of  3 	 with a query  16  is just finished.
# 14:34:03  - Combining OG 11996  with length of  4 	 with a query  18  is just finished.
# 14:34:03  - Combining OG 12646  with length of  5 	 with a query  17  is just finished.
# 14:34:03  - Combining OG 18153  with length of  5 	 with a query  23  is just finished.
# 14:34:03  - Combining OG 13162  with length of  5 	 with a query  23  is just finished.
# 14:34:03  - Combining OG 1335  with length of  5 	 with a query  20  is just finished.
# 14:34:03  - Combining OG 20241  with length of  5 	 with a query  24  is just finished.
# 14:34:03  - Combining OG 6166  with length of  5 	 with a query  22  is just finished.
# 14:34:03  - Combining OG 18734  with length of  5 	 with a query  25  is just finished.
# 14:34:03  - Combining OG 19386  with length of  5 	 with a query  23  is just finished.
# 14:34:03  - Combining OG 18909  with length of  5 	 with a query  22  is just finished.
# 14:34:03  - Combining OG 17913  with length of  5 	 with a query  24  is just finished.
# 14:34:03  - Combining OG 5841  with length of  5 	 with a query  23  is just finished.
# 14:34:03  - Combining OG 12356  with length of  5 	 with a query  24  is just finished.
# 14:34:03  - Combining OG 17693  with length of  5 	 with a query  22  is just finished.
# 14:34:03  - Combining OG 13842  with length of  5 	 with a query  18  is just finished.
# 14:34:03  - Combining OG 10744  with length of  3 	 with a query  15  is just finished.
# 14:34:03  - Combining OG 10294  with length of  5 	 with a query  24  is just finished.
# 14:34:03  - Combining OG 20144  with length of  5 	 with a query  21  is just finished.
# 14:34:03  - Combining OG 20297  with length of  5 	 with a query  19  is just finished.
# 14:34:03  - Combining OG 15372  with length of  5 	 with a query  24  is just finished.
# 14:34:03  - Combining OG 16120  with length of  5 	 with a query  16  is just finished.
# 14:34:03  - Combining OG 9969  with length of  5 	 with a query  24  is just finished.
# 14:34:03  - Combining OG 19119  with length of  5 	 with a query  20  is just finished.
# 14:34:03  - Combining OG 15474  with length of  5 	 with a query  19  is just finished.
# 14:34:03  - Combining OG 20117  with length of  5 	 with a query  22  is just finished.
# 14:34:03  - Combining OG 14881  with length of  5 	 with a query  24  is just finished.
# 14:34:03  - Combining OG 19772  with length of  5 	 with a query  23  is just finished.
# 14:34:03  - Combining OG 18497  with length of  4 	 with a query  19  is just finished.
# 14:34:03  - Combining OG 18352  with length of  5 	 with a query  18  is just finished.
# 14:34:03  - Combining OG 17957  with length of  5 	 with a query  22  is just finished.
# 14:34:03  - Combining OG 18416  with length of  5 	 with a query  24  is just finished.
# 14:34:03  - Combining OG 18243  with length of  5 	 with a query  23  is just finished.
# 14:34:03  - Combining OG 17564  with length of  5 	 with a query  25  is just finished.
# 14:34:03  - Combining OG 16950  with length of  5 	 with a query  18  is just finished.
# 14:34:03  - Combining OG 17705  with length of  4 	 with a query  18  is just finished.
# 14:34:03  - Combining OG 2534  with length of  5 	 with a query  16  is just finished.
# 14:34:03  - Combining OG 14779  with length of  3 	 with a query  17  is just finished.
# 14:34:03  - Combining OG 4472  with length of  5 	 with a query  25  is just finished.
# 14:34:03  - Combining OG 18774  with length of  5 	 with a query  25  is just finished.
# 14:34:03  - Combining OG 15523  with length of  5 	 with a query  21  is just finished.
# 14:34:03  - Combining OG 9156  with length of  5 	 with a query  20  is just finished.
# 14:34:03  - Combining OG 17051  with length of  5 	 with a query  23  is just finished.
# 14:34:03  - Combining OG 9662  with length of  5 	 with a query  19  is just finished.
# 14:34:03  - Combining OG 19333  with length of  5 	 with a query  16  is just finished.
# 14:34:03  - Combining OG 15324  with length of  4 	 with a query  24  is just finished.
# 14:34:03  - Combining OG 15854  with length of  5 	 with a query  24  is just finished.
# 14:34:03  - Combining OG 15643  with length of  4 	 with a query  18  is just finished.
# 14:34:03  - Combining OG 9189  with length of  5 	 with a query  23  is just finished.
# 14:34:03  - Combining OG 4780  with length of  5 	 with a query  22  is just finished.
# 14:34:03  - Combining OG 7324  with length of  5 	 with a query  23  is just finished.
# 14:34:03  - Combining OG 10805  with length of  5 	 with a query  25  is just finished.
# 14:34:03  - Combining OG 7797  with length of  5 	 with a query  18  is just finished.
# 14:34:03  - Combining OG 12249  with length of  5 	 with a query  24  is just finished.
# 14:34:03  - Combining OG 18401  with length of  5 	 with a query  19  is just finished.
# 14:34:03  - Combining OG 15766  with length of  5 	 with a query  20  is just finished.
# 14:34:03  - Combining OG 5936  with length of  3 	 with a query  17  is just finished.
# 14:34:03  - Combining OG 18176  with length of  5 	 with a query  24  is just finished.
# 14:34:03  - Combining OG 11777  with length of  5 	 with a query  16  is just finished.
# 14:34:03  - Combining OG 5167  with length of  5 	 with a query  20  is just finished.
# 14:34:03  - Combining OG 14079  with length of  5 	 with a query  25  is just finished.
# 14:34:03  - Combining OG 9613  with length of  5 	 with a query  25  is just finished.
# 14:34:03  - Combining OG 6583  with length of  5 	 with a query  19  is just finished.
# 14:34:03  - Combining OG 9272  with length of  5 	 with a query  24  is just finished.
# 14:34:03  - Combining OG 19775  with length of  4 	 with a query  17  is just finished.
# 14:34:03  - Combining OG 14903  with length of  5 	 with a query  17  is just finished.
# 14:34:03  - Combining OG 18385  with length of  5 	 with a query  22  is just finished.
# 14:34:03  - Combining OG 8690  with length of  5 	 with a query  17  is just finished.
# 14:34:03  - Combining OG 17877  with length of  5 	 with a query  24  is just finished.
# 14:34:03  - Combining OG 14035  with length of  5 	 with a query  24  is just finished.
# 14:34:03  - Combining OG 5886  with length of  5 	 with a query  19  is just finished.
# 14:34:03  - Combining OG 3638  with length of  5 	 with a query  17  is just finished.
# 14:34:03  - Combining OG 12531  with length of  4 	 with a query  22  is just finished.
# 14:34:03  - Combining OG 12307  with length of  4 	 with a query  15  is just finished.
# 14:34:03  - Combining OG 17189  with length of  5 	 with a query  16  is just finished.
# 14:34:03  - Combining OG 2597  with length of  5 	 with a query  20  is just finished.
# 14:34:03  - Combining OG 13306  with length of  5 	 with a query  17  is just finished.
# 14:34:03  - Combining OG 13997  with length of  5 	 with a query  20  is just finished.
# 14:34:03  - Combining OG 11631  with length of  5 	 with a query  18  is just finished.
# 14:34:03  - Combining OG 12360  with length of  4 	 with a query  15  is just finished.
# 14:34:03  - Combining OG 18945  with length of  3 	 with a query  16  is just finished.
# 14:34:03  - Combining OG 17821  with length of  5 	 with a query  19  is just finished.
# 14:34:03  - Combining OG 13750  with length of  5 	 with a query  15  is just finished.
# 14:34:03  - Combining OG 12715  with length of  5 	 with a query  15  is just finished.
# 14:34:03  - Combining OG 2354  with length of  5 	 with a query  24  is just finished.
# 14:34:03  - Combining OG 6306  with length of  5 	 with a query  22  is just finished.
# 14:34:03  - Combining OG 11414  with length of  5 	 with a query  21  is just finished.
# 14:34:03  - Combining OG 4725  with length of  5 	 with a query  18  is just finished.
# 14:34:03  - Combining OG 4945  with length of  5 	 with a query  15  is just finished.
# 14:34:03  - Combining OG 18418  with length of  4 	 with a query  17  is just finished.
# 14:34:03  - Combining OG 16269  with length of  5 	 with a query  25  is just finished.
# 14:34:03  - Combining OG 19117  with length of  5 	 with a query  17  is just finished.
# 14:34:03  - Combining OG 20672  with length of  2 	 with a query  16  is just finished.
# 14:34:03  - Combining OG 20812  with length of  3 	 with a query  15  is just finished.
# 14:34:03  - Combining OG 12713  with length of  5 	 with a query  19  is just finished.
# 14:34:03  - Combining OG 16937  with length of  5 	 with a query  23  is just finished.
# 14:34:03  - Combining OG 13242  with length of  5 	 with a query  19  is just finished.
# 14:34:03  - Combining OG 17722  with length of  4 	 with a query  17  is just finished.
# 14:34:03  - Combining OG 13559  with length of  5 	 with a query  16  is just finished.
# 14:34:03  - Combining OG 17777  with length of  4 	 with a query  20  is just finished.
# 14:34:03  - Combining OG 7756  with length of  5 	 with a query  21  is just finished.
# 14:34:03  - Combining OG 11767  with length of  5 	 with a query  17  is just finished.
# 14:34:03  - Combining OG 15665  with length of  5 	 with a query  23  is just finished.
# 14:34:03  - Combining OG 7781  with length of  5 	 with a query  15  is just finished.
# 14:34:03  - Combining OG 13911  with length of  5 	 with a query  23  is just finished.
# 14:34:03  - Combining OG 12665  with length of  5 	 with a query  23  is just finished.
# 14:34:03  - Combining OG 11604  with length of  5 	 with a query  20  is just finished.
# 14:34:03  - Combining OG 2209  with length of  4 	 with a query  16  is just finished.
# 14:34:03  - Combining OG 411  with length of  5 	 with a query  17  is just finished.
# 14:34:03  - Combining OG 1152  with length of  5 	 with a query  19  is just finished.
# 14:34:03  - Combining OG 16024  with length of  5 	 with a query  24  is just finished.
# 14:34:03  - Combining OG 18460  with length of  5 	 with a query  25  is just finished.
# 14:34:03  - Combining OG 17818  with length of  5 	 with a query  24  is just finished.
# 14:34:03  - Combining OG 8873  with length of  5 	 with a query  19  is just finished.
# 14:34:03  - Combining OG 5291  with length of  5 	 with a query  20  is just finished.
# 14:34:03  - Combining OG 17080  with length of  5 	 with a query  20  is just finished.
# 14:34:03  - Combining OG 5988  with length of  5 	 with a query  22  is just finished.
# 14:34:03  - Combining OG 18084  with length of  5 	 with a query  19  is just finished.
# 14:34:03  - Combining OG 9750  with length of  5 	 with a query  19  is just finished.
# 14:34:03  - Combining OG 18226  with length of  5 	 with a query  20  is just finished.
# 14:34:03  - Combining OG 10177  with length of  3 	 with a query  19  is just finished.
# 14:34:03  - Combining OG 18661  with length of  4 	 with a query  23  is just finished.
# 14:34:03  - Combining OG 17931  with length of  5 	 with a query  22  is just finished.
# 14:34:03  - Combining OG 4808  with length of  5 	 with a query  19  is just finished.
# 14:34:03  - Combining OG 12474  with length of  4 	 with a query  21  is just finished.
# 14:34:03  - Combining OG 13780  with length of  4 	 with a query  17  is just finished.
# 14:34:03  - Combining OG 7893  with length of  5 	 with a query  20  is just finished.
# 14:34:03  - Combining OG 14887  with length of  5 	 with a query  23  is just finished.
# 14:34:03  - Combining OG 2591  with length of  5 	 with a query  18  is just finished.
# 14:34:03  - Combining OG 11348  with length of  5 	 with a query  19  is just finished.
# 14:34:03  - Combining OG 3431  with length of  5 	 with a query  19  is just finished.
# 14:34:03  - Combining OG 19380  with length of  5 	 with a query  25  is just finished.
# 14:34:03  - Combining OG 12096  with length of  5 	 with a query  19  is just finished.
# 14:34:03  - Combining OG 10348  with length of  5 	 with a query  21  is just finished.
# 14:34:03  - Combining OG 12147  with length of  5 	 with a query  19  is just finished.
# 14:34:03  - Combining OG 20544  with length of  5 	 with a query  23  is just finished.
# 14:34:03  - Combining OG 12330  with length of  5 	 with a query  20  is just finished.
# 14:34:03  - Combining OG 15418  with length of  5 	 with a query  24  is just finished.
# 14:34:03  - Combining OG 17505  with length of  5 	 with a query  24  is just finished.
# 14:34:03  - Combining OG 11816  with length of  5 	 with a query  18  is just finished.
# 14:34:03  - Combining OG 3975  with length of  5 	 with a query  19  is just finished.
# 14:34:03  - Combining OG 19125  with length of  4 	 with a query  16  is just finished.
# 14:34:03  - Combining OG 8961  with length of  5 	 with a query  19  is just finished.
# 14:34:03  - Combining OG 18778  with length of  5 	 with a query  23  is just finished.
# 14:34:03  - Combining OG 18369  with length of  5 	 with a query  15  is just finished.
# 14:34:03  - Combining OG 18963  with length of  5 	 with a query  18  is just finished.
# 14:34:03  - Combining OG 12296  with length of  5 	 with a query  23  is just finished.
# 14:34:03  - Combining OG 11976  with length of  5 	 with a query  19  is just finished.
# 14:34:03  - Combining OG 8197  with length of  5 	 with a query  18  is just finished.
# 14:34:03  - Combining OG 10776  with length of  4 	 with a query  15  is just finished.
# 14:34:03  - Combining OG 15874  with length of  5 	 with a query  20  is just finished.
# 14:34:03  - Combining OG 19261  with length of  5 	 with a query  23  is just finished.
# 14:34:03  - Combining OG 7891  with length of  5 	 with a query  25  is just finished.
# 14:34:03  - Combining OG 19441  with length of  5 	 with a query  24  is just finished.
# 14:34:03  - Combining OG 6342  with length of  5 	 with a query  18  is just finished.
# 14:34:03  - Combining OG 18206  with length of  5 	 with a query  23  is just finished.
# 14:34:03  - Combining OG 20399  with length of  5 	 with a query  22  is just finished.
# 14:34:03  - Combining OG 17476  with length of  5 	 with a query  20  is just finished.
# 14:34:03  - Combining OG 18609  with length of  3 	 with a query  17  is just finished.
# 14:34:03  - Combining OG 16830  with length of  5 	 with a query  22  is just finished.
# 14:34:03  - Combining OG 19902  with length of  3 	 with a query  17  is just finished.
# 14:34:03  - Combining OG 17510  with length of  5 	 with a query  19  is just finished.
# 14:34:03  - Combining OG 5882  with length of  5 	 with a query  20  is just finished.
# 14:34:03  - Combining OG 18101  with length of  4 	 with a query  18  is just finished.
# 14:34:03  - Combining OG 17905  with length of  4 	 with a query  17  is just finished.
# 14:34:03  - Combining OG 11248  with length of  5 	 with a query  18  is just finished.
# 14:34:03  - Combining OG 18381  with length of  5 	 with a query  25  is just finished.
# 14:34:03  - Combining OG 16974  with length of  5 	 with a query  19  is just finished.
# 14:34:03  - Combining OG 10756  with length of  5 	 with a query  23  is just finished.
# 14:34:03  - Combining OG 9190  with length of  5 	 with a query  16  is just finished.
# 14:34:03  - Combining OG 7897  with length of  3 	 with a query  17  is just finished.
# 14:34:03  - Combining OG 6471  with length of  4 	 with a query  17  is just finished.
# 14:34:03  - Combining OG 17060  with length of  5 	 with a query  24  is just finished.
# 14:34:03  - Combining OG 7537  with length of  3 	 with a query  20  is just finished.
# 14:34:03  - Combining OG 16574  with length of  3 	 with a query  19  is just finished.
# 14:34:03  - Combining OG 8435  with length of  3 	 with a query  20  is just finished.
# 14:34:03  - Combining OG 6244  with length of  3 	 with a query  15  is just finished.
# 14:34:03  - Combining OG 4080  with length of  4 	 with a query  19  is just finished.
# 14:34:03  - Combining OG 7356  with length of  3 	 with a query  20  is just finished.
# 14:34:03  - Combining OG 15803  with length of  5 	 with a query  22  is just finished.
# 14:34:03  - Combining OG 19294  with length of  5 	 with a query  22  is just finished.
# 14:34:03  - Combining OG 8180  with length of  5 	 with a query  25  is just finished.
# 14:34:03  - Combining OG 14829  with length of  5 	 with a query  18  is just finished.
# 14:34:03  - Combining OG 19014  with length of  4 	 with a query  23  is just finished.
# 14:34:03  - Combining OG 9851  with length of  5 	 with a query  16  is just finished.
# 14:34:03  - Combining OG 4508  with length of  3 	 with a query  18  is just finished.
# 14:34:03  - Combining OG 19304  with length of  5 	 with a query  25  is just finished.
# 14:34:03  - Combining OG 19968  with length of  5 	 with a query  19  is just finished.
# 14:34:03  - Combining OG 18786  with length of  5 	 with a query  23  is just finished.
# 14:34:03  - Combining OG 9891  with length of  5 	 with a query  22  is just finished.
# 14:34:03  - Combining OG 19980  with length of  5 	 with a query  24  is just finished.
# 14:34:03  - Combining OG 13669  with length of  5 	 with a query  19  is just finished.
# 14:34:03  - Combining OG 18690  with length of  5 	 with a query  24  is just finished.
# 14:34:03  - Combining OG 19178  with length of  5 	 with a query  20  is just finished.
# 14:34:03  - Combining OG 16253  with length of  5 	 with a query  21  is just finished.
# 14:34:03  - Combining OG 20249  with length of  4 	 with a query  19  is just finished.
# 14:34:03  - Combining OG 16448  with length of  5 	 with a query  24  is just finished.
# 14:34:03  - Combining OG 17531  with length of  5 	 with a query  19  is just finished.
# 14:34:03  - Combining OG 17636  with length of  5 	 with a query  17  is just finished.
# 14:34:03  - Combining OG 8267  with length of  4 	 with a query  19  is just finished.
# 14:34:03  - Combining OG 7545  with length of  5 	 with a query  20  is just finished.
# 14:34:03  - Combining OG 12590  with length of  4 	 with a query  18  is just finished.
# 14:34:03  - Combining OG 12849  with length of  5 	 with a query  18  is just finished.
# 14:34:03  - Combining OG 2816  with length of  5 	 with a query  17  is just finished.
# 14:34:03  - Combining OG 4329  with length of  5 	 with a query  23  is just finished.
# 14:34:03  - Combining OG 18630  with length of  5 	 with a query  25  is just finished.
# 14:34:03  - Combining OG 17977  with length of  5 	 with a query  15  is just finished.
# 14:34:03  - Combining OG 12653  with length of  5 	 with a query  19  is just finished.
# 14:34:03  - Combining OG 20433  with length of  4 	 with a query  20  is just finished.
# 14:34:03  - Combining OG 20340  with length of  3 	 with a query  24  is just finished.
# 14:34:03  - Combining OG 19837  with length of  5 	 with a query  23  is just finished.
# 14:34:03  - Combining OG 1923  with length of  5 	 with a query  24  is just finished.
# 14:34:03  - Combining OG 10352  with length of  4 	 with a query  15  is just finished.
# 14:34:03  - Combining OG 7698  with length of  5 	 with a query  24  is just finished.
# 14:34:03  - Combining OG 18156  with length of  5 	 with a query  20  is just finished.
# 14:34:03  - Combining OG 12281  with length of  5 	 with a query  17  is just finished.
# 14:34:03  - Combining OG 11392  with length of  5 	 with a query  24  is just finished.
# 14:34:03  - Combining OG 17454  with length of  5 	 with a query  23  is just finished.
# 14:34:03  - Combining OG 18598  with length of  4 	 with a query  17  is just finished.
# 14:34:03  - Combining OG 15233  with length of  5 	 with a query  15  is just finished.
# 14:34:03  - Combining OG 15370  with length of  5 	 with a query  16  is just finished.
# 14:34:03  - Combining OG 16411  with length of  5 	 with a query  21  is just finished.
# 14:34:03  - Combining OG 11974  with length of  5 	 with a query  18  is just finished.
# 14:34:03  - Combining OG 16857  with length of  5 	 with a query  22  is just finished.
# 14:34:03  - Combining OG 12936  with length of  5 	 with a query  24  is just finished.
# 14:34:03  - Combining OG 16685  with length of  5 	 with a query  24  is just finished.
# 14:34:03  - Combining OG 19618  with length of  5 	 with a query  15  is just finished.
# 14:34:03  - Combining OG 20031  with length of  4 	 with a query  24  is just finished.
# 14:34:03  - Combining OG 8902  with length of  5 	 with a query  24  is just finished.
# 14:34:03  - Combining OG 3039  with length of  5 	 with a query  22  is just finished.
# 14:34:03  - Combining OG 10689  with length of  4 	 with a query  15  is just finished.
# 14:34:03  - Combining OG 13888  with length of  5 	 with a query  24  is just finished.
# 14:34:03  - Combining OG 9485  with length of  5 	 with a query  22  is just finished.
# 14:34:03  - Combining OG 12284  with length of  5 	 with a query  17  is just finished.
# 14:34:03  - Combining OG 11230  with length of  5 	 with a query  18  is just finished.
# 14:34:03  - Combining OG 16402  with length of  5 	 with a query  17  is just finished.
# 14:34:03  - Combining OG 7036  with length of  5 	 with a query  24  is just finished.
# 14:34:03  - Combining OG 18166  with length of  5 	 with a query  18  is just finished.
# 14:34:03  - Combining OG 15917  with length of  5 	 with a query  25  is just finished.
# 14:34:03  - Combining OG 5906  with length of  5 	 with a query  20  is just finished.
# 14:34:03  - Combining OG 6538  with length of  4 	 with a query  22  is just finished.
# 14:34:03  - Combining OG 15162  with length of  5 	 with a query  17  is just finished.
# 14:34:03  - Combining OG 17573  with length of  5 	 with a query  24  is just finished.
# 14:34:03  - Combining OG 6529  with length of  5 	 with a query  15  is just finished.
# 14:34:03  - Combining OG 7454  with length of  5 	 with a query  25  is just finished.
# 14:34:03  - Combining OG 10895  with length of  5 	 with a query  24  is just finished.
# 14:34:03  - Combining OG 6326  with length of  5 	 with a query  15  is just finished.
# 14:34:03  - Combining OG 11291  with length of  5 	 with a query  18  is just finished.
# 14:34:03  - Combining OG 19299  with length of  5 	 with a query  23  is just finished.
# 14:34:03  - Combining OG 18417  with length of  5 	 with a query  24  is just finished.
# 14:34:03  - Combining OG 6431  with length of  5 	 with a query  18  is just finished.
# 14:34:03  - Combining OG 8594  with length of  5 	 with a query  24  is just finished.
# 14:34:03  - Combining OG 16789  with length of  5 	 with a query  20  is just finished.
# 14:34:03  - Combining OG 17202  with length of  5 	 with a query  24  is just finished.
# 14:34:03  - Combining OG 18194  with length of  4 	 with a query  19  is just finished.
# 14:34:03  - Combining OG 13202  with length of  5 	 with a query  25  is just finished.
# 14:34:03  - Combining OG 18197  with length of  5 	 with a query  25  is just finished.
# 14:34:03  - Combining OG 2746  with length of  5 	 with a query  22  is just finished.
# 14:34:03  - Combining OG 9956  with length of  3 	 with a query  17  is just finished.
# 14:34:03  - Combining OG 12134  with length of  4 	 with a query  17  is just finished.
# 14:34:03  - Combining OG 8015  with length of  5 	 with a query  24  is just finished.
# 14:34:03  - Combining OG 14776  with length of  5 	 with a query  19  is just finished.
# 14:34:03  - Combining OG 4034  with length of  4 	 with a query  16  is just finished.
# 14:34:03  - Combining OG 4039  with length of  4 	 with a query  18  is just finished.
# 14:34:03  - Combining OG 15814  with length of  5 	 with a query  24  is just finished.
# 14:34:03  - Combining OG 8152  with length of  4 	 with a query  17  is just finished.
# 14:34:03  - Combining OG 18892  with length of  5 	 with a query  25  is just finished.
# ...
# 14:34:04  - Combining OG 7622  with length of  5 	 with a query  20  is just finished.
# 14:34:04  - Combining OG 13159  with length of  5 	 with a query  19  is just finished.
# 14:34:04  - Combining OG 5803  with length of  5 	 with a query  24  is just finished.
# 14:34:04  - Combining OG 13105  with length of  4 	 with a query  15  is just finished.
# 14:34:04  - Combining OG 12246  with length of  5 	 with a query  16  is just finished.
# 14:34:04  - Combining OG 13093  with length of  5 	 with a query  24  is just finished.
# 14:34:04  - Combining OG 15678  with length of  5 	 with a query  23  is just finished.
# 14:34:04  - Combining OG 16636  with length of  2 	 with a query  24  is just finished.
# 14:34:04  - Combining OG 17079  with length of  5 	 with a query  24  is just finished.
# 14:34:04  - Combining OG 5502  with length of  5 	 with a query  20  is just finished.
# 14:34:04  - Combining OG 14226  with length of  5 	 with a query  16  is just finished.
# 14:34:04  - Combining OG 12844  with length of  4 	 with a query  20  is just finished.
# 14:34:04  - Combining OG 16395  with length of  5 	 with a query  19  is just finished.
# 14:34:04  - Combining OG 9067  with length of  5 	 with a query  17  is just finished.
# 14:34:04  - Combining OG 9369  with length of  5 	 with a query  17  is just finished.
# 14:34:04  - Combining OG 5268  with length of  4 	 with a query  18  is just finished.
# 14:34:04  - Combining OG 4559  with length of  5 	 with a query  23  is just finished.
# 14:34:04  - Combining OG 15598  with length of  5 	 with a query  22  is just finished.
# 14:34:04  - Combining OG 16036  with length of  5 	 with a query  22  is just finished.
# 14:34:04  - Combining OG 9381  with length of  5 	 with a query  25  is just finished.
# 14:34:04  - Combining OG 19471  with length of  4 	 with a query  17  is just finished.
# 14:34:04  - Combining OG 15552  with length of  5 	 with a query  16  is just finished.
# 14:34:04  - Combining OG 19670  with length of  5 	 with a query  21  is just finished.
# 14:34:04  - Combining OG 12119  with length of  5 	 with a query  17  is just finished.
# 14:34:04  - Combining OG 470  with length of  5 	 with a query  16  is just finished.
# 14:34:04  - Combining OG 19384  with length of  5 	 with a query  21  is just finished.
# 14:34:04  - Combining OG 9914  with length of  5 	 with a query  21  is just finished.
# 14:34:04  - Combining OG 11839  with length of  5 	 with a query  16  is just finished.
# 14:34:04  - Combining OG 15655  with length of  5 	 with a query  19  is just finished.
# 14:34:04  - Combining OG 6664  with length of  4 	 with a query  18  is just finished.
# 14:34:04  - Combining OG 6375  with length of  5 	 with a query  16  is just finished.
# 14:34:04  - Combining OG 12776  with length of  4 	 with a query  15  is just finished.
# 14:34:04  - Combining OG 15325  with length of  5 	 with a query  18  is just finished.
# 14:34:04  - Combining OG 7589  with length of  5 	 with a query  16  is just finished.
# 14:34:04  - Combining OG 7740  with length of  4 	 with a query  21  is just finished.
# 14:34:04  - Combining OG 7497  with length of  5 	 with a query  24  is just finished.
# 14:34:04  - Combining OG 1333  with length of  5 	 with a query  24  is just finished.
# 14:34:04  - Combining OG 4396  with length of  5 	 with a query  16  is just finished.
# 14:34:04  - Combining OG 10067  with length of  4 	 with a query  19  is just finished.
# 14:34:04  - Combining OG 5427  with length of  5 	 with a query  22  is just finished.
# 14:34:04  - Combining OG 11293  with length of  5 	 with a query  19  is just finished.
# 14:34:04  - Combining OG 10290  with length of  5 	 with a query  24  is just finished.
# 14:34:04  - Combining OG 16632  with length of  2 	 with a query  15  is just finished.
# 14:34:04  - Combining OG 18408  with length of  4 	 with a query  16  is just finished.
# 14:34:04  - Combining OG 14806  with length of  3 	 with a query  16  is just finished.
# 14:34:04  - Combining OG 13237  with length of  3 	 with a query  16  is just finished.
# 14:34:04  - Combining OG 14122  with length of  5 	 with a query  15  is just finished.
# 14:34:04  - Combining OG 11343  with length of  3 	 with a query  16  is just finished.
# 14:34:04  - Combining OG 9660  with length of  3 	 with a query  16  is just finished.
# 14:34:04  - Combining OG 7390  with length of  5 	 with a query  22  is just finished.
# 14:34:04  - Combining OG 13629  with length of  5 	 with a query  24  is just finished.
# 14:34:04  - Combining OG 15230  with length of  5 	 with a query  19  is just finished.
# 14:34:04  - Combining OG 17035  with length of  5 	 with a query  24  is just finished.
# 14:34:04  - Combining OG 16157  with length of  5 	 with a query  23  is just finished.
# 14:34:04  - Combining OG 9609  with length of  5 	 with a query  22  is just finished.
# 14:34:04  - Combining OG 6050  with length of  5 	 with a query  25  is just finished.
# 14:34:04  - Combining OG 15398  with length of  5 	 with a query  15  is just finished.
# 14:34:04  - Combining OG 18549  with length of  5 	 with a query  17  is just finished.
# 14:34:04  - Combining OG 16056  with length of  4 	 with a query  16  is just finished.
# 14:34:04  - Combining OG 18723  with length of  5 	 with a query  20  is just finished.
# 14:34:04  - Combining OG 8444  with length of  5 	 with a query  16  is just finished.
# 14:34:04  - Combining OG 6255  with length of  5 	 with a query  19  is just finished.
# 14:34:04  - Combining OG 3693  with length of  4 	 with a query  18  is just finished.
# 14:34:04  - Combining OG 6729  with length of  2 	 with a query  19  is just finished.
# 14:34:04  - Combining OG 14826  with length of  5 	 with a query  19  is just finished.
# 14:34:04  - Combining OG 16446  with length of  4 	 with a query  16  is just finished.
# 14:34:04  - Combining OG 8172  with length of  4 	 with a query  24  is just finished.
# 14:34:04  - Combining OG 14832  with length of  3 	 with a query  21  is just finished.
# 14:34:04  - Combining OG 19702  with length of  5 	 with a query  16  is just finished.
# 14:34:04  - Combining OG 10768  with length of  5 	 with a query  18  is just finished.
# 14:34:04  - Combining OG 19689  with length of  4 	 with a query  19  is just finished.
# 14:34:04  - Combining OG 6420  with length of  5 	 with a query  21  is just finished.
# 14:34:04  - Combining OG 13052  with length of  5 	 with a query  24  is just finished.
# 14:34:04  - Combining OG 1215  with length of  5 	 with a query  19  is just finished.
# 14:34:04  - Combining OG 6053  with length of  3 	 with a query  21  is just finished.
# 14:34:04  - Combining OG 20136  with length of  5 	 with a query  21  is just finished.
# 14:34:04  - Combining OG 10830  with length of  2 	 with a query  15  is just finished.
# 14:34:04  - Combining OG 11823  with length of  2 	 with a query  16  is just finished.
# 14:34:04  - Combining OG 9253  with length of  3 	 with a query  15  is just finished.
# 14:34:04  - Combining OG 5378  with length of  4 	 with a query  17  is just finished.
# 14:34:04  - Combining OG 5189  with length of  3 	 with a query  21  is just finished.
# 14:34:04  - Combining OG 11323  with length of  5 	 with a query  19  is just finished.
# 14:34:04  - Combining OG 12568  with length of  5 	 with a query  15  is just finished.
# 14:34:04  - Combining OG 9922  with length of  5 	 with a query  19  is just finished.
# 14:34:04  - Combining OG 17962  with length of  5 	 with a query  19  is just finished.
# 14:34:04  - Combining OG 8364  with length of  5 	 with a query  17  is just finished.
# 14:34:04  - Combining OG 19982  with length of  5 	 with a query  20  is just finished.
# 14:34:04  - Combining OG 18290  with length of  5 	 with a query  17  is just finished.
# 14:34:04  - Combining OG 14995  with length of  5 	 with a query  19  is just finished.
# 14:34:04  - Combining OG 18809  with length of  5 	 with a query  21  is just finished.
# 14:34:04  - Combining OG 10925  with length of  5 	 with a query  19  is just finished.
# 14:34:04  - Combining OG 18748  with length of  4 	 with a query  16  is just finished.
# 14:34:04  - Combining OG 20214  with length of  5 	 with a query  21  is just finished.
# 14:34:04  - Combining OG 20938  with length of  3 	 with a query  16  is just finished.
# 14:34:04  - Combining OG 16892  with length of  5 	 with a query  17  is just finished.
# 14:34:04  - Combining OG 17400  with length of  5 	 with a query  15  is just finished.
# 14:34:04  - Combining OG 17214  with length of  5 	 with a query  21  is just finished.
# 14:34:04  - Combining OG 3475  with length of  5 	 with a query  19  is just finished.
# 14:34:04  - Combining OG 11034  with length of  5 	 with a query  23  is just finished.
# 14:34:04  - Combining OG 19796  with length of  5 	 with a query  17  is just finished.
# 14:34:04  - Combining OG 13903  with length of  4 	 with a query  16  is just finished.
# 14:34:04  - Combining OG 14888  with length of  5 	 with a query  23  is just finished.
# 14:34:04  - Combining OG 18544  with length of  3 	 with a query  17  is just finished.
# 14:34:04  - Combining OG 841  with length of  5 	 with a query  16  is just finished.
# 14:34:04  - Combining OG 7917  with length of  5 	 with a query  19  is just finished.
# 14:34:04  - Combining OG 18925  with length of  5 	 with a query  19  is just finished.
# 14:34:04  - Combining OG 3885  with length of  5 	 with a query  16  is just finished.
# 14:34:04  - Combining OG 5105  with length of  5 	 with a query  16  is just finished.
# 14:34:04  - Combining OG 11962  with length of  3 	 with a query  21  is just finished.
# 14:34:04  - Combining OG 5733  with length of  5 	 with a query  19  is just finished.
# 14:34:04  - Combining OG 15169  with length of  5 	 with a query  23  is just finished.
# 14:34:04  - Combining OG 13658  with length of  5 	 with a query  23  is just finished.
# 14:34:04  - Combining OG 16661  with length of  5 	 with a query  15  is just finished.
# 14:34:04  - Combining OG 10031  with length of  5 	 with a query  16  is just finished.
# 14:34:04  - Combining OG 12815  with length of  5 	 with a query  16  is just finished.
# 14:34:04  - Combining OG 18651  with length of  5 	 with a query  17  is just finished.
# 14:34:04  - Combining OG 12541  with length of  5 	 with a query  18  is just finished.
# 14:34:04  - Combining OG 18856  with length of  5 	 with a query  16  is just finished.
# 14:34:04  - Combining OG 16602  with length of  5 	 with a query  15  is just finished.
# 14:34:04  - Combining OG 19409  with length of  5 	 with a query  15  is just finished.
# 14:34:04  - Combining OG 8841  with length of  5 	 with a query  18  is just finished.
# 14:34:04  - Combining OG 14763  with length of  5 	 with a query  15  is just finished.
# 14:34:04  - Combining OG 20624  with length of  3 	 with a query  15  is just finished.
# 14:34:04  - Combining OG 6447  with length of  5 	 with a query  18  is just finished.
# 14:34:04  - Combining OG 20049  with length of  3 	 with a query  18  is just finished.
# 14:34:04  - Combining OG 17258  with length of  5 	 with a query  16  is just finished.
# 14:34:04  - Combining OG 17972  with length of  5 	 with a query  17  is just finished.
# 14:34:04  - Combining OG 13635  with length of  5 	 with a query  17  is just finished.
# 14:34:04  - Combining OG 19002  with length of  4 	 with a query  20  is just finished.
# 14:34:04  - Combining OG 16353  with length of  5 	 with a query  15  is just finished.
# 14:34:04  - Combining OG 16388  with length of  5 	 with a query  15  is just finished.
# 14:34:04  - Combining OG 5218  with length of  5 	 with a query  16  is just finished.
# 14:34:04  - Combining OG 3563  with length of  5 	 with a query  16  is just finished.
# 14:34:04  - Combining OG 19860  with length of  5 	 with a query  20  is just finished.
# 14:34:04  - Combining OG 12528  with length of  3 	 with a query  19  is just finished.
# 14:34:04  - Combining OG 12619  with length of  5 	 with a query  18  is just finished.
# 14:34:04  - Combining OG 17033  with length of  5 	 with a query  18  is just finished.
# 14:34:04  - Combining OG 19697  with length of  5 	 with a query  16  is just finished.
# 14:34:04  - Combining OG 11173  with length of  5 	 with a query  18  is just finished.
# 14:34:04  - Combining OG 10892  with length of  5 	 with a query  15  is just finished.
# 14:34:04  - Combining OG 11180  with length of  5 	 with a query  19  is just finished.
# 14:34:04  - Combining OG 2587  with length of  5 	 with a query  15  is just finished.
# 14:34:04  - Combining OG 9273  with length of  5 	 with a query  15  is just finished.
# 14:34:04  - Combining OG 14470  with length of  5 	 with a query  16  is just finished.
# 14:34:04  - Combining OG 8876  with length of  5 	 with a query  15  is just finished.
# 14:34:04  - Combining OG 14246  with length of  5 	 with a query  15  is just finished.
# 14:34:04  - Combining OG 16962  with length of  5 	 with a query  16  is just finished.
# 14:34:04  - Combining OG 12636  with length of  4 	 with a query  16  is just finished.
# 14:34:04  - Combining OG 11858  with length of  5 	 with a query  18  is just finished.
# 14:34:04  - Combining OG 12068  with length of  4 	 with a query  16  is just finished.
# 14:34:04  - Combining OG 7302  with length of  4 	 with a query  17  is just finished.
# 14:34:04  - Combining OG 12537  with length of  5 	 with a query  21  is just finished.
# 14:34:04  - Combining OG 12862  with length of  3 	 with a query  15  is just finished.
# 14:34:04  - Combining OG 7900  with length of  5 	 with a query  16  is just finished.
# 14:34:04  - Combining OG 5633  with length of  3 	 with a query  20  is just finished.
# 14:34:04  - Combining OG 17618  with length of  5 	 with a query  16  is just finished.
# 14:34:04  - Combining OG 3732  with length of  4 	 with a query  15  is just finished.
# 14:34:04  - Combining OG 7547  with length of  5 	 with a query  17  is just finished.
# 14:34:04  - Combining OG 9464  with length of  5 	 with a query  17  is just finished.
# 14:34:04  - Combining OG 14650  with length of  5 	 with a query  15  is just finished.
# 14:34:04  - Combining OG 19942  with length of  5 	 with a query  15  is just finished.
# 14:34:04  - Combining OG 13666  with length of  5 	 with a query  19  is just finished.
# 14:34:04  - Combining OG 16754  with length of  5 	 with a query  16  is just finished.
# 14:34:04  - Combining OG 19569  with length of  4 	 with a query  15  is just finished.
# 14:34:04  - Combining OG 5949  with length of  5 	 with a query  15  is just finished.
# 14:34:04  - Combining OG 16667  with length of  5 	 with a query  17  is just finished.
# 14:34:04  - Combining OG 18141  with length of  5 	 with a query  16  is just finished.
# 14:34:04  - Combining OG 7444  with length of  4 	 with a query  21  is just finished.
# 14:34:04  - Combining OG 15525  with length of  5 	 with a query  15  is just finished.
# 14:34:04  - Combining OG 19923  with length of  2 	 with a query  15  is just finished.
#
#  14:34:04 - Combining queries with OG is finished! number of OGs 960
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_713727/1220958264.py in <module>
# ----> 1 seqRecords_all_filtr = combine_OG_query_filtr(OGs_queries_filtr, oma_db,kept_oma_species_num)
#       2
#       3 #    seqRecords_all_filtr = combine_OG_query_filtr(OGs_queries_filtr, oma_db, threshold_least_query_sepecies_in_OG,kept_oma_species_num)
#       4
#
# /tmp/ipykernel_713727/3587945244.py in combine_OG_query_filtr(OGs_queries_filtr, oma_db, kept_oma_species_num)
#     756
#     757
# --> 758     open_file = open(project_folder+"fastoma_core/_file_combined_OGs_filtr.pkl", "wb")
#     759     pickle.dump(seqRecords_all_filtr, open_file)
#     760     open_file.close()
#
# FileNotFoundError: [Errno 2] No such file or directory: '/work/FAC/FBM/DBC/cdessim2/default/smajidi1/fastoma/primate_oma/v26_5/fastoma_core/_file_combined_OGs_filtr.pkl'

# %%
    number_max_workers = round(int(argv[3])*1.3) # 3
    result_mafft_all_species = run_msa_OG_parallel(seqRecords_all_filtr,number_max_workers)


    all_id=[]
    for a in result_mafft_all_species:
        for i in a:
            all_id.append(i.id)
    len(all_id),len(set(all_id))

    list_removed_species=[]
    for i in query_species_names:
        if i not in set(all_id):
            list_removed_species.append(i)

    if len(list_removed_species):
        print("These species are removed from the input proteome:",list_removed_species)
    else:
        print("All input species are included in the MSA.")

    list_added_species=[]
    for i in set(all_id):
        if i not in query_species_names:
            list_added_species.append(i)        
    if len(list_removed_species):
        print("These species are added from OMA database:", list_added_species)

# %%
## EEORORORO   One species is removed 

#project_folder = "/work/FAC/FBM/DBC/cdessim2/default/smajidi1/fastoma/mammal_uniprot/mml_v4/"
#/work/FAC/FBM/DBC/cdessim2/default/smajidi1/fastoma/mammal_uniprot/mml_v4/fastoma_core_nosplice_v5

#a = project_folder+ "fastoma_core_nosplice_v5/_file_msas.pkl"

########

    ogs_keep_number = 100
    result_mafft_all_species_filtr = filter_ogs(result_mafft_all_species,ogs_keep_number)
    msa= concatante_alignments(result_mafft_all_species_filtr, ogs_keep_number)

# %%
# # for i in range(30):
# #     print(i, msa[i].id )

# seq=msa[5].seq

# gap_count_og = seq.count("-") + seq.count("?") + seq.count(".") +seq.count("~") 
# gap_count_og

# %% [markdown]
# ## Load pkl file

# %%
#a="/work/FAC/FBM/DBC/cdessim2/default/smajidi1/fastoma/mammal/mml_v4/omamer_v4_search/fastoma_out/"

project_folder = "/work/FAC/FBM/DBC/cdessim2/default/smajidi1/fastoma/mammal_uniprot/mml_v4/"
#/work/FAC/FBM/DBC/cdessim2/default/smajidi1/fastoma/mammal_uniprot/mml_v4/fastoma_core_nosplice_v5

a = project_folder+ "fastoma_core_nosplice_v5/_file_msas.pkl"
open_file = open(a, "rb") #project_folder+"_file_msas2.pkl"
result_mafft_all_species = pickle.load(open_file)
open_file.close()
print("seq read is loaded", len(result_mafft_all_species))

# # result_mafft_all_species[0][:]
ogs_keep_number = 100# 500
result_mafft_all_species_filtr = filter_ogs(result_mafft_all_species,ogs_keep_number)
msa2= concatante_alignments(result_mafft_all_species_filtr, ogs_keep_number)



# for record in msa:
#     if record.id =="S0003":
#         a= record.seq
# Out:
# seq read is loaded 1181
# 09:42:57 - Filtering MSA started.
# 09:42:58 - The histogram of density ogs is saved.
# 09:42:58 - Filtering MSA finished, keeping 100 out of 1181
# 09:42:58 - MSA concatenation started
# 09:42:58 - Alignments len 100
# 09:42:58 - ids:  106 10138
# 09:42:58 - MSA concatenation finished
# 09:42:58 - MSA concatenation has been written in the file /work/FAC/FBM/DBC/cdessim2/default/smajidi1/fastoma/mammal_uniprot/mml_v4/fastoma_core/_100_msa_concatanated.txt with length 106 135151

# %%
# Out:
# 106

# %%
# Out:
# 107

# %%
len(msa2),len(msa2[0]),len(msa2[1])
# Out:
# (106, 135151, 135151)

# %%
def msa_filter_col(msa_filtered_row, tresh_ratio_gap_col):

    ratio_col_all = []

    length_record= len(msa_filtered_row[1])
    num_records = len(msa_filtered_row)


    keep_cols = []
    for col_i in range(length_record):  # inspired by https://github.com/andreas-wilm/compbio-utils/blob/master/prune_aln_cols.py 

        col_values = [record.seq[col_i] for record in msa_filtered_row]

        gap_count=col_values.count("-") + col_values.count("?") + col_values.count(".") +col_values.count("~")

        ratio_col_nongap = 1- gap_count/num_records
        ratio_col_all.append(ratio_col_nongap)
        if ratio_col_nongap  > tresh_ratio_gap_col:
            keep_cols.append(col_i)


    plt.hist(ratio_col_all,bins=100) # , bins=10
    #plt.show()
    plt.savefig(project_folder+"fastoma_core/_ratio_col.pdf")

    current_time = datetime.now().strftime("%H:%M:%S")
    print(current_time, "- Columns indecis extracted. Out of ", length_record,"columns,",len(keep_cols),"is remained.") 

    msa_filtered_row_col = []

    for record in msa_filtered_row :
        record_seq = str(record.seq)

        record_seq_edited  = ''.join([record_seq[i] for i in keep_cols  ])
        record_edited= SeqRecord(Seq(record_seq_edited), record.id, '', '')
        msa_filtered_row_col.append(record_edited)                         
#ogs_keep_number
#tresh_ratio_gap_row
    out_name_msa=project_folder+"fastoma_core/_"+str("_")+"_msa_concatanated_filtered_row_"+str("_")+"_col_"+str(tresh_ratio_gap_col)+".txt"
    handle_msa_fasta = open(out_name_msa,"w")
    SeqIO.write(msa_filtered_row_col, handle_msa_fasta,"fasta")
    handle_msa_fasta.close()
    
    current_time = datetime.now().strftime("%H:%M:%S")
    print(current_time, "- Column-wise filtering of MSA is finished",len(msa_filtered_row_col),len(msa_filtered_row_col[0])) 
       
    #msa_filtered_row_col = MultipleSeqAlignment(msa_filtered_row_col)
    return msa_filtered_row_col

# %%
len(msa),len(msa[0])
# Out:
# (107, 1249527)

# %%
tresh_ratio_gap_col = 0.9
out1= msa_filter_col(msa, tresh_ratio_gap_col)
# Out:
# 09:38:43 - Columns indecis extracted. Out of  1249527 columns, 476182 is remained.
# 09:38:46 - Column-wise filtering of MSA is finished 107 476182

# %%
tresh_ratio_gap_col = 0.93
out2= msa_filter_col(out1, tresh_ratio_gap_col)
# Out:
# 09:45:47 - Columns indecis extracted. Out of  476182 columns, 295757 is remained.
# 09:45:49 - Column-wise filtering of MSA is finished 107 295757

# %%
tresh_ratio_gap_col = 0.943
out3= msa_filter_col(out2, tresh_ratio_gap_col)
# Out:
# 09:46:02 - Columns indecis extracted. Out of  295757 columns, 209881 is remained.
# 09:46:03 - Column-wise filtering of MSA is finished 107 209881

# %%
tresh_ratio_gap_col = 0.9439
out3= msa_filter_col(out2, tresh_ratio_gap_col)
# Out:
# 09:55:18 - Columns indecis extracted. Out of  295757 columns, 209881 is remained.
# 09:55:20 - Column-wise filtering of MSA is finished 107 209881

# %%
# tresh_ratio_gap_col = 0.8
# tresh_ratio_gap_row="norow"
# out2= msa_filter_col(out1, tresh_ratio_gap_col)

# %%
# reading pkl file 
# open_file = open(project_folder+"_file_msas2.pkl", "rb")
# result_mafft_all_species = pickle.load(open_file)
# open_file.close()
# print("seq read is loaded", len(seqRecords_all))

#print(current_time, "- Row-wise filtering of MSA is started.")        
#tresh_ratio_gap_row = 0.3
#msa_filtered_row = msa_filter_row(msa,tresh_ratio_gap_row,query_species_names,ogs_keep_number)
#print(current_time, "- Column-wise filtering of MSA is started.") 
#tresh_ratio_gap_col = 0.3
#msa_filtered_row_col=  msa_filter_col(msa_filtered_row, tresh_ratio_gap_col,tresh_ratio_gap_row,ogs_keep_number)

# %%
#oma_database_address = "/work/FAC/FBM/DBC/cdessim2/default/smajidi1/fastoma/mammal/mml_v4/omamer_v4_database/oma_path_/OmaServer.h5"
#oma_db = db.Database(oma_database_address+"")

#oma_db.tax.as_dict()
#oma_db.tax.genomes.values()
#oma_db.tax.newick()
#import pyoma.browser.models as models
# models.Genome

# %%
msa_id= []
for i in msa2:
    msa_id.append(i.id)

# %%
out3_id= []
for i in out3:
    out3_id.append(i.id)

# %%
set(out3_id)-set(msa_id)
# Out:
# {'Gulo_gulo'}

# %%
len(msa_id), len(out3_id)
# Out:
# (106, 107)

# %%
len(msa2), len(out3)
# Out:
# (106, 107)

# %%
len(result_mafft_all_species_filtr)
# Out:
# 100

# %%
out3_id.index('Gulo_gulo')
# Out:
# 1

# %%
out3_id[1]
# Out:
# 'Gulo_gulo'

# %%
out3[1]
# Out:
# SeqRecord(seq=Seq('??????????????????????????????????????????????????????...???'), id='Gulo_gulo', name='', description='', dbxrefs=[])

# %%
out2.remove(1)
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# /tmp/ipykernel_713727/3215610233.py in <module>
# ----> 1 out2.remove(1)
#
# /work/FAC/FBM/DBC/cdessim2/default/smajidi1/software/miniconda3/lib/python3.8/site-packages/Bio/SeqRecord.py in __eq__(self, other)
#     801     def __eq__(self, other):
#     802         """Define the equal-to operand (not implemented)."""
# --> 803         raise NotImplementedError(_NO_SEQRECORD_COMPARISON)
#     804
#     805     def __ne__(self, other):
#
# NotImplementedError: SeqRecord comparison is deliberately not implemented. Explicitly compare the attributes of interest.

# %%
out4 = MultipleSeqAlignment([out2[i]  for i in range(107) if i!=1])

# %%
tresh_ratio_gap_col = 0.92
out5= msa_filter_col(out4, tresh_ratio_gap_col)
# Out:
# 10:17:57 - Columns indecis extracted. Out of  295757 columns, 295757 is remained.
# 10:17:59 - Column-wise filtering of MSA is finished 106 295757

# %%
tresh_ratio_gap_col = 0.945
out6= msa_filter_col(out5, tresh_ratio_gap_col)
# Out:
# 10:18:39 - Columns indecis extracted. Out of  295757 columns, 209737 is remained.
# 10:18:41 - Column-wise filtering of MSA is finished 106 209737

# %%
tresh_ratio_gap_col = 0.946
out6= msa_filter_col(out5, tresh_ratio_gap_col)
# Out:
# 10:19:02 - Columns indecis extracted. Out of  295757 columns, 209737 is remained.
# 10:19:04 - Column-wise filtering of MSA is finished 106 209737

# %%
tresh_ratio_gap_col = 0.95
out6= msa_filter_col(out5, tresh_ratio_gap_col)
# Out:
# 10:19:17 - Columns indecis extracted. Out of  295757 columns, 209737 is remained.
# 10:19:18 - Column-wise filtering of MSA is finished 106 209737

# %%
tresh_ratio_gap_col = 0.97
out6= msa_filter_col(out5, tresh_ratio_gap_col)
# Out:
# 10:19:41 - Columns indecis extracted. Out of  295757 columns, 50788 is remained.
# 10:19:41 - Column-wise filtering of MSA is finished 106 50788

# %%
tresh_ratio_gap_col = 0.96
out6= msa_filter_col(out5, tresh_ratio_gap_col)
# Out:
# 10:19:55 - Columns indecis extracted. Out of  295757 columns, 121044 is remained.
# 10:19:56 - Column-wise filtering of MSA is finished 106 121044
