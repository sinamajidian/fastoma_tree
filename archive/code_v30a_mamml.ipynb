# %%
# IMPORTNAT  this code accept only .fa file as proteome

def parse_oma_db(oma_database_address):
    
    ############### Parsing OMA db ####################
    ###################################################

    oma_db = db.Database(oma_database_address)

    current_time = datetime.now().strftime("%H:%M:%S")
    print(current_time, "- OMA data is parsed and its release name is:", oma_db.get_release_name())
    list_speices= [z.uniprot_species_code for z in oma_db.tax.genomes.values()] 
    current_time = datetime.now().strftime("%H:%M:%S")
    print(current_time,"- There are",len(list_speices),"species in the OMA database.")
    
    return (oma_db, list_speices)


def parse_hog_og_map(hog_og_map_address):
    
    ############### Parsing hog map python dic #############
    #########################################################

    oma_db = db.Database(oma_database_address)

    file = open(hog_og_map_address, "r")
    contents = file.read()
    hog_OG_map = ast.literal_eval(contents)
    file.close()
    current_time = datetime.now().strftime("%H:%M:%S")
    print(current_time,"- The hog-og map is read from file with the length of ", len(hog_OG_map))
       
    return (hog_OG_map)



def HOG_OG_map(oma_database_address):

    oma_db = db.Database(oma_database_address)
    print("OMA data is parsed and its release name is:", oma_db.get_release_name())
    list_speices= [z.uniprot_species_code for z in oma_db.tax.genomes.values()] 
    print("There are",len(list_speices),"species in the OMA database.")

    hog_OG_map = {hog_id.decode("utf-8") : og_count_list[0][0] for hog_id, og_count_list in build_hog_to_og_map(oma_db)}
    print("HOG-OG map is extracted with length of ", len(hog_OG_map))


    hog_OG_map_address = oma_database_address+"_hog_og_map.dic"
    with open(hog_OG_map_address, 'w') as file_map:
        print(hog_OG_map, file=file_map)

    file_map.close()
    print("HOG-OG map is written in the file",hog_OG_map_address)
    
    return hog_OG_map


def parse_proteome(list_speices):
    
    ############### Parsing query proteome of species #######
    #########################################################

    
    # IMPORTNAT  this code accept only .fa file as proteome
    project_files = listdir(project_folder+"/omamer_search/proteome/")

    query_species_names = []
    for file in project_files:
        if file.split(".")[-1]=="fa":
            file_name_split = file.split(".")[:-1]
            query_species_names.append('.'.join(file_name_split))
        if file.split(".")[-1]=="fasta":
            file_name_split = file.split(".")[:-1]
            query_species_names.append('.'.join(file_name_split))

    # we may assert existence of query_species_name+".fa/hogmap"
    query_prot_records_species = [ ]
    for query_species_name in query_species_names:
        query_prot_address = project_folder +"omamer_search/proteome/"+ query_species_name + ".fa" 
        
        query_prot_records = list(SeqIO.parse(query_prot_address, "fasta")) 
        query_prot_records_species.append(query_prot_records)

    query_species_num = len(query_species_names)    
    current_time = datetime.now().strftime("%H:%M:%S")
    print(current_time,"- The are",str(query_species_num),"species in the proteome folder.")

    # for development
    query_species_num = len(query_species_names)
    for species_i in range(query_species_num):
        len_prot_record_i = len( query_prot_records_species[species_i] )
        species_name_i = query_species_names[species_i]
        #print(species_name_i,len_prot_record_i)
        if species_name_i in list_speices: 
            current_time = datetime.now().strftime("%H:%M:%S")
            print(current_time,"- the species",species_name_i," already exists in the oma database, remove them first")
            exit()

      
    # The proteins are parsed using  Bio.SeqIO.parse
    # the first part of the header line before space 
    # >tr|A0A2I3FYY2|A0A2I3FYY2_NOMLE Uncharacterized protein OS=Nomascus leucogenys OX=61853 GN=CLPTM1L PE=3 SV=1
    # will be ">tr|A0A2I3FYY2|A0A2I3FYY2_NOMLE"
    # [i.id for i in query_prot_records_species[0] if len(i.id)!=30 and len(i.id)!=22 ] #'sp|O47892|CYB_NOMLE',
    

    
    return (query_species_names, query_prot_records_species)



def parse_hogmap_omamer(query_species_names):

    ################### Parsing omamer's output  ########
    #####################################################

    query_prot_names_species_mapped = []
    query_hogids_species = []

    for query_species_name in query_species_names:
        omamer_output_address = project_folder + "omamer_search/hogmap/"+ query_species_name + ".hogmap"     
        omamer_output_file = open(omamer_output_address,'r');

        query_prot_names= []
        query_hogids= []

        for line in omamer_output_file:
            line_strip=line.strip()
            if not line_strip.startswith('qs'):
                line_split= line_strip.split("\t")    
                #if line_split[1]!='na':
                query_prot_names.append(line_split[0])
                query_hogids.append(line_split[1])
        #print("number of proteins in omamer output for ",query_species_name,"is",len(query_hogids)) # ,query_hogids
        query_prot_names_species_mapped.append(query_prot_names)
        query_hogids_species.append(query_hogids)    
        
    current_time = datetime.now().strftime("%H:%M:%S")
    print(current_time,"- There are ",len(query_prot_names_species_mapped)," in hogmap folder.")
    print(current_time,"- The first species",query_species_names[0]," contains ",len(query_hogids_species[0])," proteins.")
    print(current_time,"- The first protein of first species is ",query_prot_names[0])

    
    return (query_prot_names_species_mapped, query_hogids_species)
    
    

def filter_prot_mapped(query_species_names, query_prot_records_species,query_prot_names_species_mapped):
    # omamer remove very small proteins, 
    # so  we lose track of order comparing hogmap and fasta file
    # the goal here is to remove those from seq record (of the fasta file)
    query_prot_records_species_filtered=[]
    for species_idx in range(len(query_species_names)):    
        # from fasta file
        query_species_name=query_species_names[species_idx]
        query_prot_records_species_i = query_prot_records_species[species_idx]
        query_prot_ids_records = [record.id for record in query_prot_records_species_i]

        # from hogmap file
        # without proteins that are not mapped on any hogs
        query_prot_names_species_i = query_prot_names_species_mapped[species_idx]

        if len(query_prot_names_species_i) != len(query_prot_records_species_i):

            query_prot_records_filterd=[]
            for query_prot_name in query_prot_names_species_i:
                if query_prot_name in query_prot_ids_records:
                    prot_record_idx = query_prot_ids_records.index(query_prot_name)
                    prot_record = query_prot_records_species_i[prot_record_idx]
                    query_prot_records_filterd.append(prot_record)
                else:
                    current_time = datetime.now().strftime("%H:%M:%S")                    
                    print(current_time,"- Error",query_species_name, query_prot_name)

            current_time = datetime.now().strftime("%H:%M:%S")        
            print(current_time,"- For the species", query_species_name, ", few proteins were ignored by omamer.")
            print(current_time,"- before filtering: in hogmap", len(query_prot_names_species_i), "in proteome", len(query_prot_records_species_i))
            print(current_time,"- After filtering:  in hogmap", len(query_prot_names_species_i), "in proteome", len(query_prot_records_filterd))            
            

        else:
            query_prot_records_filterd = query_prot_records_species_i

        query_prot_records_species_filtered.append(query_prot_records_filterd)
    current_time = datetime.now().strftime("%H:%M:%S")        
    print(current_time,"- For the rest of species, all proteins were mapped using OMAmer.")

    return query_prot_records_species_filtered



def extract_unique_hog_pure(query_species_names,query_hogids_species, query_prot_names_species_mapped,query_prot_records_species):
    ###### Extracting unique HOG list and corresponding query proteins ########
    ###########################################################################

    current_time = datetime.now().strftime("%H:%M:%S")
    print(current_time,"- Extracting proteins mapped only once on a HOG is started")

    query_hogids_filtr_species = []
    query_prot_names_filtr_species = []
    query_prot_records_filtr_species = []

    repeated_hogid_num = 0
    
    query_species_num = len(query_species_names) 
    
    dic_hogs_list=[]  # a list of dictinaries 


    for species_i in range(query_species_num):

        query_hogids =  query_hogids_species[species_i]
        query_prot_names = query_prot_names_species_mapped[species_i]
        query_prot_records  = query_prot_records_species[species_i]
        
        dic_hogs = {}
        for prot_i in range(len(query_hogids)):
            query_hogid      = query_hogids[prot_i]
            query_prot_name  = query_prot_names[prot_i]
            query_prot_record= query_prot_records[prot_i]
            if query_hogid!= 'na':
                if  query_hogid  not in  dic_hogs:
                    dic_hogs[query_hogid]=[(query_prot_name,query_prot_record)]
                else:
                    repeated_hogid_num += 1 
                    dic_hogs[query_hogid].append((query_prot_name,query_prot_record))
        dic_hogs_list.append(dic_hogs)

        
    for dic_hogs in dic_hogs_list: # each species
        
        query_prot_names_filtr = []
        query_prot_records_filtr = []

        hogid_list = list(dic_hogs.keys())
        for hogid in hogid_list:
            list_query_prot = dic_hogs[hogid]
            if len(list_query_prot)>1:
                del dic_hogs[hogid]
        #here dic_hogs is updated and  dic_hogs_list  is also updated.
        
        #print(len(hogid_list),len(dic_hogs))
        #for key, value in d.items():
        query_hogids_filtr = []
        query_prot_names_filtr = []
        query_prot_records_filtr = []        
        #query_hogids_filtr=list(dic_hogs.keys())
        for hogid, tuple_value  in dic_hogs.items():
            query_hogids_filtr.append(hogid)
            query_prot_names_filtr.append(tuple_value[0][0])
            query_prot_records_filtr.append(tuple_value[0][1])
        
        
        

        query_hogids_filtr_species.append(query_hogids_filtr)
        query_prot_names_filtr_species.append(query_prot_names_filtr)
        query_prot_records_filtr_species.append(query_prot_records_filtr)        
    
    current_time  = datetime.now().strftime("%H:%M:%S")
    print(current_time,"- Extracting proteins mapped only once on a HOG is finished")
    num_all_hogs=np.sum([len(dic_hogs) for dic_hogs in dic_hogs_list])
    print(current_time,"- For ",len(dic_hogs_list)," species, we keep ",num_all_hogs,"HOGs.")
    

    return (query_hogids_filtr_species, query_prot_names_filtr_species, query_prot_records_filtr_species )
  

def gather_OG(query_species_names, query_hogids_filtr_species, query_prot_names_filtr_species, query_prot_records_filtr_species):

    ############ Extracting the most frequent OG  ########
    #####################################################

    #dict (oma_group_nr -> dict(species, [proteins]))
    #Og[555] = {homo_erectus: [blabla, blublu], yellow_bird: [P52134], brown_bear: [P2121,B53223]}

    OGs_queries = {}

    # hog_OG_map = {}

    mostFrequent_OG_list_species = []

    frq_most_frequent_og_list_all = [] # for development
    
    query_species_num = len(query_species_names)  
    for species_i in  range(query_species_num):

        query_species_name = query_species_names[species_i]
        #print("\n",query_species_name)

        query_hogids_filtr = query_hogids_filtr_species[species_i]
        query_prot_names_filtr = query_prot_names_filtr_species[species_i]
        query_prot_records_filtr = query_prot_records_filtr_species[species_i]

        mostFrequent_OG_list=[]

        num_query_filtr = len(query_hogids_filtr)
        for  item_idx in range(num_query_filtr): #

            #query_protein = query_prot_names_filtr[item_idx]
            seqRecords_query =  query_prot_records_filtr[item_idx]
            seqRecords_query_edited = SeqRecord(Seq(str(seqRecords_query.seq)), query_species_name, '', '')
            #print(seqRecords_query_edited)

            hog_id= query_hogids_filtr[item_idx]

            if not hog_id in hog_OG_map:   # Caculitng  most frq OG for the new hog
                mostFrequent_OG= -1
                hog_OG_map[hog_id]=mostFrequent_OG

            else:  # hog_id is in hog_OG_map dic
                #print("using the hog-og-map")
                mostFrequent_OG = hog_OG_map[hog_id]

            if mostFrequent_OG in OGs_queries:
                OGs_queries_k = OGs_queries[mostFrequent_OG]

                if not query_species_name in OGs_queries_k:
                    OGs_queries_k[query_species_name] = seqRecords_query_edited
                    OGs_queries[mostFrequent_OG] = OGs_queries_k
            else:
                OGs_queries[mostFrequent_OG] = {query_species_name: seqRecords_query_edited} # query_protein = query_prot_names_filtr[item_idx]
    current_time = datetime.now().strftime("%H:%M:%S")
    print(current_time, "- Needed HOH-OG map ",len(OGs_queries),"are extracted from the map file.") 
    
    return OGs_queries



    
def filter_gathered_OG(OGs_queries, query_species_names,keep_og_treshold_species_query):

    
    current_time = datetime.now().strftime("%H:%M:%S")
    print(current_time, "- Start filtering OGs of proteme queries with length of ", len(OGs_queries),"for ",len(query_species_names),"species.") 
       
        
        
    OGs_queries_filtr={}

    query_species_og_kept_set= set()

    query_species_num_OGs_list=[]
    for OG_id, values in OGs_queries.items():
        query_species_og= list(values.keys())

        query_species_num_OGs_list.append(len(query_species_og)) 
        if len(query_species_og) > keep_og_treshold_species_query:
            OGs_queries_filtr[OG_id]=values
            query_species_og_kept_set= query_species_og_kept_set.union(set(query_species_og))


    current_time = datetime.now().strftime("%H:%M:%S")
    print(current_time, "- Finished filetering from ",len(OGs_queries),", now only",len(OGs_queries_filtr),"OGs are remained.") 
               


    not_included_species =[]
    for i in set(query_species_names):
        if i not in query_species_og_kept_set:
            not_included_species.append(i)

    
    current_time = datetime.now().strftime("%H:%M:%S")
    print(current_time, "- These species missed due to the threshold of",keep_og_treshold_species_query,":",not_included_species) 
               


    #query_species_num_OGs_list
    # for i in not_included_species:
    #     #print(i)
    #     for OG_id, values in OGs_queries.items():
    #         if i in values:
    #             print(values.keys())
    # easiet way keep the first one or make list and keep the best
    # but better to set trehsold not to misss any species 
    
    return OGs_queries_filtr
    

    
    
    

def combine_OG_query_filtr(OGs_queries_filtr, oma_db, threshold_least_query_sepecies_in_OG,kept_oma_species_num):
    
#     ########## Combine proteins of OG with queries ##################
#     #################################################################
    
    current_time = datetime.now().strftime("%H:%M:%S")
    print(current_time, "- Combining queries with OG started for",len(OGs_queries_filtr),"OGs.") 
    
    species_og_dic={}
    
    proteins_object_OG_dic={}
    for OG_q in OGs_queries_filtr.keys():  # OG found in the query

        dic_species_prot = OGs_queries_filtr[OG_q]
        if len(dic_species_prot) >threshold_least_query_sepecies_in_OG:
            if OG_q != -1:
                OG_members = oma_db.oma_group_members(OG_q)
                proteins_object_OG = [db.ProteinEntry(oma_db, pr) for pr in OG_members]  # the protein IDs of og members
                proteins_object_OG_dic[OG_q]=proteins_object_OG
                
                species_all_og = [ str(pr.genome.uniprot_species_code) for pr in proteins_object_OG ]

                for species in species_all_og:
                    if species in species_og_dic:
                        #species_og_dic[species].append(OG_q)                        
                        species_og_dic[species] +=1 
                    else:
                        #species_og_dic[species]=[OG_q]
                        species_og_dic[species] = 1
    
    current_time = datetime.now().strftime("%H:%M:%S")
    print(current_time, "- Number of OMA species per OG is calculated") 
                         
    species_oma_list=[]
    og_num_list = []
    for species_oma, og_num in species_og_dic.items():
        og_num_list.append(og_num)
        species_oma_list.append(species_oma)
        
    id_species_keep = np.argsort(og_num_list)[-kept_oma_species_num:]
    species_oma_kept = [species_oma_list[i] for i in id_species_keep]

    current_time = datetime.now().strftime("%H:%M:%S")
    print(current_time, "- These OMA species are kept",species_oma_kept) 

    
    seqRecords_OG_queries = []
    seqRecords_all_filtr = []
    for OG_q in OGs_queries_filtr.keys():  # OG found in the query

        dic_species_prot = OGs_queries_filtr[OG_q]
        if len(dic_species_prot) >threshold_least_query_sepecies_in_OG:
            
            seqRecords_query_edited_all = list(dic_species_prot.values())
            if OG_q != -1:
                proteins_object_OG = proteins_object_OG_dic[OG_q]
                 # covnert to biopython objects
                seqRecords_OG = []
                for pr in proteins_object_OG:
                    species_code = str(pr.genome.uniprot_species_code)
                    if species_code in species_oma_kept:
                        seq_record = SeqRecord(Seq(pr.sequence),species_code,'','') 
                        seqRecords_OG.append(seq_record)
                
                seqRecords_OG_queries =seqRecords_OG + seqRecords_query_edited_all
                current_time = datetime.now().strftime("%H:%M:%S")
                #print(current_time, " - Length of OG",OG_q,"was",len(seqRecords_OG),",now is",len(seqRecords_OG_queries))
                print(current_time, " - Combining OG",OG_q," with length of ",len(seqRecords_OG),"\t with a query ",len(seqRecords_query_edited_all)," is just finished.")

                seqRecords_all_filtr.append(seqRecords_OG_queries)


    current_time = datetime.now().strftime("%H:%M:%S")
    print("\n", current_time, "- Combining queries with OG is finished! number of OGs",len(seqRecords_all_filtr)) # 
    
    
    
    open_file = open(project_folder+"fastoma_core/_file_combined_OGs_filtr.pkl", "wb")
    pickle.dump(seqRecords_all_filtr, open_file)
    open_file.close()

    current_time = datetime.now().strftime("%H:%M:%S")
    print("\n", current_time, "- The variable seqRecords_all_filtr is saved as", project_folder+"fastoma_core/_file_combined_OGs_filtr.pkl") # 
    
    return(seqRecords_all_filtr)




def run_msa_OG(seqRecords_OG_queries):
    ############## MSA  ##############
    ##################################
    #current_time = datetime.now().strftime("%H:%M:%S")
    #print(current_time, "- working on new OG with length of ",len(seqRecords_OG_queries))

    wrapper_mafft = mafft.Mafft(seqRecords_OG_queries,datatype="PROTEIN") 
    # MAfft error: Alphabet 'U' is unknown. -> add --anysymbol argument needed to define in the sourse code
    # workaround sed "s/U/X/g"
    
    wrapper_mafft.options.options['--retree'].set_value(1)


    run_mafft = wrapper_mafft() # it's wrapper  storing the result  and time 
    time_taken_mafft = wrapper_mafft.elapsed_time

    result_mafft = wrapper_mafft.result 
    time_taken_mafft2 = wrapper_mafft.elapsed_time
    
    current_time = datetime.now().strftime("%H:%M:%S")
    #print(current_time,"- time elapsed for MSA: ",time_taken_mafft2)
    print(current_time,"- MSA for an OG is just finished: ",time_taken_mafft2)

    return(result_mafft)
   


def run_msa_OG_parallel(seqRecords_all,number_max_workers):
        
    iterotr_OGs = 0 
    
    result_mafft_all_species=[]
    current_time = datetime.now().strftime("%H:%M:%S")
    print(current_time, "- Parallel msa is started for ",len(seqRecords_all)," OGs.")
    
    
    
    with concurrent.futures.ProcessPoolExecutor(max_workers=number_max_workers) as executor: 
        for seqRecords_OG_queries, output_values in zip(seqRecords_all, executor.map(run_msa_OG, seqRecords_all)):
            result_mafft_all_species.append(output_values)

            
    
    open_file = open(project_folder+"fastoma_core/_file_msas.pkl", "wb")
    pickle.dump(result_mafft_all_species, open_file)
    open_file.close()
    
    return result_mafft_all_species
    

def filter_ogs(result_mafft_all_species,ogs_keep_number):

    current_time = datetime.now().strftime("%H:%M:%S")
    print(current_time, "- Filtering MSA started.")

    density_ogs=[]
    for msa_og in result_mafft_all_species:

        gap_count_og= 0
        all_count_og=0
        for record in msa_og:
            seq=str(record.seq)
            gap_count_og += seq.count("-") + seq.count("?") + seq.count(".") +seq.count("~")    
        #gap_count_ogs.append(gap_count_og)
        density_og=gap_count_og/(len(msa_og)*len(msa_og[0]))
        density_ogs.append(density_og)
        #if density_ogs> treshold_density:
    plt.hist(density_ogs,bins=100) # , bins=10
    #plt.show()
    plt.savefig(project_folder+"fastoma_core/_density_ogs.pdf")
    current_time = datetime.now().strftime("%H:%M:%S")
    print(current_time, "- The histogram of density ogs is saved.")
    
    id_og_keep = np.argsort(density_ogs)[-ogs_keep_number:]
    result_mafft_all_species_filtr = [result_mafft_all_species[i] for i in id_og_keep]

    current_time = datetime.now().strftime("%H:%M:%S")
    print(current_time, "- Filtering MSA finished, keeping",len(result_mafft_all_species_filtr),"out of",len(result_mafft_all_species))       
    

    open_file = open(project_folder+"fastoma_core/_"+str(ogs_keep_number)+"_file_msas_filtered.pkl", "wb")
    pickle.dump(result_mafft_all_species_filtr, open_file)
    open_file.close()

        
    return result_mafft_all_species_filtr



def concatante_alignments(result_mafft_all_species,ogs_keep_number):
    ############## Concatante alignments  ##############
    ####################################################

    #alignments= result_maf2_all
    current_time = datetime.now().strftime("%H:%M:%S")
    print(current_time, "- MSA concatenation started")
    
    
    alignments= result_mafft_all_species
    current_time = datetime.now().strftime("%H:%M:%S")
    print(current_time, "- Alignments len",len(alignments))
    #print([len(aln) for aln in alignments ])
    #print([len(seq) for aln in alignments for seq in aln])

    all_labels_raw = [seq.id for aln in alignments for seq in aln]
    all_labels = set(all_labels_raw)
    current_time = datetime.now().strftime("%H:%M:%S")
    print(current_time, "- ids: ",len(all_labels),len(all_labels_raw))
    
    # Make a dictionary to store info as we go along
    # (defaultdict is convenient -- asking for a missing key gives back an empty list)
    concat_buf = defaultdict(list)

    # Assume all alignments have same alphabet
    alphabet = alignments[0]._alphabet

    for aln in alignments:
        length = aln.get_alignment_length()
        #print("length",length)
        # check if any labels are missing in the current alignment
        these_labels = set(rec.id for rec in aln)
        missing = all_labels - these_labels
        #print(missing)
        # if any are missing, create unknown data of the right length,
        # stuff the string representation into the concat_buf dict
        for label in missing:
            new_seq = UnknownSeq(length, alphabet=alphabet)
            concat_buf[label].append(str(new_seq))

        # else stuff the string representation into the concat_buf dict
        for rec in aln:
            concat_buf[rec.id].append(str(rec.seq))

    # Stitch all the substrings together using join (most efficient way),
    # and build the Biopython data structures Seq, SeqRecord and MultipleSeqAlignment
    msa = MultipleSeqAlignment(SeqRecord(Seq(''.join(seq_arr), alphabet=alphabet), id=label)
                                for (label, seq_arr) in concat_buf.items())


    current_time = datetime.now().strftime("%H:%M:%S")
    print(current_time, "- MSA concatenation finished")

    ##########
    # print the borders of concatatnion  in nexus format
    # http://www.iqtree.org/doc/Advanced-Tutorial
    #######
    out_name_msa=project_folder+"fastoma_core/_"+str(ogs_keep_number)+"_msa_concatanated.txt"
    handle_msa_fasta = open(out_name_msa,"w")
    SeqIO.write(msa, handle_msa_fasta,"fasta")
    handle_msa_fasta.close()


    # sequences_all=[]
    # for spec, sequences in concat_buf.items():
    #      sequences_all.append(sequences)
    # for i in range(1,100):
    #     print(len(sequences_all[0][i]),len(sequences_all[2][i]) ,len(sequences_all[40][i]) )
    ## therefore, all of them are with same length of sequences

    species_0=list(concat_buf.keys())[0]
    sequences =  concat_buf[species_0]
    len_all = [len(i) for i in sequences] 
#     borders_in_supermatrix=[]
#     borders_in_supermatrix.append((1,len_all[0] )) 
#     accumalte = len_all[0]
#     for i in range(1,100):
#         borders_in_supermatrix.append((accumalte+1,accumalte+len_all[i]))
#         accumalte +=len_all[i]

#     print(len(msa),len(msa[0]),accumalte)
#     #check it works or not
#     # for i in range(100):
#     #     print(borders_in_supermatrix[i][1]-borders_in_supermatrix[i][0]+1,len_all[i])

#     #borders_in_supermatrix
    
#     # begin sets;
#     #     charset part1 = 1-100;
#     #     charset part2 = 101-384;
#     #     charpartition mine = HKY+G:part1, GTR+I+G:part2;
#     # end;
#     borders_out_file_add=project_folder+"border_out_parition.nex"
#     borders_out_file = open(borders_out_file_add,'w')

#     borders_out_file.write("#nexus"+"\n")
#     borders_out_file.write("begin sets;"+"\n")

#     for i, val in enumerate(borders_in_supermatrix):

#         line="    charset part"+str(i)+" = "+str(val[0])+"-"+str(val[1])+";"
#         #print(line)
#         borders_out_file.write(line+'\n')

#     borders_out_file.write("end;\n")
#     borders_out_file.close()
#     print(borders_out_file_add)
    
    
    current_time = datetime.now().strftime("%H:%M:%S")
    print(current_time, "- MSA concatenation has been written in the file",out_name_msa,"with length", len(msa),msa.get_alignment_length()) # super matrix size
    
    
    return msa
    

def msa_filter_row(msa,tresh_ratio_gap_row,query_species_names,ogs_keep_number):

    msa_filtered_row = [] # msa_fltr
    ratio_records=[]
    for record in msa:
        species_name = record.id
        seq = record.seq
        seqLen = len(record)
        
        gap_count=seq.count("-") + seq.count("?") + seq.count(".") +seq.count("~")
                
        ratio_record_nongap= 1-gap_count/seqLen
        ratio_records.append(round(ratio_record_nongap,3))

        if ratio_record_nongap > tresh_ratio_gap_row:
            msa_filtered_row.append(record)
        elif species_name in query_species_names : 
            msa_filtered_row.append(record)
            current_time = datetime.now().strftime("%H:%M:%S")
            print(current_time, "- Many row-wise gap for query",species_name,"with a ratio of",ratio_record_nongap) 

    current_time = datetime.now().strftime("%H:%M:%S")

    print(current_time, "- Row-wise filtering of MSA is finished.") 
    print(current_time, "- Out of ",len(msa),"species,",len(msa_filtered_row),"species (row of msa) remained.")

    out_name_msa=project_folder+"fastoma_core_"+str(ogs_keep_number)+"_msa_concatanated_filtered_row_"+str(tresh_ratio_gap_row)+".txt"
    handle_msa_fasta = open(out_name_msa,"w")
    SeqIO.write(msa_filtered_row, handle_msa_fasta,"fasta")
    handle_msa_fasta.close()
    
    print(current_time, "- MSA Row-wise filtered stored in file.") # super matrix size
    
    
    return msa_filtered_row
    
    

def msa_filter_col(msa_filtered_row, tresh_ratio_gap_col,tresh_ratio_gap_row,ogs_keep_number):

    ratio_col_all = []

    length_record= len(msa_filtered_row[1])
    num_records = len(msa_filtered_row)


    keep_cols = []
    for col_i in range(length_record):  # inspired by https://github.com/andreas-wilm/compbio-utils/blob/master/prune_aln_cols.py 

        col_values = [record.seq[col_i] for record in msa_filtered_row]

        gap_count=col_values.count("-") + col_values.count("?") + col_values.count(".") +col_values.count("~")

        ratio_col_nongap = 1- gap_count/num_records
        ratio_col_all.append(ratio_col_nongap)
        if ratio_col_nongap  > tresh_ratio_gap_col:
            keep_cols.append(col_i)


    plt.hist(ratio_col_all,bins=100) # , bins=10
    #plt.show()
    plt.savefig(project_folder+"fastoma_core/_ratio_col.pdf")

    current_time = datetime.now().strftime("%H:%M:%S")
    print(current_time, "- Columns indecis extracted. Out of ", length_record,"columns,",len(keep_cols),"is remained.") 

    msa_filtered_row_col = []

    for record in msa_filtered_row :
        record_seq = str(record.seq)

        record_seq_edited  = ''.join([record_seq[i] for i in keep_cols  ])
        record_edited= SeqRecord(Seq(record_seq_edited), record.id, '', '')
        msa_filtered_row_col.append(record_edited)                         


    out_name_msa=project_folder+"fastoma_core/_"+str(ogs_keep_number)+"_msa_concatanated_filtered_row_"+str(tresh_ratio_gap_row)+"_col_"+str(tresh_ratio_gap_col)+".txt"
    handle_msa_fasta = open(out_name_msa,"w")
    SeqIO.write(msa_filtered_row_col, handle_msa_fasta,"fasta")
    handle_msa_fasta.close()
    
    current_time = datetime.now().strftime("%H:%M:%S")
    print(current_time, "- Column-wise filtering of MSA is finished",len(msa_filtered_row_col),len(msa_filtered_row_col[0])) 
       
    #msa_filtered_row_col = MultipleSeqAlignment(msa_filtered_row_col)
    return msa_filtered_row_col


def draw_tree(msa):
    ############## Tree inference  ###################
    ##################################################

    wrapper_tree=fasttree.Fasttree(msa,datatype="PROTEIN")
    wrapper_tree.options.options['-fastest']    
    result_tree1 = wrapper_tree()

    time_taken_tree = wrapper_tree.elapsed_time 
    time_taken_tree

    result_tree2 = wrapper_tree.result
    tree_nwk=str(result_tree2["tree"])
    current_time = datetime.now().strftime("%H:%M:%S")
    print(current_time,"- ",len(tree_nwk))

    out_name_tree=project_folder+"fastoma_core/_tree.txt"
    file1 = open(out_name_tree,"w")
    file1.write(tree_nwk)
    file1.close() 
    return tree_nwk

# %%
#!/usr/bin/python3

import numpy as np
import pyoma.browser.db as db
import concurrent.futures
import ast
import pickle

import zoo.wrappers.aligners.mafft as mafft  # mafft should be installed beforehand
# import zoo.wrappers.treebuilders.fasttree as fasttree

from datetime import datetime
from sys import argv
from os import listdir
from Bio import SeqIO
from Bio.SeqRecord import SeqRecord
from Bio.Seq import Seq, UnknownSeq
from Bio.Align import MultipleSeqAlignment

from collections import defaultdict


import matplotlib   #for development 
matplotlib.use('Agg')
import matplotlib.pyplot as plt


import pyoma.browser.db as db
from pyoma.browser.hoghelper import build_hog_to_og_map

# %%
if __name__ == "__main__":

    # a global variable
    project_folder = "/work/FAC/FBM/DBC/cdessim2/default/smajidi1/fastoma/mammal/old/mml5/"
    
    oma_database_address = project_folder+"omamer_database/oma_path/OmaServer.h5"
        
    (oma_db, list_speices) = parse_oma_db(oma_database_address)

    ## if you already  have the hog-og-map, parse it: 
    # hog_og_map_address=oma_database_address+"_hog_og_map.dic"    
    # (hog_OG_map)= parse_hog_og_map(hog_og_map_address)

    ## if you you don't have the hog-og-map, run this: 
    hog_OG_map = HOG_OG_map(oma_database_address)
    
    
    
    (query_species_names, query_prot_records_species) = parse_proteome(list_speices)   
    (query_prot_names_species_mapped, query_hogids_species) = parse_hogmap_omamer(query_species_names) 

    query_prot_records_species_filtered=  filter_prot_mapped(query_species_names, query_prot_records_species, query_prot_names_species_mapped)
    
    
    (query_hogids_filtr_species, query_prot_names_filtr_species, query_prot_records_filtr_species) = extract_unique_hog_pure(query_species_names,query_hogids_species, query_prot_names_species_mapped, query_prot_records_species_filtered) 

    OGs_queries = gather_OG(query_species_names, query_hogids_filtr_species, query_prot_names_filtr_species, query_prot_records_filtr_species)

    keep_og_treshold_species_query =  93  #360

    OGs_queries_filtr= filter_gathered_OG(OGs_queries, query_species_names,keep_og_treshold_species_query)

    threshold_least_query_sepecies_in_OG = 98 # 15
    kept_oma_species_num = 8 # 20
    
    seqRecords_all_filtr = combine_OG_query_filtr(OGs_queries_filtr, oma_db, threshold_least_query_sepecies_in_OG,kept_oma_species_num)
    
    number_max_workers = 2 # round(int(argv[3])*1.3)
    result_mafft_all_species = run_msa_OG_parallel(seqRecords_all_filtr,number_max_workers)
# Out:
# 14:24:36 - OMA data is parsed and its release name is: OmaStandalone; 1.0.x
# 14:24:36 - There are 9 species in the OMA database.
# OMA data is parsed and its release name is: OmaStandalone; 1.0.x
# There are 9 species in the OMA database.
# HOG-OG map is extracted with length of  51777
# HOG-OG map is written in the file /work/FAC/FBM/DBC/cdessim2/default/smajidi1/fastoma/mammal/old/mml5/omamer_database/oma_path/OmaServer.h5_hog_og_map.dic
# 14:25:04 - The are 100 species in the proteome folder.
# 14:25:06 - There are  100  in hogmap folder.
# 14:25:06 - The first species 30611  contains  19446  proteins.
# 14:25:06 - The first protein of first species is  tr|A0A341A900|A0A341A900_NEOAA
# 14:25:13 - For the species 9823 , few proteins were ignored by omamer.
# 14:25:13 - before filtering: in hogmap 22164 in proteome 22165
# 14:25:13 - After filtering:  in hogmap 22164 in proteome 22164
# 14:25:21 - For the species 10090 , few proteins were ignored by omamer.
# 14:25:21 - before filtering: in hogmap 21985 in proteome 21986
# 14:25:21 - After filtering:  in hogmap 21985 in proteome 21985
# 14:25:28 - For the species 9940 , few proteins were ignored by omamer.
# 14:25:28 - before filtering: in hogmap 21220 in proteome 21221
# 14:25:28 - After filtering:  in hogmap 21220 in proteome 21220
# 14:25:35 - For the species 9606 , few proteins were ignored by omamer.
# 14:25:35 - before filtering: in hogmap 20585 in proteome 20588
# 14:25:35 - After filtering:  in hogmap 20585 in proteome 20585
# 14:25:35 - For the rest of species, all proteins were mapped using OMAmer.
# 14:25:36 - Extracting proteins mapped only once on a HOG is started
# 14:25:38 - Extracting proteins mapped only once on a HOG is finished
# 14:25:38 - For  100  species, we keep only 1273171 HOGs.
# 14:25:50 - Needed HOH-OG map  18894 are extracted from the map file.
# 14:25:52 - Start filtering OGs of proteme queries with length of  18894 for  100 species.
# 14:25:52 - Finished filetering from  18894 , now only 3205 OGs are remained.
# 14:25:52 - These species missed due to the threshold of 93 : []
# 14:25:52 - Combining queries with OG started for 3205 OGs.
# 14:26:07 - Number of OMA species per OG is calculated
# 14:26:07 - These OMA species are kept ['S0001', 'S0004', 'S0002', 'S0009', 'S0007', 'S0006', 'S0008', 'S0003']
# 14:26:07  - Combining OG 19080  with length of  6 	 with a query  98  is just finished.
# 14:26:07  - Combining OG 3881  with length of  5 	 with a query  97  is just finished.
# 14:26:07  - Combining OG 15959  with length of  7 	 with a query  96  is just finished.
# 14:26:07  - Combining OG 8298  with length of  8 	 with a query  96  is just finished.
# 14:26:07  - Combining OG 9319  with length of  8 	 with a query  96  is just finished.
# 14:26:07  - Combining OG 13498  with length of  6 	 with a query  96  is just finished.
# 14:26:07  - Combining OG 12355  with length of  6 	 with a query  97  is just finished.
# 14:26:07  - Combining OG 2360  with length of  8 	 with a query  97  is just finished.
# 14:26:07  - Combining OG 12609  with length of  6 	 with a query  97  is just finished.
# 14:26:07  - Combining OG 9462  with length of  7 	 with a query  97  is just finished.
# 14:26:07  - Combining OG 23295  with length of  5 	 with a query  96  is just finished.
# 14:26:07  - Combining OG 4773  with length of  8 	 with a query  100  is just finished.
# 14:26:07  - Combining OG 5790  with length of  7 	 with a query  96  is just finished.
# 14:26:07  - Combining OG 10376  with length of  8 	 with a query  96  is just finished.
# 14:26:07  - Combining OG 12416  with length of  8 	 with a query  96  is just finished.
# 14:26:07  - Combining OG 5918  with length of  6 	 with a query  96  is just finished.
# 14:26:07  - Combining OG 1648  with length of  7 	 with a query  98  is just finished.
# 14:26:07  - Combining OG 8054  with length of  6 	 with a query  99  is just finished.
# 14:26:07  - Combining OG 18991  with length of  7 	 with a query  97  is just finished.
# 14:26:07  - Combining OG 12988  with length of  8 	 with a query  96  is just finished.
# 14:26:07  - Combining OG 7902  with length of  5 	 with a query  98  is just finished.
# 14:26:07  - Combining OG 11639  with length of  7 	 with a query  100  is just finished.
# 14:26:07  - Combining OG 3731  with length of  7 	 with a query  96  is just finished.
# 14:26:07  - Combining OG 11932  with length of  5 	 with a query  99  is just finished.
# 14:26:07  - Combining OG 2780  with length of  8 	 with a query  96  is just finished.
# 14:26:07  - Combining OG 17332  with length of  7 	 with a query  96  is just finished.
# 14:26:07  - Combining OG 4537  with length of  8 	 with a query  97  is just finished.
# 14:26:07  - Combining OG 9061  with length of  8 	 with a query  97  is just finished.
# 14:26:07  - Combining OG 5426  with length of  7 	 with a query  96  is just finished.
# 14:26:07  - Combining OG 11355  with length of  8 	 with a query  97  is just finished.
# 14:26:07  - Combining OG 11421  with length of  8 	 with a query  98  is just finished.
# 14:26:07  - Combining OG 4092  with length of  5 	 with a query  98  is just finished.
# 14:26:07  - Combining OG 8534  with length of  8 	 with a query  98  is just finished.
# 14:26:07  - Combining OG 12078  with length of  6 	 with a query  97  is just finished.
# 14:26:07  - Combining OG 11949  with length of  7 	 with a query  97  is just finished.
# 14:26:07  - Combining OG 3433  with length of  8 	 with a query  98  is just finished.
# 14:26:07  - Combining OG 4138  with length of  8 	 with a query  96  is just finished.
# 14:26:07  - Combining OG 20075  with length of  6 	 with a query  98  is just finished.
# 14:26:07  - Combining OG 16074  with length of  8 	 with a query  97  is just finished.
# 14:26:07  - Combining OG 13451  with length of  5 	 with a query  98  is just finished.
# 14:26:07  - Combining OG 8441  with length of  7 	 with a query  99  is just finished.
# 14:26:07  - Combining OG 10502  with length of  8 	 with a query  96  is just finished.
# 14:26:07  - Combining OG 12983  with length of  7 	 with a query  96  is just finished.
# 14:26:07  - Combining OG 17488  with length of  6 	 with a query  99  is just finished.
# 14:26:07  - Combining OG 12890  with length of  8 	 with a query  98  is just finished.
# 14:26:07  - Combining OG 9687  with length of  8 	 with a query  98  is just finished.
# 14:26:07  - Combining OG 5447  with length of  6 	 with a query  98  is just finished.
# 14:26:07  - Combining OG 12959  with length of  8 	 with a query  96  is just finished.
# 14:26:07  - Combining OG 8226  with length of  7 	 with a query  97  is just finished.
# 14:26:07  - Combining OG 2910  with length of  8 	 with a query  96  is just finished.
# 14:26:07  - Combining OG 14467  with length of  6 	 with a query  97  is just finished.
# 14:26:07  - Combining OG 3874  with length of  7 	 with a query  98  is just finished.
# 14:26:07  - Combining OG 9839  with length of  8 	 with a query  96  is just finished.
# 14:26:07  - Combining OG 6341  with length of  7 	 with a query  96  is just finished.
# 14:26:07  - Combining OG 23907  with length of  6 	 with a query  96  is just finished.
# 14:26:07  - Combining OG 19198  with length of  8 	 with a query  97  is just finished.
# 14:26:07  - Combining OG 19222  with length of  7 	 with a query  97  is just finished.
# 14:26:07  - Combining OG 10241  with length of  6 	 with a query  96  is just finished.
# 14:26:07  - Combining OG 6897  with length of  6 	 with a query  97  is just finished.
# 14:26:07  - Combining OG 5473  with length of  7 	 with a query  99  is just finished.
# 14:26:07  - Combining OG 2767  with length of  6 	 with a query  97  is just finished.
# 14:26:07  - Combining OG 7254  with length of  8 	 with a query  96  is just finished.
# 14:26:07  - Combining OG 7207  with length of  7 	 with a query  96  is just finished.
# 14:26:07  - Combining OG 11913  with length of  8 	 with a query  97  is just finished.
# 14:26:07  - Combining OG 11434  with length of  8 	 with a query  98  is just finished.
# 14:26:07  - Combining OG 3407  with length of  7 	 with a query  96  is just finished.
# 14:26:08  - Combining OG 5017  with length of  7 	 with a query  96  is just finished.
# 14:26:08  - Combining OG 12543  with length of  6 	 with a query  99  is just finished.
# 14:26:08  - Combining OG 16958  with length of  6 	 with a query  97  is just finished.
# 14:26:08  - Combining OG 2418  with length of  8 	 with a query  98  is just finished.
# 14:26:08  - Combining OG 5626  with length of  8 	 with a query  97  is just finished.
# 14:26:08  - Combining OG 7000  with length of  7 	 with a query  96  is just finished.
# 14:26:08  - Combining OG 8334  with length of  7 	 with a query  96  is just finished.
# 14:26:08  - Combining OG 15435  with length of  6 	 with a query  96  is just finished.
# 14:26:08  - Combining OG 6558  with length of  7 	 with a query  96  is just finished.
# 14:26:08  - Combining OG 13062  with length of  8 	 with a query  96  is just finished.
# 14:26:08  - Combining OG 8757  with length of  4 	 with a query  98  is just finished.
# 14:26:08  - Combining OG 9276  with length of  7 	 with a query  96  is just finished.
# 14:26:08  - Combining OG 2716  with length of  8 	 with a query  99  is just finished.
# 14:26:08  - Combining OG 20763  with length of  5 	 with a query  98  is just finished.
# 14:26:08  - Combining OG 13774  with length of  8 	 with a query  96  is just finished.
# 14:26:08  - Combining OG 4299  with length of  8 	 with a query  97  is just finished.
# 14:26:08  - Combining OG 411  with length of  8 	 with a query  96  is just finished.
# 14:26:08  - Combining OG 7402  with length of  8 	 with a query  96  is just finished.
# 14:26:08  - Combining OG 16806  with length of  7 	 with a query  99  is just finished.
# 14:26:08  - Combining OG 4471  with length of  8 	 with a query  96  is just finished.
# 14:26:08  - Combining OG 15110  with length of  8 	 with a query  97  is just finished.
# 14:26:08  - Combining OG 22702  with length of  4 	 with a query  96  is just finished.
# 14:26:08  - Combining OG 17617  with length of  6 	 with a query  98  is just finished.
# 14:26:08  - Combining OG 18643  with length of  7 	 with a query  98  is just finished.
# 14:26:08  - Combining OG 6204  with length of  8 	 with a query  97  is just finished.
# 14:26:08  - Combining OG 9667  with length of  8 	 with a query  96  is just finished.
# 14:26:08  - Combining OG 2859  with length of  7 	 with a query  97  is just finished.
# 14:26:08  - Combining OG 11042  with length of  7 	 with a query  97  is just finished.
# 14:26:08  - Combining OG 4639  with length of  7 	 with a query  97  is just finished.
# 14:26:08  - Combining OG 12006  with length of  4 	 with a query  98  is just finished.
# 14:26:08  - Combining OG 5197  with length of  6 	 with a query  98  is just finished.
# 14:26:08  - Combining OG 5653  with length of  7 	 with a query  97  is just finished.
# 14:26:08  - Combining OG 12018  with length of  8 	 with a query  96  is just finished.
# 14:26:08  - Combining OG 10127  with length of  8 	 with a query  97  is just finished.
# 14:26:08  - Combining OG 14448  with length of  7 	 with a query  98  is just finished.
# 14:26:08  - Combining OG 3488  with length of  7 	 with a query  96  is just finished.
# 14:26:08  - Combining OG 4074  with length of  8 	 with a query  98  is just finished.
# 14:26:08  - Combining OG 4111  with length of  7 	 with a query  97  is just finished.
# 14:26:08  - Combining OG 11212  with length of  6 	 with a query  97  is just finished.
# 14:26:08  - Combining OG 818  with length of  8 	 with a query  96  is just finished.
# 14:26:08  - Combining OG 8982  with length of  6 	 with a query  96  is just finished.
# 14:26:08  - Combining OG 19949  with length of  8 	 with a query  97  is just finished.
# 14:26:08  - Combining OG 4375  with length of  6 	 with a query  96  is just finished.
# 14:26:08  - Combining OG 5345  with length of  8 	 with a query  97  is just finished.
# 14:26:08  - Combining OG 8845  with length of  7 	 with a query  96  is just finished.
# 14:26:08  - Combining OG 1103  with length of  8 	 with a query  97  is just finished.
# 14:26:08  - Combining OG 8278  with length of  5 	 with a query  97  is just finished.
# 14:26:08  - Combining OG 3225  with length of  6 	 with a query  96  is just finished.
# 14:26:08  - Combining OG 7919  with length of  8 	 with a query  97  is just finished.
# 14:26:08  - Combining OG 832  with length of  7 	 with a query  97  is just finished.
# 14:26:08  - Combining OG 13455  with length of  7 	 with a query  97  is just finished.
# 14:26:08  - Combining OG 8056  with length of  7 	 with a query  97  is just finished.
# 14:26:08  - Combining OG 1765  with length of  6 	 with a query  96  is just finished.
# 14:26:08  - Combining OG 10887  with length of  8 	 with a query  96  is just finished.
# 14:26:08  - Combining OG 1001  with length of  7 	 with a query  99  is just finished.
# 14:26:08  - Combining OG 6778  with length of  7 	 with a query  97  is just finished.
# 14:26:08  - Combining OG 17523  with length of  8 	 with a query  99  is just finished.
# 14:26:08  - Combining OG 17286  with length of  8 	 with a query  96  is just finished.
# 14:26:08  - Combining OG 3440  with length of  7 	 with a query  99  is just finished.
# 14:26:08  - Combining OG 20603  with length of  7 	 with a query  99  is just finished.
# 14:26:08  - Combining OG 5360  with length of  8 	 with a query  96  is just finished.
# 14:26:08  - Combining OG 2598  with length of  8 	 with a query  96  is just finished.
# 14:26:08  - Combining OG 11504  with length of  8 	 with a query  96  is just finished.
# 14:26:08  - Combining OG 23466  with length of  2 	 with a query  96  is just finished.
# 14:26:08  - Combining OG 11107  with length of  8 	 with a query  97  is just finished.
# 14:26:08  - Combining OG 7583  with length of  6 	 with a query  97  is just finished.
# 14:26:08  - Combining OG 10626  with length of  7 	 with a query  97  is just finished.
# 14:26:08  - Combining OG 11560  with length of  8 	 with a query  97  is just finished.
# 14:26:08  - Combining OG 3458  with length of  7 	 with a query  98  is just finished.
# 14:26:08  - Combining OG 7890  with length of  6 	 with a query  99  is just finished.
# 14:26:08  - Combining OG 5054  with length of  5 	 with a query  99  is just finished.
# 14:26:08  - Combining OG 10695  with length of  8 	 with a query  96  is just finished.
# 14:26:08  - Combining OG 1911  with length of  8 	 with a query  97  is just finished.
# 14:26:08  - Combining OG 8771  with length of  7 	 with a query  96  is just finished.
# 14:26:08  - Combining OG 9576  with length of  6 	 with a query  97  is just finished.
# 14:26:08  - Combining OG 2522  with length of  8 	 with a query  97  is just finished.
# 14:26:08  - Combining OG 17641  with length of  7 	 with a query  97  is just finished.
# 14:26:08  - Combining OG 10229  with length of  5 	 with a query  96  is just finished.
# 14:26:08  - Combining OG 14927  with length of  6 	 with a query  96  is just finished.
# 14:26:08  - Combining OG 9747  with length of  8 	 with a query  96  is just finished.
# 14:26:08  - Combining OG 8557  with length of  6 	 with a query  98  is just finished.
# 14:26:08  - Combining OG 13246  with length of  6 	 with a query  96  is just finished.
# 14:26:08  - Combining OG 14127  with length of  7 	 with a query  98  is just finished.
# 14:26:08  - Combining OG 2275  with length of  8 	 with a query  100  is just finished.
# 14:26:08  - Combining OG 7559  with length of  7 	 with a query  97  is just finished.
# 14:26:08  - Combining OG 6390  with length of  8 	 with a query  98  is just finished.
# 14:26:08  - Combining OG 17175  with length of  7 	 with a query  96  is just finished.
# 14:26:08  - Combining OG 16247  with length of  7 	 with a query  96  is just finished.
# 14:26:08  - Combining OG 11300  with length of  8 	 with a query  96  is just finished.
# 14:26:08  - Combining OG 9088  with length of  8 	 with a query  98  is just finished.
# 14:26:08  - Combining OG 10886  with length of  7 	 with a query  96  is just finished.
# 14:26:08  - Combining OG 20664  with length of  7 	 with a query  97  is just finished.
# 14:26:08  - Combining OG 9696  with length of  8 	 with a query  96  is just finished.
# 14:26:08  - Combining OG 4343  with length of  7 	 with a query  99  is just finished.
# 14:26:08  - Combining OG 5907  with length of  8 	 with a query  96  is just finished.
# 14:26:08  - Combining OG 6667  with length of  8 	 with a query  98  is just finished.
# 14:26:08  - Combining OG 20540  with length of  8 	 with a query  98  is just finished.
# 14:26:08  - Combining OG 16840  with length of  7 	 with a query  97  is just finished.
# 14:26:08  - Combining OG 5312  with length of  7 	 with a query  97  is just finished.
# 14:26:08  - Combining OG 2694  with length of  7 	 with a query  96  is just finished.
# 14:26:08  - Combining OG 1143  with length of  8 	 with a query  97  is just finished.
# 14:26:08  - Combining OG 13024  with length of  6 	 with a query  96  is just finished.
# 14:26:08  - Combining OG 18829  with length of  6 	 with a query  96  is just finished.
# 14:26:08  - Combining OG 17518  with length of  8 	 with a query  96  is just finished.
# 14:26:08  - Combining OG 9847  with length of  4 	 with a query  96  is just finished.
# 14:26:08  - Combining OG 15969  with length of  8 	 with a query  99  is just finished.
# 14:26:08  - Combining OG 14822  with length of  7 	 with a query  96  is just finished.
# 14:26:08  - Combining OG 18962  with length of  7 	 with a query  96  is just finished.
# 14:26:08  - Combining OG 9188  with length of  6 	 with a query  96  is just finished.
# 14:26:08  - Combining OG 7994  with length of  8 	 with a query  96  is just finished.
# 14:26:08  - Combining OG 14235  with length of  5 	 with a query  96  is just finished.
# 14:26:08  - Combining OG 1722  with length of  8 	 with a query  96  is just finished.
# 14:26:08  - Combining OG 4185  with length of  8 	 with a query  97  is just finished.
# 14:26:08  - Combining OG 9668  with length of  8 	 with a query  96  is just finished.
# 14:26:08  - Combining OG 1155  with length of  8 	 with a query  96  is just finished.
# 14:26:08  - Combining OG 10383  with length of  6 	 with a query  98  is just finished.
# 14:26:08  - Combining OG 17410  with length of  7 	 with a query  96  is just finished.
# 14:26:08  - Combining OG 9683  with length of  8 	 with a query  96  is just finished.
# 14:26:08  - Combining OG 4279  with length of  7 	 with a query  97  is just finished.
# 14:26:08  - Combining OG 461  with length of  8 	 with a query  97  is just finished.
# 14:26:08  - Combining OG 16759  with length of  5 	 with a query  97  is just finished.
# 14:26:08  - Combining OG 13718  with length of  6 	 with a query  97  is just finished.
# 14:26:08  - Combining OG 9226  with length of  5 	 with a query  98  is just finished.
# 14:26:08  - Combining OG 4431  with length of  5 	 with a query  98  is just finished.
# 14:26:08  - Combining OG 13069  with length of  7 	 with a query  100  is just finished.
# 14:26:08  - Combining OG 8151  with length of  4 	 with a query  96  is just finished.
# 14:26:08  - Combining OG 13180  with length of  8 	 with a query  98  is just finished.
# 14:26:08  - Combining OG 12179  with length of  6 	 with a query  96  is just finished.
# 14:26:08  - Combining OG 7299  with length of  8 	 with a query  96  is just finished.
# 14:26:08  - Combining OG 14972  with length of  8 	 with a query  96  is just finished.
# 14:26:08  - Combining OG 2364  with length of  6 	 with a query  96  is just finished.
# 14:26:08  - Combining OG 10405  with length of  6 	 with a query  96  is just finished.
# 14:26:08  - Combining OG 4007  with length of  8 	 with a query  96  is just finished.
# 14:26:08  - Combining OG 4096  with length of  7 	 with a query  96  is just finished.
# 14:26:08  - Combining OG 4242  with length of  7 	 with a query  96  is just finished.
# 14:26:08  - Combining OG 18257  with length of  7 	 with a query  96  is just finished.
# 14:26:08  - Combining OG 12059  with length of  8 	 with a query  96  is just finished.
# 14:26:08  - Combining OG 7407  with length of  6 	 with a query  98  is just finished.
# 14:26:08  - Combining OG 17776  with length of  7 	 with a query  97  is just finished.
# 14:26:08  - Combining OG 4268  with length of  8 	 with a query  97  is just finished.
# 14:26:08  - Combining OG 9718  with length of  7 	 with a query  97  is just finished.
# 14:26:08  - Combining OG 4568  with length of  8 	 with a query  96  is just finished.
# 14:26:08  - Combining OG 4429  with length of  7 	 with a query  96  is just finished.
# 14:26:08  - Combining OG 12814  with length of  8 	 with a query  96  is just finished.
# 14:26:08  - Combining OG 19494  with length of  6 	 with a query  98  is just finished.
# 14:26:08  - Combining OG 17760  with length of  8 	 with a query  97  is just finished.
# 14:26:09  - Combining OG 9460  with length of  7 	 with a query  97  is just finished.
# 14:26:09  - Combining OG 14067  with length of  7 	 with a query  99  is just finished.
# 14:26:09  - Combining OG 4544  with length of  6 	 with a query  96  is just finished.
# 14:26:09  - Combining OG 1219  with length of  8 	 with a query  98  is just finished.
# 14:26:09  - Combining OG 10912  with length of  8 	 with a query  96  is just finished.
# 14:26:09  - Combining OG 1896  with length of  8 	 with a query  99  is just finished.
# 14:26:09  - Combining OG 6599  with length of  8 	 with a query  97  is just finished.
# 14:26:09  - Combining OG 10896  with length of  8 	 with a query  96  is just finished.
# 14:26:09  - Combining OG 14879  with length of  8 	 with a query  98  is just finished.
# 14:26:09  - Combining OG 5339  with length of  7 	 with a query  96  is just finished.
# 14:26:09  - Combining OG 2815  with length of  7 	 with a query  97  is just finished.
# 14:26:09  - Combining OG 11195  with length of  5 	 with a query  96  is just finished.
# 14:26:09  - Combining OG 9253  with length of  6 	 with a query  96  is just finished.
# 14:26:09  - Combining OG 13300  with length of  7 	 with a query  96  is just finished.
# 14:26:09  - Combining OG 13803  with length of  6 	 with a query  96  is just finished.
# 14:26:09  - Combining OG 9562  with length of  7 	 with a query  96  is just finished.
# 14:26:09  - Combining OG 14525  with length of  6 	 with a query  96  is just finished.
# 14:26:09  - Combining OG 13623  with length of  7 	 with a query  97  is just finished.
# 14:26:09  - Combining OG 25155  with length of  6 	 with a query  96  is just finished.
# 14:26:09  - Combining OG 9003  with length of  4 	 with a query  96  is just finished.
# 14:26:09  - Combining OG 8723  with length of  5 	 with a query  98  is just finished.
# 14:26:09  - Combining OG 10960  with length of  8 	 with a query  99  is just finished.
# 14:26:09  - Combining OG 4300  with length of  7 	 with a query  97  is just finished.
# 14:26:09  - Combining OG 3981  with length of  8 	 with a query  96  is just finished.
# 14:26:09  - Combining OG 3794  with length of  8 	 with a query  96  is just finished.
# 14:26:09  - Combining OG 2670  with length of  8 	 with a query  96  is just finished.
# 14:26:09  - Combining OG 21731  with length of  5 	 with a query  96  is just finished.
# 14:26:09  - Combining OG 13923  with length of  7 	 with a query  96  is just finished.
# 14:26:09  - Combining OG 1831  with length of  8 	 with a query  98  is just finished.
# 14:26:09  - Combining OG 12815  with length of  8 	 with a query  96  is just finished.
# 14:26:09  - Combining OG 11595  with length of  8 	 with a query  96  is just finished.
# 14:26:09  - Combining OG 5933  with length of  8 	 with a query  97  is just finished.
# 14:26:09  - Combining OG 13967  with length of  8 	 with a query  97  is just finished.
# 14:26:09  - Combining OG 13336  with length of  5 	 with a query  97  is just finished.
# 14:26:09  - Combining OG 1858  with length of  7 	 with a query  96  is just finished.
# 14:26:09  - Combining OG 13553  with length of  6 	 with a query  97  is just finished.
# 14:26:09  - Combining OG 11863  with length of  8 	 with a query  98  is just finished.
# 14:26:09  - Combining OG 10380  with length of  8 	 with a query  96  is just finished.
# 14:26:09  - Combining OG 6669  with length of  8 	 with a query  97  is just finished.
# 14:26:09  - Combining OG 14369  with length of  8 	 with a query  96  is just finished.
# 14:26:09  - Combining OG 18675  with length of  7 	 with a query  97  is just finished.
# 14:26:09  - Combining OG 18601  with length of  6 	 with a query  96  is just finished.
# 14:26:09  - Combining OG 20484  with length of  7 	 with a query  96  is just finished.
# 14:26:09  - Combining OG 17321  with length of  6 	 with a query  96  is just finished.
# 14:26:09  - Combining OG 9936  with length of  8 	 with a query  96  is just finished.
# 14:26:09  - Combining OG 4467  with length of  8 	 with a query  96  is just finished.
# 14:26:09  - Combining OG 19371  with length of  7 	 with a query  96  is just finished.
# 14:26:09  - Combining OG 20768  with length of  6 	 with a query  98  is just finished.
# 14:26:09  - Combining OG 5700  with length of  6 	 with a query  97  is just finished.
# 14:26:09  - Combining OG 22592  with length of  7 	 with a query  96  is just finished.
# 14:26:09  - Combining OG 13372  with length of  7 	 with a query  99  is just finished.
# 14:26:09  - Combining OG 13875  with length of  5 	 with a query  98  is just finished.
# 14:26:09  - Combining OG 5210  with length of  4 	 with a query  97  is just finished.
# 14:26:09  - Combining OG 6127  with length of  8 	 with a query  96  is just finished.
# 14:26:09  - Combining OG 6743  with length of  7 	 with a query  96  is just finished.
# 14:26:09  - Combining OG 1880  with length of  8 	 with a query  97  is just finished.
# 14:26:09  - Combining OG 4523  with length of  8 	 with a query  96  is just finished.
# 14:26:09  - Combining OG 16668  with length of  7 	 with a query  98  is just finished.
# 14:26:09  - Combining OG 19794  with length of  8 	 with a query  96  is just finished.
# 14:26:09  - Combining OG 1804  with length of  6 	 with a query  96  is just finished.
# 14:26:09  - Combining OG 16015  with length of  6 	 with a query  96  is just finished.
# 14:26:09  - Combining OG 2269  with length of  8 	 with a query  96  is just finished.
# 14:26:09  - Combining OG 8456  with length of  7 	 with a query  98  is just finished.
# 14:26:09  - Combining OG 1935  with length of  7 	 with a query  96  is just finished.
# 14:26:09  - Combining OG 13043  with length of  5 	 with a query  98  is just finished.
# 14:26:09  - Combining OG 20456  with length of  6 	 with a query  98  is just finished.
# 14:26:09  - Combining OG 4689  with length of  7 	 with a query  97  is just finished.
# 14:26:09  - Combining OG 6883  with length of  8 	 with a query  96  is just finished.
# 14:26:09  - Combining OG 8867  with length of  6 	 with a query  96  is just finished.
# 14:26:09  - Combining OG 24013  with length of  6 	 with a query  97  is just finished.
# 14:26:09  - Combining OG 22270  with length of  6 	 with a query  96  is just finished.
# 14:26:09  - Combining OG 8485  with length of  7 	 with a query  96  is just finished.
# 14:26:09  - Combining OG 16635  with length of  8 	 with a query  97  is just finished.
# 14:26:09  - Combining OG 7400  with length of  8 	 with a query  98  is just finished.
# 14:26:09  - Combining OG 1998  with length of  8 	 with a query  99  is just finished.
# 14:26:09  - Combining OG 15529  with length of  7 	 with a query  98  is just finished.
# 14:26:09  - Combining OG 8900  with length of  8 	 with a query  99  is just finished.
# 14:26:09  - Combining OG 6677  with length of  8 	 with a query  96  is just finished.
# 14:26:09  - Combining OG 12781  with length of  6 	 with a query  97  is just finished.
# 14:26:09  - Combining OG 17912  with length of  8 	 with a query  96  is just finished.
# 14:26:09  - Combining OG 2819  with length of  8 	 with a query  96  is just finished.
# 14:26:09  - Combining OG 5393  with length of  7 	 with a query  97  is just finished.
# 14:26:09  - Combining OG 10412  with length of  8 	 with a query  96  is just finished.
# 14:26:09  - Combining OG 10005  with length of  8 	 with a query  96  is just finished.
# 14:26:09  - Combining OG 4623  with length of  8 	 with a query  96  is just finished.
# 14:26:09  - Combining OG 7846  with length of  8 	 with a query  97  is just finished.
# 14:26:09  - Combining OG 5926  with length of  7 	 with a query  96  is just finished.
# 14:26:09  - Combining OG 10845  with length of  8 	 with a query  96  is just finished.
# 14:26:09  - Combining OG 15616  with length of  8 	 with a query  97  is just finished.
# 14:26:09  - Combining OG 17598  with length of  6 	 with a query  97  is just finished.
# 14:26:09  - Combining OG 5694  with length of  8 	 with a query  96  is just finished.
# 14:26:09  - Combining OG 5860  with length of  8 	 with a query  97  is just finished.
# 14:26:09  - Combining OG 7267  with length of  8 	 with a query  98  is just finished.
# 14:26:09  - Combining OG 14099  with length of  8 	 with a query  96  is just finished.
# 14:26:09  - Combining OG 11114  with length of  6 	 with a query  98  is just finished.
# 14:26:09  - Combining OG 7371  with length of  6 	 with a query  97  is just finished.
# 14:26:09  - Combining OG 3880  with length of  8 	 with a query  97  is just finished.
# 14:26:09  - Combining OG 4130  with length of  7 	 with a query  98  is just finished.
# 14:26:09  - Combining OG 10098  with length of  5 	 with a query  97  is just finished.
# 14:26:09  - Combining OG 12095  with length of  7 	 with a query  98  is just finished.
# 14:26:09  - Combining OG 7644  with length of  8 	 with a query  97  is just finished.
# 14:26:09  - Combining OG 19184  with length of  6 	 with a query  97  is just finished.
# 14:26:09  - Combining OG 18150  with length of  8 	 with a query  96  is just finished.
# 14:26:09  - Combining OG 14789  with length of  6 	 with a query  99  is just finished.
# 14:26:09  - Combining OG 11315  with length of  7 	 with a query  98  is just finished.
# 14:26:09  - Combining OG 10196  with length of  8 	 with a query  96  is just finished.
# 14:26:09  - Combining OG 10249  with length of  5 	 with a query  97  is just finished.
# 14:26:09  - Combining OG 22647  with length of  5 	 with a query  97  is just finished.
# 14:26:09  - Combining OG 12555  with length of  8 	 with a query  96  is just finished.
# 14:26:09  - Combining OG 5849  with length of  8 	 with a query  98  is just finished.
# 14:26:09  - Combining OG 12682  with length of  8 	 with a query  98  is just finished.
# 14:26:09  - Combining OG 5635  with length of  8 	 with a query  99  is just finished.
# 14:26:09  - Combining OG 13316  with length of  7 	 with a query  96  is just finished.
# 14:26:09  - Combining OG 4168  with length of  7 	 with a query  96  is just finished.
# 14:26:09  - Combining OG 8302  with length of  7 	 with a query  96  is just finished.
# 14:26:09  - Combining OG 9681  with length of  7 	 with a query  96  is just finished.
# 14:26:09  - Combining OG 15427  with length of  6 	 with a query  97  is just finished.
# 14:26:09  - Combining OG 1942  with length of  8 	 with a query  96  is just finished.
# 14:26:09  - Combining OG 14040  with length of  7 	 with a query  97  is just finished.
# 14:26:09  - Combining OG 13037  with length of  7 	 with a query  97  is just finished.
# 14:26:09  - Combining OG 4526  with length of  7 	 with a query  96  is just finished.
# 14:26:09  - Combining OG 1952  with length of  8 	 with a query  97  is just finished.
# 14:26:09  - Combining OG 19205  with length of  6 	 with a query  97  is just finished.
# 14:26:09  - Combining OG 12667  with length of  8 	 with a query  98  is just finished.
# 14:26:09  - Combining OG 9435  with length of  8 	 with a query  96  is just finished.
# 14:26:09  - Combining OG 11117  with length of  7 	 with a query  96  is just finished.
# 14:26:09  - Combining OG 3729  with length of  7 	 with a query  96  is just finished.
# 14:26:09  - Combining OG 12853  with length of  7 	 with a query  97  is just finished.
# 14:26:09  - Combining OG 7685  with length of  6 	 with a query  97  is just finished.
# 14:26:09  - Combining OG 12849  with length of  6 	 with a query  96  is just finished.
# 14:26:09  - Combining OG 15860  with length of  7 	 with a query  98  is just finished.
# 14:26:09  - Combining OG 12153  with length of  7 	 with a query  98  is just finished.
# 14:26:09  - Combining OG 11828  with length of  8 	 with a query  96  is just finished.
# 14:26:09  - Combining OG 8502  with length of  8 	 with a query  98  is just finished.
# 14:26:09  - Combining OG 14633  with length of  6 	 with a query  96  is just finished.
# 14:26:09  - Combining OG 8716  with length of  7 	 with a query  99  is just finished.
# 14:26:09  - Combining OG 15868  with length of  6 	 with a query  96  is just finished.
# 14:26:09  - Combining OG 4815  with length of  7 	 with a query  96  is just finished.
# 14:26:09  - Combining OG 5407  with length of  8 	 with a query  96  is just finished.
# 14:26:09  - Combining OG 6602  with length of  8 	 with a query  96  is just finished.
# 14:26:09  - Combining OG 1255  with length of  8 	 with a query  96  is just finished.
# 14:26:09  - Combining OG 9470  with length of  8 	 with a query  96  is just finished.
# 14:26:09  - Combining OG 5424  with length of  8 	 with a query  96  is just finished.
# 14:26:09  - Combining OG 4508  with length of  8 	 with a query  97  is just finished.
# 14:26:09  - Combining OG 5247  with length of  8 	 with a query  96  is just finished.
# 14:26:09  - Combining OG 9467  with length of  7 	 with a query  96  is just finished.
# 14:26:09  - Combining OG 21048  with length of  7 	 with a query  96  is just finished.
# 14:26:09  - Combining OG 14546  with length of  6 	 with a query  96  is just finished.
# 14:26:09  - Combining OG 13737  with length of  5 	 with a query  96  is just finished.
# 14:26:09  - Combining OG 2615  with length of  6 	 with a query  96  is just finished.
# 14:26:09  - Combining OG 7781  with length of  7 	 with a query  99  is just finished.
# 14:26:09  - Combining OG 10936  with length of  8 	 with a query  97  is just finished.
# 14:26:10  - Combining OG 9428  with length of  8 	 with a query  96  is just finished.
# 14:26:10  - Combining OG 23158  with length of  6 	 with a query  96  is just finished.
# 14:26:10  - Combining OG 8614  with length of  8 	 with a query  97  is just finished.
# 14:26:10  - Combining OG 19289  with length of  8 	 with a query  96  is just finished.
# 14:26:10  - Combining OG 1782  with length of  7 	 with a query  96  is just finished.
# 14:26:10  - Combining OG 2207  with length of  8 	 with a query  96  is just finished.
# 14:26:10  - Combining OG 9291  with length of  8 	 with a query  97  is just finished.
# 14:26:10  - Combining OG 10855  with length of  7 	 with a query  96  is just finished.
# 14:26:10  - Combining OG 3322  with length of  7 	 with a query  97  is just finished.
# 14:26:10  - Combining OG 3420  with length of  6 	 with a query  96  is just finished.
# 14:26:10  - Combining OG 16826  with length of  6 	 with a query  96  is just finished.
# 14:26:10  - Combining OG 17756  with length of  8 	 with a query  97  is just finished.
# 14:26:10  - Combining OG 26314  with length of  7 	 with a query  96  is just finished.
# 14:26:10  - Combining OG 1110  with length of  7 	 with a query  97  is just finished.
# 14:26:10  - Combining OG 12679  with length of  7 	 with a query  96  is just finished.
# 14:26:10  - Combining OG 11024  with length of  8 	 with a query  97  is just finished.
# 14:26:10  - Combining OG 11988  with length of  6 	 with a query  97  is just finished.
# 14:26:10  - Combining OG 3354  with length of  8 	 with a query  98  is just finished.
# 14:26:10  - Combining OG 7906  with length of  7 	 with a query  97  is just finished.
# 14:26:10  - Combining OG 17895  with length of  8 	 with a query  96  is just finished.
# 14:26:10  - Combining OG 10367  with length of  8 	 with a query  97  is just finished.
# 14:26:10  - Combining OG 8393  with length of  6 	 with a query  99  is just finished.
# 14:26:10  - Combining OG 11919  with length of  6 	 with a query  96  is just finished.
# 14:26:10  - Combining OG 13231  with length of  7 	 with a query  97  is just finished.
# 14:26:10  - Combining OG 12275  with length of  6 	 with a query  98  is just finished.
# 14:26:10  - Combining OG 10657  with length of  7 	 with a query  97  is just finished.
# 14:26:10  - Combining OG 9899  with length of  6 	 with a query  96  is just finished.
# 14:26:10  - Combining OG 5304  with length of  8 	 with a query  96  is just finished.
# 14:26:10  - Combining OG 24172  with length of  6 	 with a query  98  is just finished.
# 14:26:10  - Combining OG 9446  with length of  6 	 with a query  97  is just finished.
# 14:26:10  - Combining OG 9149  with length of  8 	 with a query  98  is just finished.
# 14:26:10  - Combining OG 13957  with length of  7 	 with a query  97  is just finished.
# 14:26:10  - Combining OG 19604  with length of  8 	 with a query  97  is just finished.
# 14:26:10  - Combining OG 5643  with length of  7 	 with a query  96  is just finished.
# 14:26:10  - Combining OG 15079  with length of  7 	 with a query  97  is just finished.
# 14:26:10  - Combining OG 13099  with length of  8 	 with a query  97  is just finished.
# 14:26:10  - Combining OG 12850  with length of  8 	 with a query  96  is just finished.
# 14:26:10  - Combining OG 4859  with length of  8 	 with a query  96  is just finished.
# 14:26:10  - Combining OG 17746  with length of  7 	 with a query  96  is just finished.
# 14:26:10  - Combining OG 19388  with length of  6 	 with a query  98  is just finished.
# 14:26:10  - Combining OG 15689  with length of  7 	 with a query  97  is just finished.
# 14:26:10  - Combining OG 14859  with length of  8 	 with a query  96  is just finished.
# 14:26:10  - Combining OG 6246  with length of  8 	 with a query  97  is just finished.
# 14:26:10  - Combining OG 16919  with length of  5 	 with a query  96  is just finished.
# 14:26:10  - Combining OG 3868  with length of  8 	 with a query  97  is just finished.
# 14:26:10  - Combining OG 2957  with length of  8 	 with a query  99  is just finished.
# 14:26:10  - Combining OG 5279  with length of  6 	 with a query  99  is just finished.
# 14:26:10  - Combining OG 7885  with length of  8 	 with a query  99  is just finished.
# 14:26:10  - Combining OG 5065  with length of  7 	 with a query  98  is just finished.
# 14:26:10  - Combining OG 19642  with length of  8 	 with a query  96  is just finished.
# 14:26:10  - Combining OG 9716  with length of  7 	 with a query  96  is just finished.
# 14:26:10  - Combining OG 14512  with length of  5 	 with a query  96  is just finished.
# 14:26:10  - Combining OG 4954  with length of  8 	 with a query  96  is just finished.
# 14:26:10  - Combining OG 18438  with length of  6 	 with a query  99  is just finished.
# 14:26:10  - Combining OG 16971  with length of  8 	 with a query  98  is just finished.
# 14:26:10  - Combining OG 11636  with length of  6 	 with a query  96  is just finished.
# 14:26:10  - Combining OG 2063  with length of  8 	 with a query  98  is just finished.
# 14:26:10  - Combining OG 3060  with length of  8 	 with a query  97  is just finished.
# 14:26:10  - Combining OG 2444  with length of  8 	 with a query  97  is just finished.
# 14:26:10  - Combining OG 7125  with length of  8 	 with a query  99  is just finished.
# 14:26:10  - Combining OG 4711  with length of  8 	 with a query  97  is just finished.
# 14:26:10  - Combining OG 2100  with length of  8 	 with a query  97  is just finished.
# 14:26:10  - Combining OG 12236  with length of  8 	 with a query  98  is just finished.
# 14:26:10  - Combining OG 9315  with length of  8 	 with a query  96  is just finished.
# 14:26:10  - Combining OG 800  with length of  8 	 with a query  96  is just finished.
# 14:26:10  - Combining OG 1770  with length of  8 	 with a query  96  is just finished.
# 14:26:10  - Combining OG 14305  with length of  7 	 with a query  97  is just finished.
# 14:26:10  - Combining OG 7023  with length of  7 	 with a query  97  is just finished.
# 14:26:10  - Combining OG 7015  with length of  4 	 with a query  97  is just finished.
# 14:26:10  - Combining OG 19163  with length of  6 	 with a query  97  is just finished.
# 14:26:10  - Combining OG 6852  with length of  8 	 with a query  96  is just finished.
# 14:26:10  - Combining OG 10865  with length of  7 	 with a query  96  is just finished.
# 14:26:10  - Combining OG 2941  with length of  6 	 with a query  98  is just finished.
# 14:26:10  - Combining OG 14606  with length of  6 	 with a query  97  is just finished.
# 14:26:10  - Combining OG 7282  with length of  8 	 with a query  97  is just finished.
# 14:26:10  - Combining OG 10160  with length of  5 	 with a query  96  is just finished.
# 14:26:10  - Combining OG 7336  with length of  8 	 with a query  99  is just finished.
# 14:26:10  - Combining OG 21620  with length of  5 	 with a query  97  is just finished.
# 14:26:10  - Combining OG 4284  with length of  8 	 with a query  97  is just finished.
# 14:26:10  - Combining OG 21636  with length of  6 	 with a query  98  is just finished.
# 14:26:10  - Combining OG 7448  with length of  7 	 with a query  97  is just finished.
# 14:26:10  - Combining OG 1445  with length of  8 	 with a query  96  is just finished.
# 14:26:10  - Combining OG 12176  with length of  8 	 with a query  100  is just finished.
# 14:26:10  - Combining OG 2093  with length of  8 	 with a query  97  is just finished.
# 14:26:10  - Combining OG 9301  with length of  8 	 with a query  96  is just finished.
# 14:26:10  - Combining OG 4632  with length of  8 	 with a query  96  is just finished.
# 14:26:10  - Combining OG 11027  with length of  7 	 with a query  97  is just finished.
# 14:26:10  - Combining OG 5975  with length of  6 	 with a query  98  is just finished.
# 14:26:10  - Combining OG 2891  with length of  7 	 with a query  96  is just finished.
# 14:26:10  - Combining OG 9993  with length of  6 	 with a query  96  is just finished.
# 14:26:10  - Combining OG 24453  with length of  8 	 with a query  96  is just finished.
# 14:26:10  - Combining OG 18352  with length of  8 	 with a query  97  is just finished.
# 14:26:10  - Combining OG 17892  with length of  7 	 with a query  96  is just finished.
# 14:26:10  - Combining OG 16722  with length of  5 	 with a query  98  is just finished.
# 14:26:10  - Combining OG 8462  with length of  6 	 with a query  96  is just finished.
# 14:26:10  - Combining OG 13735  with length of  8 	 with a query  96  is just finished.
# 14:26:10  - Combining OG 14678  with length of  6 	 with a query  96  is just finished.
# 14:26:10  - Combining OG 15644  with length of  7 	 with a query  97  is just finished.
# 14:26:10  - Combining OG 9119  with length of  8 	 with a query  96  is just finished.
# 14:26:10  - Combining OG 12208  with length of  6 	 with a query  98  is just finished.
# 14:26:10  - Combining OG 12496  with length of  7 	 with a query  96  is just finished.
# 14:26:10  - Combining OG 11549  with length of  5 	 with a query  96  is just finished.
# 14:26:10  - Combining OG 22452  with length of  7 	 with a query  96  is just finished.
# 14:26:10  - Combining OG 11121  with length of  7 	 with a query  97  is just finished.
# 14:26:10  - Combining OG 14081  with length of  8 	 with a query  97  is just finished.
# 14:26:10  - Combining OG 5598  with length of  8 	 with a query  97  is just finished.
# 14:26:10  - Combining OG 14857  with length of  6 	 with a query  97  is just finished.
# 14:26:10  - Combining OG 3422  with length of  8 	 with a query  97  is just finished.
# 14:26:10  - Combining OG 18359  with length of  6 	 with a query  97  is just finished.
# 14:26:10  - Combining OG 13965  with length of  6 	 with a query  97  is just finished.
# 14:26:10  - Combining OG 4206  with length of  7 	 with a query  96  is just finished.
# 14:26:10  - Combining OG 4893  with length of  8 	 with a query  96  is just finished.
# 14:26:10  - Combining OG 16747  with length of  7 	 with a query  100  is just finished.
# 14:26:10  - Combining OG 7863  with length of  6 	 with a query  96  is just finished.
# 14:26:10  - Combining OG 10816  with length of  6 	 with a query  98  is just finished.
# 14:26:10  - Combining OG 9761  with length of  6 	 with a query  98  is just finished.
# 14:26:10  - Combining OG 13383  with length of  8 	 with a query  97  is just finished.
# 14:26:10  - Combining OG 12234  with length of  8 	 with a query  97  is just finished.
# 14:26:10  - Combining OG 10429  with length of  7 	 with a query  97  is just finished.
# 14:26:10  - Combining OG 10239  with length of  7 	 with a query  97  is just finished.
# 14:26:10  - Combining OG 3912  with length of  6 	 with a query  100  is just finished.
# 14:26:10  - Combining OG 9018  with length of  8 	 with a query  98  is just finished.
# 14:26:10  - Combining OG 13021  with length of  7 	 with a query  98  is just finished.
# 14:26:10  - Combining OG 8886  with length of  6 	 with a query  96  is just finished.
# 14:26:10  - Combining OG 9579  with length of  8 	 with a query  96  is just finished.
# 14:26:10  - Combining OG 9645  with length of  8 	 with a query  96  is just finished.
# 14:26:10  - Combining OG 10876  with length of  8 	 with a query  98  is just finished.
# 14:26:10  - Combining OG 4750  with length of  7 	 with a query  96  is just finished.
# 14:26:10  - Combining OG 16553  with length of  7 	 with a query  96  is just finished.
# 14:26:10  - Combining OG 10151  with length of  8 	 with a query  97  is just finished.
# 14:26:10  - Combining OG 12651  with length of  6 	 with a query  97  is just finished.
# 14:26:10  - Combining OG 19888  with length of  8 	 with a query  98  is just finished.
# 14:26:10  - Combining OG 6777  with length of  7 	 with a query  97  is just finished.
# 14:26:10  - Combining OG 10789  with length of  7 	 with a query  97  is just finished.
# 14:26:10  - Combining OG 7295  with length of  8 	 with a query  99  is just finished.
# 14:26:10  - Combining OG 8911  with length of  7 	 with a query  96  is just finished.
# 14:26:10  - Combining OG 14237  with length of  6 	 with a query  97  is just finished.
# 14:26:10  - Combining OG 4582  with length of  8 	 with a query  98  is just finished.
# 14:26:10  - Combining OG 19438  with length of  6 	 with a query  96  is just finished.
# 14:26:10  - Combining OG 12578  with length of  6 	 with a query  96  is just finished.
# 14:26:10  - Combining OG 7481  with length of  7 	 with a query  96  is just finished.
# 14:26:10  - Combining OG 16209  with length of  7 	 with a query  96  is just finished.
# 14:26:10  - Combining OG 1872  with length of  8 	 with a query  96  is just finished.
# 14:26:10  - Combining OG 14362  with length of  5 	 with a query  97  is just finished.
# 14:26:10  - Combining OG 7847  with length of  5 	 with a query  96  is just finished.
# 14:26:10  - Combining OG 1769  with length of  7 	 with a query  98  is just finished.
# 14:26:10  - Combining OG 20345  with length of  7 	 with a query  98  is just finished.
# 14:26:10  - Combining OG 8802  with length of  7 	 with a query  96  is just finished.
# 14:26:10  - Combining OG 8234  with length of  8 	 with a query  98  is just finished.
# 14:26:10  - Combining OG 4830  with length of  8 	 with a query  96  is just finished.
# 14:26:10  - Combining OG 10035  with length of  8 	 with a query  98  is just finished.
# 14:26:11  - Combining OG 17542  with length of  8 	 with a query  99  is just finished.
# 14:26:11  - Combining OG 4747  with length of  8 	 with a query  97  is just finished.
# 14:26:11  - Combining OG 9068  with length of  7 	 with a query  100  is just finished.
# 14:26:11  - Combining OG 15322  with length of  8 	 with a query  96  is just finished.
# 14:26:11  - Combining OG 4786  with length of  7 	 with a query  96  is just finished.
# 14:26:11  - Combining OG 18791  with length of  8 	 with a query  99  is just finished.
# 14:26:11  - Combining OG 11693  with length of  6 	 with a query  99  is just finished.
# ...
# 14:26:16  - Combining OG 17081  with length of  5 	 with a query  97  is just finished.
# 14:26:16  - Combining OG 10100  with length of  6 	 with a query  98  is just finished.
# 14:26:16  - Combining OG 17496  with length of  8 	 with a query  99  is just finished.
# 14:26:16  - Combining OG 10392  with length of  7 	 with a query  98  is just finished.
# 14:26:16  - Combining OG 14251  with length of  8 	 with a query  97  is just finished.
# 14:26:16  - Combining OG 3996  with length of  5 	 with a query  97  is just finished.
# 14:26:16  - Combining OG 18519  with length of  7 	 with a query  96  is just finished.
# 14:26:16  - Combining OG 3784  with length of  6 	 with a query  96  is just finished.
# 14:26:16  - Combining OG 12262  with length of  6 	 with a query  97  is just finished.
# 14:26:16  - Combining OG 6675  with length of  7 	 with a query  97  is just finished.
# 14:26:16  - Combining OG 17415  with length of  7 	 with a query  96  is just finished.
# 14:26:16  - Combining OG 9043  with length of  6 	 with a query  96  is just finished.
# 14:26:16  - Combining OG 8220  with length of  6 	 with a query  96  is just finished.
# 14:26:16  - Combining OG 18600  with length of  6 	 with a query  96  is just finished.
# 14:26:16  - Combining OG 13096  with length of  7 	 with a query  96  is just finished.
# 14:26:16  - Combining OG 10823  with length of  8 	 with a query  96  is just finished.
# 14:26:16  - Combining OG 10242  with length of  8 	 with a query  96  is just finished.
# 14:26:16  - Combining OG 10487  with length of  7 	 with a query  97  is just finished.
# 14:26:16  - Combining OG 4020  with length of  6 	 with a query  98  is just finished.
# 14:26:16  - Combining OG 13640  with length of  8 	 with a query  98  is just finished.
# 14:26:16  - Combining OG 2602  with length of  7 	 with a query  97  is just finished.
# 14:26:16  - Combining OG 16751  with length of  7 	 with a query  96  is just finished.
# 14:26:16  - Combining OG 5413  with length of  8 	 with a query  97  is just finished.
# 14:26:16  - Combining OG 15749  with length of  7 	 with a query  97  is just finished.
# 14:26:16  - Combining OG 6106  with length of  7 	 with a query  97  is just finished.
# 14:26:16  - Combining OG 2576  with length of  8 	 with a query  97  is just finished.
# 14:26:16  - Combining OG 5378  with length of  8 	 with a query  97  is just finished.
# 14:26:16  - Combining OG 19176  with length of  8 	 with a query  96  is just finished.
# 14:26:16  - Combining OG 12371  with length of  8 	 with a query  97  is just finished.
# 14:26:16  - Combining OG 3274  with length of  7 	 with a query  98  is just finished.
# 14:26:16  - Combining OG 7623  with length of  8 	 with a query  96  is just finished.
# 14:26:16  - Combining OG 10123  with length of  8 	 with a query  98  is just finished.
# 14:26:16  - Combining OG 5609  with length of  8 	 with a query  96  is just finished.
# 14:26:16  - Combining OG 10783  with length of  7 	 with a query  97  is just finished.
# 14:26:16  - Combining OG 3775  with length of  8 	 with a query  97  is just finished.
# 14:26:16  - Combining OG 8464  with length of  7 	 with a query  97  is just finished.
# 14:26:16  - Combining OG 13248  with length of  4 	 with a query  97  is just finished.
# 14:26:16  - Combining OG 5547  with length of  6 	 with a query  97  is just finished.
# 14:26:16  - Combining OG 8418  with length of  8 	 with a query  97  is just finished.
# 14:26:16  - Combining OG 8482  with length of  8 	 with a query  98  is just finished.
# 14:26:16  - Combining OG 9994  with length of  5 	 with a query  97  is just finished.
# 14:26:16  - Combining OG 6905  with length of  6 	 with a query  96  is just finished.
# 14:26:16  - Combining OG 11874  with length of  7 	 with a query  96  is just finished.
# 14:26:16  - Combining OG 6821  with length of  8 	 with a query  96  is just finished.
# 14:26:16  - Combining OG 9454  with length of  7 	 with a query  98  is just finished.
# 14:26:16  - Combining OG 11718  with length of  6 	 with a query  96  is just finished.
# 14:26:16  - Combining OG 17113  with length of  7 	 with a query  97  is just finished.
# 14:26:16  - Combining OG 2358  with length of  8 	 with a query  96  is just finished.
# 14:26:16  - Combining OG 13826  with length of  6 	 with a query  99  is just finished.
# 14:26:16  - Combining OG 5001  with length of  8 	 with a query  96  is just finished.
# 14:26:16  - Combining OG 7146  with length of  7 	 with a query  96  is just finished.
# 14:26:16  - Combining OG 2148  with length of  7 	 with a query  97  is just finished.
# 14:26:16  - Combining OG 8711  with length of  7 	 with a query  97  is just finished.
# 14:26:16  - Combining OG 6537  with length of  6 	 with a query  96  is just finished.
# 14:26:16  - Combining OG 6098  with length of  8 	 with a query  98  is just finished.
# 14:26:16  - Combining OG 5828  with length of  7 	 with a query  96  is just finished.
# 14:26:16  - Combining OG 6136  with length of  7 	 with a query  99  is just finished.
# 14:26:16  - Combining OG 4725  with length of  7 	 with a query  96  is just finished.
# 14:26:16  - Combining OG 2283  with length of  8 	 with a query  96  is just finished.
# 14:26:16  - Combining OG 5722  with length of  8 	 with a query  96  is just finished.
# 14:26:16  - Combining OG 10917  with length of  4 	 with a query  96  is just finished.
# 14:26:16  - Combining OG 9144  with length of  8 	 with a query  99  is just finished.
# 14:26:16  - Combining OG 10561  with length of  7 	 with a query  98  is just finished.
# 14:26:16  - Combining OG 10473  with length of  8 	 with a query  98  is just finished.
# 14:26:16  - Combining OG 14774  with length of  7 	 with a query  96  is just finished.
# 14:26:16  - Combining OG 18612  with length of  6 	 with a query  99  is just finished.
# 14:26:16  - Combining OG 4578  with length of  7 	 with a query  96  is just finished.
# 14:26:16  - Combining OG 11168  with length of  7 	 with a query  96  is just finished.
# 14:26:16  - Combining OG 11631  with length of  5 	 with a query  96  is just finished.
# 14:26:17  - Combining OG 6619  with length of  8 	 with a query  99  is just finished.
# 14:26:17  - Combining OG 5621  with length of  7 	 with a query  98  is just finished.
# 14:26:17  - Combining OG 7754  with length of  8 	 with a query  97  is just finished.
# 14:26:17  - Combining OG 7213  with length of  7 	 with a query  98  is just finished.
# 14:26:17  - Combining OG 16027  with length of  6 	 with a query  99  is just finished.
# 14:26:17  - Combining OG 22923  with length of  6 	 with a query  97  is just finished.
# 14:26:17  - Combining OG 6729  with length of  7 	 with a query  98  is just finished.
# 14:26:17  - Combining OG 22797  with length of  8 	 with a query  96  is just finished.
# 14:26:17  - Combining OG 15038  with length of  7 	 with a query  96  is just finished.
# 14:26:17  - Combining OG 2546  with length of  8 	 with a query  96  is just finished.
# 14:26:17  - Combining OG 10336  with length of  7 	 with a query  96  is just finished.
# 14:26:17  - Combining OG 3625  with length of  7 	 with a query  96  is just finished.
# 14:26:17  - Combining OG 730  with length of  8 	 with a query  96  is just finished.
# 14:26:17  - Combining OG 20346  with length of  5 	 with a query  97  is just finished.
# 14:26:17  - Combining OG 10628  with length of  8 	 with a query  98  is just finished.
# 14:26:17  - Combining OG 6973  with length of  3 	 with a query  96  is just finished.
# 14:26:17  - Combining OG 5897  with length of  8 	 with a query  97  is just finished.
# 14:26:17  - Combining OG 4159  with length of  6 	 with a query  97  is just finished.
# 14:26:17  - Combining OG 7428  with length of  8 	 with a query  97  is just finished.
# 14:26:17  - Combining OG 8206  with length of  5 	 with a query  96  is just finished.
# 14:26:17  - Combining OG 10963  with length of  6 	 with a query  96  is just finished.
# 14:26:17  - Combining OG 1027  with length of  8 	 with a query  96  is just finished.
# 14:26:17  - Combining OG 4066  with length of  8 	 with a query  98  is just finished.
# 14:26:17  - Combining OG 16877  with length of  8 	 with a query  96  is just finished.
# 14:26:17  - Combining OG 4732  with length of  7 	 with a query  96  is just finished.
# 14:26:17  - Combining OG 12774  with length of  8 	 with a query  96  is just finished.
# 14:26:17  - Combining OG 4787  with length of  8 	 with a query  96  is just finished.
# 14:26:17  - Combining OG 17265  with length of  8 	 with a query  98  is just finished.
# 14:26:17  - Combining OG 10045  with length of  8 	 with a query  96  is just finished.
# 14:26:17  - Combining OG 11589  with length of  8 	 with a query  96  is just finished.
# 14:26:17  - Combining OG 4215  with length of  7 	 with a query  97  is just finished.
# 14:26:17  - Combining OG 2732  with length of  8 	 with a query  99  is just finished.
# 14:26:17  - Combining OG 5433  with length of  8 	 with a query  96  is just finished.
# 14:26:17  - Combining OG 13345  with length of  6 	 with a query  97  is just finished.
# 14:26:17  - Combining OG 6829  with length of  8 	 with a query  97  is just finished.
# 14:26:17  - Combining OG 10872  with length of  6 	 with a query  97  is just finished.
# 14:26:17  - Combining OG 15878  with length of  8 	 with a query  96  is just finished.
# 14:26:17  - Combining OG 10482  with length of  7 	 with a query  96  is just finished.
# 14:26:17  - Combining OG 19368  with length of  8 	 with a query  98  is just finished.
# 14:26:17  - Combining OG 5106  with length of  8 	 with a query  96  is just finished.
# 14:26:17  - Combining OG 12366  with length of  5 	 with a query  96  is just finished.
# 14:26:17  - Combining OG 11571  with length of  8 	 with a query  96  is just finished.
# 14:26:17  - Combining OG 11545  with length of  7 	 with a query  97  is just finished.
#
#  14:26:17 - Combining queries with OG is finished! number of OGs 1454
#
#  14:26:18 - The variable seqRecords_all_filtr is saved as /work/FAC/FBM/DBC/cdessim2/default/smajidi1/fastoma/mammal/old/mml5/fastoma_core/_file_combined_OGs_filtr.pkl
# 14:26:18 - Parallel msa is started for  1454  OGs.
# /work/FAC/FBM/DBC/cdessim2/default/smajidi1/software/miniconda3/lib/python3.8/subprocess.py:844: RuntimeWarning: line buffering (buffering=1) isn't supported in binary mode, the default buffer size will be used
#   self.stdout = io.open(c2pread, 'rb', bufsize)
# /work/FAC/FBM/DBC/cdessim2/default/smajidi1/software/miniconda3/lib/python3.8/subprocess.py:844: RuntimeWarning: line buffering (buffering=1) isn't supported in binary mode, the default buffer size will be used
#   self.stdout = io.open(c2pread, 'rb', bufsize)
# /work/FAC/FBM/DBC/cdessim2/default/smajidi1/software/miniconda3/lib/python3.8/subprocess.py:849: RuntimeWarning: line buffering (buffering=1) isn't supported in binary mode, the default buffer size will be used
#   self.stderr = io.open(errread, 'rb', bufsize)
# /work/FAC/FBM/DBC/cdessim2/default/smajidi1/software/miniconda3/lib/python3.8/subprocess.py:849: RuntimeWarning: line buffering (buffering=1) isn't supported in binary mode, the default buffer size will be used
#   self.stderr = io.open(errread, 'rb', bufsize)
# 14:26:23 - MSA for an OG is just finished:  4.3368308544158936
# 14:26:23 - MSA for an OG is just finished:  4.748178720474243
# 14:26:26 - MSA for an OG is just finished:  2.5308046340942383
# 14:26:30 - MSA for an OG is just finished:  7.436330080032349
# 14:26:38 - MSA for an OG is just finished:  12.028180599212646
# 14:26:38 - MSA for an OG is just finished:  8.031468391418457
# 14:26:42 - MSA for an OG is just finished:  4.128121852874756
# 14:26:50 - MSA for an OG is just finished:  8.053401708602905
# 14:26:54 - MSA for an OG is just finished:  16.1132755279541
# 14:26:56 - MSA for an OG is just finished:  2.083308696746826
# 14:27:07 - MSA for an OG is just finished:  16.1383318901062
# 14:27:11 - MSA for an OG is just finished:  4.413765907287598
# 14:27:25 - MSA for an OG is just finished:  13.716216325759888
# 14:27:31 - MSA for an OG is just finished:  6.718891143798828
# 14:27:34 - MSA for an OG is just finished:  37.703938722610474
# 14:27:37 - MSA for an OG is just finished:  3.258568048477173
# 14:27:52 - MSA for an OG is just finished:  20.180983066558838
# 14:28:01 - MSA for an OG is just finished:  9.66798448562622
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_1871269/832330888.py in run_msa_OG_parallel(seqRecords_all, number_max_workers)
#     511     with concurrent.futures.ProcessPoolExecutor(max_workers=number_max_workers) as executor:
# --> 512         for seqRecords_OG_queries, output_values in zip(seqRecords_all, executor.map(run_msa_OG, seqRecords_all)):
#     513             result_mafft_all_species.append(output_values)
#
# /work/FAC/FBM/DBC/cdessim2/default/smajidi1/software/miniconda3/lib/python3.8/concurrent/futures/process.py in _chain_from_iterable_of_lists(iterable)
#     483     """
# --> 484     for element in iterable:
#     485         element.reverse()
#
# /work/FAC/FBM/DBC/cdessim2/default/smajidi1/software/miniconda3/lib/python3.8/concurrent/futures/_base.py in result_iterator()
#     610                     if timeout is None:
# --> 611                         yield fs.pop().result()
#     612                     else:
#
# /work/FAC/FBM/DBC/cdessim2/default/smajidi1/software/miniconda3/lib/python3.8/concurrent/futures/_base.py in result(self, timeout)
#     433
# --> 434             self._condition.wait(timeout)
#     435
#
# /work/FAC/FBM/DBC/cdessim2/default/smajidi1/software/miniconda3/lib/python3.8/threading.py in wait(self, timeout)
#     301             if timeout is None:
# --> 302                 waiter.acquire()
#     303                 gotit = True
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_1871269/3159067516.py in <module>
#      41
#      42     number_max_workers = 2 # round(int(argv[3])*1.3)
# ---> 43     result_mafft_all_species = run_msa_OG_parallel(seqRecords_all_filtr,number_max_workers)
#
# /tmp/ipykernel_1871269/832330888.py in run_msa_OG_parallel(seqRecords_all, number_max_workers)
#     511     with concurrent.futures.ProcessPoolExecutor(max_workers=number_max_workers) as executor:
#     512         for seqRecords_OG_queries, output_values in zip(seqRecords_all, executor.map(run_msa_OG, seqRecords_all)):
# --> 513             result_mafft_all_species.append(output_values)
#     514
#     515
#
# /work/FAC/FBM/DBC/cdessim2/default/smajidi1/software/miniconda3/lib/python3.8/concurrent/futures/_base.py in __exit__(self, exc_type, exc_val, exc_tb)
#     634
#     635     def __exit__(self, exc_type, exc_val, exc_tb):
# --> 636         self.shutdown(wait=True)
#     637         return False
#     638
#
# /work/FAC/FBM/DBC/cdessim2/default/smajidi1/software/miniconda3/lib/python3.8/concurrent/futures/process.py in shutdown(self, wait)
#     684             self._queue_management_thread_wakeup.wakeup()
#     685             if wait:
# --> 686                 self._queue_management_thread.join()
#     687         # To reduce the risk of opening too many files, remove references to
#     688         # objects that use file descriptors.
#
# /work/FAC/FBM/DBC/cdessim2/default/smajidi1/software/miniconda3/lib/python3.8/threading.py in join(self, timeout)
#    1009
#    1010         if timeout is None:
# -> 1011             self._wait_for_tstate_lock()
#    1012         else:
#    1013             # the behavior of a negative timeout isn't documented, but
#
# /work/FAC/FBM/DBC/cdessim2/default/smajidi1/software/miniconda3/lib/python3.8/threading.py in _wait_for_tstate_lock(self, block, timeout)
#    1025         if lock is None:  # already determined that the C code is done
#    1026             assert self._is_stopped
# -> 1027         elif lock.acquire(block, timeout):
#    1028             lock.release()
#    1029             self._stop()
#
# KeyboardInterrupt:

# %%
    threshold_least_query_sepecies_in_OG = 99 # 15
    kept_oma_species_num = 8 # 20
    
    seqRecords_all_filtr = combine_OG_query_filtr(OGs_queries_filtr, oma_db, threshold_least_query_sepecies_in_OG,kept_oma_species_num)
    
    

    number_max_workers = 2 # round(int(argv[3])*1.3)
    result_mafft_all_species = run_msa_OG_parallel(seqRecords_all_filtr,number_max_workers)

    
    
    
    all_id=[]
    for a in result_mafft_all_species:
        for i in a:
            all_id.append(i.id)
    len(all_id),len(set(all_id))

    list_removed_species=[]
    for i in query_species_names:
        if i not in set(all_id):
            list_removed_species.append(i)

    if len(list_removed_species):
        print("These species are removed from the input proteome:",list_removed_species)
    else:
        print("All input species are included in the MSA.")

    list_added_species=[]
    for i in set(all_id):
        if i not in query_species_names:
            list_added_species.append(i)        
    if len(list_removed_species):
        print("These species are added from OMA database:",list_added_species)
# Out:
# 14:34:40 - Combining queries with OG started for 3205 OGs.
# 14:34:40 - Number of OMA species per OG is calculated
# 14:34:40 - These OMA species are kept ['S0005', 'S0007', 'S0009', 'S0001', 'S0006', 'S0004', 'S0003', 'S0008']
# 14:34:40  - Combining OG 4773  with length of  8 	 with a query  100  is just finished.
# 14:34:40  - Combining OG 11639  with length of  7 	 with a query  100  is just finished.
# 14:34:40  - Combining OG 2275  with length of  8 	 with a query  100  is just finished.
# 14:34:40  - Combining OG 13069  with length of  7 	 with a query  100  is just finished.
# 14:34:40  - Combining OG 12176  with length of  8 	 with a query  100  is just finished.
# 14:34:40  - Combining OG 16747  with length of  7 	 with a query  100  is just finished.
# 14:34:40  - Combining OG 3912  with length of  5 	 with a query  100  is just finished.
# 14:34:40  - Combining OG 9068  with length of  8 	 with a query  100  is just finished.
# 14:34:40  - Combining OG 6482  with length of  8 	 with a query  100  is just finished.
# 14:34:40  - Combining OG 12786  with length of  7 	 with a query  100  is just finished.
# 14:34:40  - Combining OG 17183  with length of  7 	 with a query  100  is just finished.
# 14:34:40  - Combining OG 8212  with length of  8 	 with a query  100  is just finished.
# 14:34:40  - Combining OG 2349  with length of  8 	 with a query  100  is just finished.
# 14:34:40  - Combining OG 12684  with length of  7 	 with a query  100  is just finished.
# 14:34:40  - Combining OG 4791  with length of  6 	 with a query  100  is just finished.
# 14:34:40  - Combining OG 4862  with length of  7 	 with a query  100  is just finished.
# 14:34:40  - Combining OG 3366  with length of  6 	 with a query  100  is just finished.
# 14:34:40  - Combining OG 20071  with length of  7 	 with a query  100  is just finished.
# 14:34:40  - Combining OG 6843  with length of  8 	 with a query  100  is just finished.
# 14:34:40  - Combining OG 15810  with length of  6 	 with a query  100  is just finished.
# 14:34:40  - Combining OG 20432  with length of  6 	 with a query  100  is just finished.
# 14:34:40  - Combining OG 16801  with length of  5 	 with a query  100  is just finished.
# 14:34:40  - Combining OG 6882  with length of  8 	 with a query  100  is just finished.
#
#  14:34:40 - Combining queries with OG is finished! number of OGs 23
#
#  14:34:40 - The variable seqRecords_all_filtr is saved as /work/FAC/FBM/DBC/cdessim2/default/smajidi1/fastoma/mammal/old/mml5/fastoma_core/_file_combined_OGs_filtr.pkl
# 14:34:40 - Parallel msa is started for  23  OGs.
# /work/FAC/FBM/DBC/cdessim2/default/smajidi1/software/miniconda3/lib/python3.8/subprocess.py:844: RuntimeWarning: line buffering (buffering=1) isn't supported in binary mode, the default buffer size will be used
#   self.stdout = io.open(c2pread, 'rb', bufsize)
# /work/FAC/FBM/DBC/cdessim2/default/smajidi1/software/miniconda3/lib/python3.8/subprocess.py:844: RuntimeWarning: line buffering (buffering=1) isn't supported in binary mode, the default buffer size will be used
#   self.stdout = io.open(c2pread, 'rb', bufsize)
# /work/FAC/FBM/DBC/cdessim2/default/smajidi1/software/miniconda3/lib/python3.8/subprocess.py:849: RuntimeWarning: line buffering (buffering=1) isn't supported in binary mode, the default buffer size will be used
#   self.stderr = io.open(errread, 'rb', bufsize)
# /work/FAC/FBM/DBC/cdessim2/default/smajidi1/software/miniconda3/lib/python3.8/subprocess.py:849: RuntimeWarning: line buffering (buffering=1) isn't supported in binary mode, the default buffer size will be used
#   self.stderr = io.open(errread, 'rb', bufsize)
# 14:34:52 - MSA for an OG is just finished:  12.144623279571533
# 14:34:57 - MSA for an OG is just finished:  4.810637712478638
# 14:35:09 - MSA for an OG is just finished:  11.885201215744019
# 14:35:18 - MSA for an OG is just finished:  37.228986740112305
# 14:35:18 - MSA for an OG is just finished:  8.477354288101196
# 14:35:22 - MSA for an OG is just finished:  4.341278314590454
# 14:35:25 - MSA for an OG is just finished:  7.826817512512207
# 14:35:36 - MSA for an OG is just finished:  14.135514736175537
# 14:35:43 - MSA for an OG is just finished:  7.148903846740723
# 14:35:47 - MSA for an OG is just finished:  21.694726705551147
# 14:35:54 - MSA for an OG is just finished:  10.64980673789978
# 14:35:57 - MSA for an OG is just finished:  3.152738094329834
# 14:36:07 - MSA for an OG is just finished:  20.30612015724182
# 14:36:08 - MSA for an OG is just finished:  10.502928972244263
# 14:36:30 - MSA for an OG is just finished:  22.266713619232178
# 14:36:39 - MSA for an OG is just finished:  31.363946676254272
# 14:36:43 - MSA for an OG is just finished:  13.062010288238525
# 14:36:44 - MSA for an OG is just finished:  5.452875137329102
# 14:36:52 - MSA for an OG is just finished:  8.206057786941528
# 14:36:57 - MSA for an OG is just finished:  4.65303373336792
# 14:36:59 - MSA for an OG is just finished:  15.915759801864624
# 14:37:02 - MSA for an OG is just finished:  5.144493341445923
# 14:37:14 - MSA for an OG is just finished:  15.403236865997314

# %% [markdown]
# ## Load pkl file

# %%
# a="/work/FAC/FBM/DBC/cdessim2/default/smajidi1/fastoma/mammal/mml_v4/omamer_v4_search/fastoma_out/"
# a+= "_file_msas.pkl"
# open_file = open(a, "rb") #project_folder+"_file_msas2.pkl"
# result_mafft_all_species = pickle.load(open_file)
# open_file.close()
# print("seq read is loaded", len(result_mafft_all_species))

# result_mafft_all_species[0][:]
# ogs_keep_number = 82
# result_mafft_all_species_filtr = filter_ogs(result_mafft_all_species,ogs_keep_number)
# msa= concatante_alignments(result_mafft_all_species_filtr, ogs_keep_number)


# for record in msa:
#     if record.id =="S0003":
#         a= record.seq

# %%
    ogs_keep_number = 80
    result_mafft_all_species_filtr = filter_ogs(result_mafft_all_species,ogs_keep_number)
    msa= concatante_alignments(result_mafft_all_species_filtr, ogs_keep_number)
# Out:
# 14:42:46 - Filtering MSA started.
# 14:42:46 - The histogram of density ogs is saved.
# 14:42:46 - Filtering MSA finished, keeping 23 out of 23
# 14:42:46 - MSA concatenation started
# 14:42:46 - Alignments len 23
# 14:42:46 - ids:  108 2462
# 14:42:46 - MSA concatenation finished
# 14:42:46 - MSA concatenation has been written in the file /work/FAC/FBM/DBC/cdessim2/default/smajidi1/fastoma/mammal/old/mml5/fastoma_core/_80_msa_concatanated.txt with length 108 25642

# %%
# reading pkl file 
# open_file = open(project_folder+"_file_msas2.pkl", "rb")
# result_mafft_all_species = pickle.load(open_file)
# open_file.close()
# print("seq read is loaded", len(seqRecords_all))

#print(current_time, "- Row-wise filtering of MSA is started.")        
#tresh_ratio_gap_row = 0.3
#msa_filtered_row = msa_filter_row(msa,tresh_ratio_gap_row,query_species_names,ogs_keep_number)
#print(current_time, "- Column-wise filtering of MSA is started.") 
#tresh_ratio_gap_col = 0.3
#msa_filtered_row_col=  msa_filter_col(msa_filtered_row, tresh_ratio_gap_col,tresh_ratio_gap_row,ogs_keep_number)

# %%
#oma_database_address = "/work/FAC/FBM/DBC/cdessim2/default/smajidi1/fastoma/mammal/mml_v4/omamer_v4_database/oma_path_/OmaServer.h5"
#oma_db = db.Database(oma_database_address+"")

#oma_db.tax.as_dict()
#oma_db.tax.genomes.values()
#oma_db.tax.newick()
#import pyoma.browser.models as models
# models.Genome
